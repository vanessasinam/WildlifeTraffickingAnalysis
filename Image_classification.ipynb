# %% [markdown]
# <a href="https://colab.research.google.com/github/vanessasinam/WildlifeTraffickingAnalysis/blob/main/Image_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install rapidfuzz
# Out:
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 24.5 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz
# Successfully installed rapidfuzz-3.5.2

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Duplicate image URLs
# We need an 'image' column to classify species, which is the image URL provided by the page's metadata.
#
# - We found out that the image is not directly relevant to the product advertised.
# - We discovered that even though the domains differ, the image URL is duplicated. I assume the advertisement is posted by a bot on multiple websites.
#
# We will remove the duplicate image URLs; however, at this stage, we will not address the irrelevant images. We will assume that the image URL represents the "most relevant image.

# %%
df = pd.read_csv('/content/drive/MyDrive/BigData/Project/data/final_cleaned_data.csv')
df.head()
# Out:
#                                                 name  \
# 0  adventures and bones color ebay hailstones hal...
# 1  contortus ebay hill miocene physogaleus shark ...
# 2    azaz contortus ebay hill physogaleus sharktooth
# 3  contortus de dent ebay hill miocune physogaleu...
# 4  colline contortus de dent ebay miocune physoga...
#
#                                                title  \
# 0  adventures and bones color ebay hailstones hal...
# 1  contortus ebay hill miocene physogaleus shark ...
# 2    azaz contortus ebay hill physogaleus sharktooth
# 3  contortus de dent ebay hill miocune physogaleu...
# 4  colline contortus de dent ebay miocune physoga...
#
#                                              product  \
# 0  adventures and bones color ebay hailstones hal...
# 1  contortus ebay hill miocene physogaleus shark ...
# 2    azaz contortus ebay hill physogaleus sharktooth
# 3  contortus de dent ebay hill miocune physogaleu...
# 4  colline contortus de dent ebay miocune physoga...
#
#                                          description       domain  \
# 0  adventures and at best bones color deals ebay ...  ebay.com.au
# 1  and at best contortus deals delivery ebay find...   ebay.co.uk
# 2  and at azaz best contortus deals ebay find for...     ebay.com
# 3  comparez contortus darticles de dent des docca...      ebay.fr
# 4  colline comparez contortus darticles de dent d...      ebay.fr
#
#           country        label_product   price currency production_date  \
# 0       Australia  an animal body part   22.25      AUD             NaN
# 1  United Kingdom  an animal body part   12.63      GBP             NaN
# 2             NaN  an animal body part  111.39      CNY             NaN
# 3          France  an animal body part   12.22      EUR             NaN
# 4          France  an animal body part   14.53      EUR             NaN
#
#                                                image  \
# 0  https://images.awesomebooks.com/images/books/r...
# 1  https://i.ebayimg.com/images/g/x~gAAOSwtsVZkch...
# 2  https://i.ebayimg.com/images/g/x~gAAOSwtsVZkch...
# 3  https://i.ebayimg.com/images/g/~M8AAOSwjuBZlzv...
# 4  https://i.ebayimg.com/images/g/x~gAAOSwtsVZkch...
#
#                                                  url location  \
# 0  https://www.ebay.com.au/itm/384104329587?amdat...      NaN
# 1            https://www.ebay.co.uk/itm/222613331802      NaN
# 2       https://www.ebay.com/itm/222613331802?_ul=CN      NaN
# 3  https://www.ebay.fr/itm/222617333943?amdata=en...      NaN
# 4               https://www.ebay.fr/itm/222613331802      NaN
#
#   domain_country_code  domain_country  normalized_price_usd
# 0                  au       Australia                    34
# 1                  uk  United Kingdom                    10
# 2                 com             NaN                   790
# 3                  fr          France                    11
# 4                  fr          France                    13

# %%
# We can confirm that we do have duplicate URLs in our data.
image_column_as_list = df['image'].tolist()
image_column_as_list[0:10]
# Out:
# ['https://images.awesomebooks.com/images/books/rnaimages/9996402263_1.jpg',
#  'https://i.ebayimg.com/images/g/x~gAAOSwtsVZkchE/s-l500.jpg',
#  'https://i.ebayimg.com/images/g/x~gAAOSwtsVZkchE/s-l500.jpg',
#  'https://i.ebayimg.com/images/g/~M8AAOSwjuBZlzvK/s-l500.jpg',
#  'https://i.ebayimg.com/images/g/x~gAAOSwtsVZkchE/s-l500.jpg',
#  'https://i.ebayimg.com/images/g/CQkAAOSwbtFlGxOL/s-l500.jpg',
#  'https://i.ebayimg.com/images/g/CQkAAOSwbtFlGxOL/s-l500.jpg',
#  'https://i.ebayimg.com/images/g/Q1IAAOSws29lGwlq/s-l500.jpg',
#  'https://i.ebayimg.com/images/g/UukAAOSwlfJlGwl5/s-l500.jpg',
#  'https://i.ebayimg.com/images/g/4IQAAOSwmHtlGwk5/s-l500.jpg']

# %%
url_counts = df['image'].value_counts()

duplicates = url_counts[url_counts > 1]

# Count the number of duplicate URLs
num_duplicate_urls = duplicates.sum()

# Total count of rows that are duplicates, including all instances of duplication.
print(f"Number of duplicate image URLs: {num_duplicate_urls}")
# Out:
# Number of duplicate image URLs: 4638

# %%
print(f"Number of unique image URLs that are duplicated: {len(duplicates)}")
# Out:
# Number of unique image URLs that are duplicated: 1662

# %%
duplicate_urls = df.duplicated(subset='image', keep=False)

# The rows where duplication occurs, and if a URL appears more than twice, all of those rows are included in this count.
duplicate_rows = df[duplicate_urls]

# Display the duplicate rows
duplicate_rows
# Out:
#                                                     name  \
# 1      contortus ebay hill miocene physogaleus shark ...
# 2        azaz contortus ebay hill physogaleus sharktooth
# 4      colline contortus de dent ebay miocune physoga...
# 5      almofada brinquedo d de ebay estereo gato peca...
# 6      cuscino d ebay gatto giocattolo imbottito pelu...
# ...                                                  ...
# 17423           bl caiman ebay latirostris mnh ss yacare
# 17424      crocodylus ebay mnh niloticus novaeguineae ss
# 17425               crocodylus ebay niloticus porosus ss
# 17426  canis ebay estampillada hoja iic lupus montada...
# 17428  coin crocodile dollars ebay iaia islands nile ...
#
#                                                    title  \
# 1      contortus ebay hill miocene physogaleus shark ...
# 2        azaz contortus ebay hill physogaleus sharktooth
# 4      colline contortus de dent ebay miocune physoga...
# 5      almofada brinquedo d de ebay estereo gato peca...
# 6      cuscino d ebay gatto giocattolo imbottito pelu...
# ...                                                  ...
# 17423           bl caiman ebay latirostris mnh ss yacare
# 17424      crocodylus ebay mnh niloticus novaeguineae ss
# 17425               crocodylus ebay niloticus porosus ss
# 17426  canis ebay estampillada hoja iic lupus montada...
# 17428  coin crocodile dollars ebay iaia islands nile ...
#
#                                                  product  \
# 1      contortus ebay hill miocene physogaleus shark ...
# 2        azaz contortus ebay hill physogaleus sharktooth
# 4      colline contortus de dent ebay miocune physoga...
# 5      almofada brinquedo d de ebay estereo gato peca...
# 6      cuscino d ebay gatto giocattolo imbottito pelu...
# ...                                                  ...
# 17423           bl caiman ebay latirostris mnh ss yacare
# 17424      crocodylus ebay mnh niloticus novaeguineae ss
# 17425               crocodylus ebay niloticus porosus ss
# 17426  canis ebay estampillada hoja iic lupus montada...
# 17428  coin crocodile dollars ebay iaia islands nile ...
#
#                                              description      domain  \
# 1      and at best contortus deals delivery ebay find...  ebay.co.uk
# 2      and at azaz best contortus deals ebay find for...    ebay.com
# 4      colline comparez contortus darticles de dent d...     ebay.fr
# 5      almofada and at best brinquedo d de deals ebay...    ebay.com
# 6      articoli caratteristiche con confronta consegn...     ebay.it
# ...                                                  ...         ...
# 17423  and at best bl caiman deals ebay find for free...    ebay.com
# 17424  and at best crocodylus deals ebay find for fre...    ebay.com
# 17425  and at best crocodylus deals ebay find for fre...    ebay.com
# 17426  and at best canis deals ebay estampillada find...    ebay.com
# 17428  australia coin coins crocodile dollars ebay ia...     ebay.nl
#
#               country        label_product   price currency production_date  \
# 1      United Kingdom  an animal body part   12.63      GBP             NaN
# 2                 NaN  an animal body part  111.39      CNY             NaN
# 4              France  an animal body part   14.53      EUR             NaN
# 5                 NaN  an animal body part   74.43      EUR             NaN
# 6               Italy  an animal body part   74.43      EUR             NaN
# ...               ...                  ...     ...      ...             ...
# 17423             NaN  an animal body part  138.49      CNY             NaN
# 17424             NaN  an animal body part  131.62      CNY             NaN
# 17425             NaN  an animal body part  119.49      CNY             NaN
# 17426             NaN  an animal body part    5.00      USD             NaN
# 17428     Netherlands  an animal body part  180.99      EUR             NaN
#
#                                                    image  \
# 1      https://i.ebayimg.com/images/g/x~gAAOSwtsVZkch...
# 2      https://i.ebayimg.com/images/g/x~gAAOSwtsVZkch...
# 4      https://i.ebayimg.com/images/g/x~gAAOSwtsVZkch...
# 5      https://i.ebayimg.com/images/g/CQkAAOSwbtFlGxO...
# 6      https://i.ebayimg.com/images/g/CQkAAOSwbtFlGxO...
# ...                                                  ...
# 17423  https://i.ebayimg.com/images/g/5h8AAOSwTUVk0hT...
# 17424  https://i.ebayimg.com/images/g/fzcAAOSwFJlk0g9...
# 17425  https://i.ebayimg.com/images/g/YsUAAOSwt45lEwP...
# 17426  https://i.ebayimg.com/images/g/DowAAOSwhKpj43p...
# 17428  https://i.ebayimg.com/images/g/KFEAAOSwNV1hF~N...
#
#                                                      url location  \
# 1                https://www.ebay.co.uk/itm/222613331802      NaN
# 2           https://www.ebay.com/itm/222613331802?_ul=CN      NaN
# 4                   https://www.ebay.fr/itm/222613331802      NaN
# 5           https://www.ebay.com/itm/155807567987?_ul=PT      NaN
# 6      https://www.ebay.it/itm/155807567987?amdata=en...      NaN
# ...                                                  ...      ...
# 17423       https://www.ebay.com/itm/126105039342?_ul=CN      NaN
# 17424       https://www.ebay.com/itm/125590485442?_ul=CN      NaN
# 17425       https://www.ebay.com/itm/126111169118?_ul=CN      NaN
# 17426       https://www.ebay.com/itm/115699607920?_ul=PA      NaN
# 17428  https://www.ebay.nl/itm/124801735586?amdata=en...      NaN
#
#       domain_country_code  domain_country  normalized_price_usd
# 1                      uk  United Kingdom                    10
# 2                     com             NaN                   790
# 4                      fr          France                    13
# 5                     com             NaN                    68
# 6                      it           Italy                    68
# ...                   ...             ...                   ...
# 17423                 com             NaN                   982
# 17424                 com             NaN                   933
# 17425                 com             NaN                   847
# 17426                 com             NaN                     5
# 17428                  nl     Netherlands                   165
#
# [4659 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17433 entries, 0 to 17432
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  17433 non-null  object
#  1   title                 17433 non-null  object
#  2   product               17433 non-null  object
#  3   description           17432 non-null  object
#  4   domain                17433 non-null  object
#  5   country               14209 non-null  object
#  6   label_product         17433 non-null  object
#  7   price                 17433 non-null  float64
#  8   currency              17433 non-null  object
#  9   production_date       14 non-null     object
#  10  image                 17412 non-null  object
#  11  url                   17433 non-null  object
#  12  location              4744 non-null   object
#  13  domain_country_code   17433 non-null  object
#  14  domain_country        9544 non-null   object
#  15  normalized_price_usd  17433 non-null  int64
# dtypes: float64(1), int64(1), object(14)
# memory usage: 2.1+ MB

# %% [markdown]
# We will eliminate duplicates based on the 'image' field, retaining the first occurrence associated with **the longest text**. This approach is grounded in the assumption that longer text yields more information for species identification. \\
#
# To implement this, we will assess text length in the following order: description, product, title, and name.

# %%
df = df.sort_values(by=['description', 'product', 'title', 'name'],
                    key=lambda col: col.str.len(),
                    ascending=False)

df = df.drop_duplicates(subset='image', keep='first')

# %%
file_path = '/content/drive/MyDrive/BigData/Project/data/url_cleaned_data.csv'
df.to_csv(file_path, index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14437 entries, 8201 to 2707
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  14437 non-null  object
#  1   title                 14437 non-null  object
#  2   product               14437 non-null  object
#  3   description           14436 non-null  object
#  4   domain                14437 non-null  object
#  5   country               12249 non-null  object
#  6   label_product         14437 non-null  object
#  7   price                 14437 non-null  float64
#  8   currency              14437 non-null  object
#  9   production_date       14 non-null     object
#  10  image                 14436 non-null  object
#  11  url                   14437 non-null  object
#  12  location              4738 non-null   object
#  13  domain_country_code   14437 non-null  object
#  14  domain_country        7590 non-null   object
#  15  normalized_price_usd  14437 non-null  int64
# dtypes: float64(1), int64(1), object(14)
# memory usage: 1.9+ MB

# %%
df = pd.read_csv('/content/drive/MyDrive/BigData/Project/data/url_cleaned_data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14437 entries, 0 to 14436
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  14437 non-null  object
#  1   title                 14437 non-null  object
#  2   product               14437 non-null  object
#  3   description           14436 non-null  object
#  4   domain                14437 non-null  object
#  5   country               12249 non-null  object
#  6   label_product         14437 non-null  object
#  7   price                 14437 non-null  float64
#  8   currency              14437 non-null  object
#  9   production_date       14 non-null     object
#  10  image                 14436 non-null  object
#  11  url                   14437 non-null  object
#  12  location              4738 non-null   object
#  13  domain_country_code   14437 non-null  object
#  14  domain_country        7590 non-null   object
#  15  normalized_price_usd  14437 non-null  int64
# dtypes: float64(1), int64(1), object(14)
# memory usage: 1.8+ MB

# %% [markdown]
# # Download images
# A list of expected predictions:
# 1. Shark, Object (post card, badge)
# 2. Beetle
# 3. Beetle
# 4. Beetle
# 5. Beetle
# 6. Shark, Object (post card, badge)
# 7. Beetle
# 8. Wood, Object, Wolf
# 9. Rhinoceros, Rhino, Object (badge)
# 10. Wolf, Object (badge)

# %%
image_column_as_list = df['image'].tolist()
image_column_as_list[0:10]
# Out:
# ['https://www.picclickimg.com/ne0AAOSwn4lim49Q/JAWS-Great-White-Shark-Silver-Coin-Steven.webp',
#  'https://www.picclickimg.com/7rEAAOSwAoNk6CFY/Carabidae-Cychrini-Scaphinotus-Steniridia-ridingsii-monongahelae-USA.webp',
#  'https://www.picclickimg.com/uTYAAOSwhElk6CMq/Carabidae-Carabinae-Cychrini-Scaphinotus-Steniridia-andrewsii-germari-USA.webp',
#  'https://www.picclickimg.com/m6IAAOSwZNJk6B~b/Carabidae-Scaphinotus-Irichroa-viduus-RARE-golden-green-form-USA.webp',
#  'https://www.picclickimg.com/a5QAAOSwVGhiq~Ln/Carabidae-Carabinae-Calosoma-s-lato-Calosoma-Calosoma-sycophantha.webp',
#  'https://www.picclickimg.com/qk4AAOSwFHJim5AB/JAWS-Great-White-Shark-Silver-Coin-Spielberg-Roy.webp',
#  'https://www.picclickimg.com/C48AAOSw5bBiKB9l/Carabidae-Carabinae-Carabus-Carabus-Carabus-goryi-USA.webp',
#  'https://www.picclickimg.com/ybUAAOSwp5JWVoj0/Antoninus-Pius-138AD-Ephesus-in-Ionia-CALYDONIAN-Boar.webp',
#  'https://www.picclickimg.com/htYAAOSwHxdkjFcl/Rhino-Wild-Animal-Zoo-Embroidered.webp',
#  'https://www.picclickimg.com/Yo0AAOSwHudgzeCh/Throw-Me-To-The-Wolves-Embroidered-Patch-Iron-on.webp']

# %%
import cv2 as cv
from matplotlib import pyplot as plt

def display_image(img):
    plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
    plt.axis('off')
    plt.show()

def resize_with_aspect_ratio(image, size=100):
    h, w = image.shape[:2]
    if h > w:
        r = size / float(h)
        dim = (int(w * r), size)
    else:
        r = size / float(w)
        dim = (size, int(h * r))
    return cv.resize(image, dim, interpolation=cv.INTER_AREA)

for i in range(10):
    img_path = f'/content/drive/MyDrive/BigData/Project/data/image_{i}.jpg'

    img = cv.imread(img_path)
    if img is not None:
        resized_img = resize_with_aspect_ratio(img)
        display_image(resized_img)
    else:
        print(f"Image at {img_path} could not be loaded.")

# %%
# Download WEBP image files from URLs and convert them to JPG format
import requests
from PIL import Image
from io import BytesIO

def download_and_convert_image(url, save_path):
  try:
    response = requests.get(url, verify=False)  # Skipping SSL verification
    if response.status_code == 200:
        image = Image.open(BytesIO(response.content)).convert("RGB")
        image.save(save_path, "JPEG")
        return True
  except Exception as e:
    print(f"An error occurred while downloading {url}: {e}")
    return False

# %%
# %%time
import os
import warnings
from urllib3.exceptions import InsecureRequestWarning

# Suppress only the InsecureRequestWarning from urllib3
warnings.simplefilter('ignore', InsecureRequestWarning)

image_directory = '/content/drive/MyDrive/BigData/Project/data/'

# Clear existing images in the directory if starting anew
for filename in os.listdir(image_directory):
    if filename.endswith('.jpg'):
        os.remove(os.path.join(image_directory, filename))

image_column_as_list = df['image'].tolist()
df['image_path'] = pd.NA

for i in range(len(image_column_as_list)):
    url = image_column_as_list[i]

    try:
      # Check if the URL is valid
      if pd.notna(url) and url.startswith('http'):
        image_path = f'{image_directory}image_{i}.jpg'
        success = download_and_convert_image(url, image_path)
        if success:
            df.at[i, 'image_path'] = image_path
        else:
            df.at[i, 'image_path'] = 'error'
      else:
          print(f"Invalid URL at index {i}: {url}")
          df.at[i, 'image_path'] = 'invalid_url'
    except requests.exceptions.SSLError as e:
      print(f"SSL Error for URL {url}: {e}")
    except Exception as e:
      print(f"Error for URL {url}: {e}")

df.to_csv('/content/drive/MyDrive/BigData/Project/data/image_path.csv', index=False)
df.info()
# Out:
# Invalid URL at index 3898: nan
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:996: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# An error occurred while downloading https://d1o0zx25fn5p70.cloudfront.net/UlFHwjchpBjkzcpggXUC-deDGjU=/fit-in/500x0/rebuy-akeneo/products/default/main.svg: cannot identify image file <_io.BytesIO object at 0x7bf7a5c89ad0>
# An error occurred while downloading https://tmpg.ecrater.com/stores/563276/651a83c0a15e6_563276b.jpg: HTTPSConnectionPool(host='tmpg.ecrater.com', port=443): Max retries exceeded with url: /stores/563276/651a83c0a15e6_563276b.jpg (Caused by SSLError(SSLError(1, '[SSL: DH_KEY_TOO_SMALL] dh key too small (_ssl.c:1007)')))
# An error occurred while downloading https://tmpp.ecrater.com/stores/592650/651af13ca98bc_592650b.jpg: HTTPSConnectionPool(host='tmpp.ecrater.com', port=443): Max retries exceeded with url: /stores/592650/651af13ca98bc_592650b.jpg (Caused by SSLError(SSLError(1, '[SSL: DH_KEY_TOO_SMALL] dh key too small (_ssl.c:1007)')))
# An error occurred while downloading https://tmpg.ecrater.com/stores/429064/651a79b523b08_429064b.jpg: HTTPSConnectionPool(host='tmpg.ecrater.com', port=443): Max retries exceeded with url: /stores/429064/651a79b523b08_429064b.jpg (Caused by SSLError(SSLError(1, '[SSL: DH_KEY_TOO_SMALL] dh key too small (_ssl.c:1007)')))
# An error occurred while downloading https://tmpg.ecrater.com/stores/531419/65199f903842a_531419b.jpg: HTTPSConnectionPool(host='tmpg.ecrater.com', port=443): Max retries exceeded with url: /stores/531419/65199f903842a_531419b.jpg (Caused by SSLError(SSLError(1, '[SSL: DH_KEY_TOO_SMALL] dh key too small (_ssl.c:1007)')))
# An error occurred while downloading https://tmpg.ecrater.com/stores/583312/651a92d84cf84_583312b.jpg: HTTPSConnectionPool(host='tmpg.ecrater.com', port=443): Max retries exceeded with url: /stores/583312/651a92d84cf84_583312b.jpg (Caused by SSLError(SSLError(1, '[SSL: DH_KEY_TOO_SMALL] dh key too small (_ssl.c:1007)')))
# An error occurred while downloading https://tmpg.ecrater.com/stores/612722/65198ddd63883_612722b.jpg: HTTPSConnectionPool(host='tmpg.ecrater.com', port=443): Max retries exceeded with url: /stores/612722/65198ddd63883_612722b.jpg (Caused by SSLError(SSLError(1, '[SSL: DH_KEY_TOO_SMALL] dh key too small (_ssl.c:1007)')))
# An error occurred while downloading https://tmpp.ecrater.com/stores/592650/651aff529abd9_592650b.jpg: HTTPSConnectionPool(host='tmpp.ecrater.com', port=443): Max retries exceeded with url: /stores/592650/651aff529abd9_592650b.jpg (Caused by SSLError(SSLError(1, '[SSL: DH_KEY_TOO_SMALL] dh key too small (_ssl.c:1007)')))
# An error occurred while downloading https://tmpp.ecrater.com/stores/404163/6518fdbb26197_404163b.jpg: HTTPSConnectionPool(host='tmpp.ecrater.com', port=443): Max retries exceeded with url: /stores/404163/6518fdbb26197_404163b.jpg (Caused by SSLError(SSLError(1, '[SSL: DH_KEY_TOO_SMALL] dh key too small (_ssl.c:1007)')))
# An error occurred while downloading https://tmpg.ecrater.com/stores/575426/65196829ddaee_575426b.jpg: HTTPSConnectionPool(host='tmpg.ecrater.com', port=443): Max retries exceeded with url: /stores/575426/65196829ddaee_575426b.jpg (Caused by SSLError(SSLError(1, '[SSL: DH_KEY_TOO_SMALL] dh key too small (_ssl.c:1007)')))
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14437 entries, 0 to 14436
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  14437 non-null  object
#  1   title                 14437 non-null  object
#  2   product               14437 non-null  object
#  3   description           14436 non-null  object
#  4   domain                14437 non-null  object
#  5   country               12249 non-null  object
#  6   label_product         14437 non-null  object
#  7   price                 14437 non-null  float64
#  8   currency              14437 non-null  object
#  9   production_date       14 non-null     object
#  10  image                 14436 non-null  object
#  11  url                   14437 non-null  object
#  12  location              4738 non-null   object
#  13  domain_country_code   14437 non-null  object
#  14  domain_country        7590 non-null   object
#  15  normalized_price_usd  14437 non-null  int64
#  16  image_path            14437 non-null  object
# dtypes: float64(1), int64(1), object(15)
# memory usage: 1.9+ MB
# CPU times: user 4min 29s, sys: 23.1 s, total: 4min 53s
# Wall time: 50min 46s

# %%
# A list of URLs that should be skipped during the downloading process due to the errors we've encountered
skip_urls = [
    'https://d1o0zx25fn5p70.cloudfront.net/UlFHwjchpBjkzcpggXUC-deDGjU=/fit-in/500x0/rebuy-akeneo/products/default/main.svg',
    'https://tmpg.ecrater.com/stores/563276/651a83c0a15e6_563276b.jpg',
    'https://tmpp.ecrater.com/stores/592650/651af13ca98bc_592650b.jpg',
    'https://tmpg.ecrater.com/stores/429064/651a79b523b08_429064b.jpg',
    'https://tmpg.ecrater.com/stores/531419/65199f903842a_531419b.jpg',
    'https://tmpg.ecrater.com/stores/583312/651a92d84cf84_583312b.jpg',
    'https://tmpg.ecrater.com/stores/612722/65198ddd63883_612722b.jpg',
    'https://tmpp.ecrater.com/stores/592650/651aff529abd9_592650b.jpg',
    'https://tmpp.ecrater.com/stores/404163/6518fdbb26197_404163b.jpg',
    'https://tmpg.ecrater.com/stores/575426/65196829ddaee_575426b.jpg'
]

# %% [markdown]
# We need to identify the specific images that failed to download and attempt to download only those images again, without re-downloading the images that were downloaded successfully.

# %%
# %%time
image_directory = '/content/drive/MyDrive/BigData/Project/data/'
image_column_as_list = df['image'].tolist()
df['image_path'] = pd.NA

# Create a set of already downloaded image filenames
downloaded_images = set(os.listdir(image_directory))

# for i, url in enumerate(df['image'][:10]):
for i, url in enumerate(image_column_as_list):
    image_path = f'{image_directory}image_{i}.jpg'

    if url in skip_urls:
        print(f"Skipping download for URL at index {i}: {url}")
        df.at[i, 'image_path'] = 'skipped'
    elif os.path.basename(image_path) in downloaded_images:
        print(f"Image already downloaded at index {i}: {url}")
        df.at[i, 'image_path'] = image_path
    else:
        if pd.notna(url) and url.startswith('http'):
            success = download_and_convert_image(url, image_path)
            if success:
                df.at[i, 'image_path'] = image_path
            else:
                df.at[i, 'image_path'] = 'error'
        else:
            print(f"Invalid URL at index {i}: {url}")
            df.at[i, 'image_path'] = 'invalid_url'

df.to_csv('/content/drive/MyDrive/BigData/Project/data/image_path.csv', index=False)

# %%
df = pd.read_csv('/content/drive/MyDrive/BigData/Project/data/image_path.csv')
df.tail()
# Out:
#                                               name  \
# 14432  bag black braided cobra implora skin tassel
# 14433                from mussel polished thailand
# 14434               black implora ostrich skin xin
# 14435                            in lucite octopus
# 14436            accurate description great seller
#
#                                                    title  \
# 14432  bags christmas cobra free genuine natural ship...
# 14433                      from mussel polished thailand
# 14434  black christmas free genuine hides leather lea...
# 14435                                  in lucite octopus
# 14436  black collaboration hoodie mastermind shark sk...
#
#                                                  product description  \
# 14432  bags christmas cobra free genuine natural ship...        size
# 14433                      from mussel polished thailand        each
# 14434  black christmas free genuine hides leather lea...           h
# 14435                                  in lucite octopus           x
# 14436  black collaboration hoodie mastermind shark sk...         NaN
#
#              domain country        label_product   price currency  \
# 14432   implora.com     NaN  an animal body part  325.00      USD
# 14433  boneroom.com     NaN  an animal body part    5.00      USD
# 14434   implora.com     NaN  an animal body part  480.00      USD
# 14435  boneroom.com     NaN  an animal body part   25.00      USD
# 14436    ioffer.com     NaN  an animal body part   24.99      USD
#
#       production_date                                              image  \
# 14432             NaN               http://implora.com/images/0773-1.jpg
# 14433             NaN  http://www.boneroom.com/uploads/4/8/1/1/481182...
# 14434             NaN            http://implora.com/images/0503_02-1.jpg
# 14435             NaN  http://www.boneroom.com/uploads/4/8/1/1/481182...
# 14436             NaN  http://www.ioffer.com/rails/active_storage/blo...
#
#                                                      url location  \
# 14432  http://implora.com/product.asp?jd=Implora%20Bl...      NaN
# 14433  http://www.boneroom.com/store/p4584/Polished_m...      NaN
# 14434  http://implora.com/product.asp?jd=Implora%20Os...      NaN
# 14435  http://www.boneroom.com/store/p3874/Octopus_in...      NaN
# 14436  http://www.ioffer.com/vp/mastermind-x-collabor...      NaN
#
#       domain_country_code domain_country  normalized_price_usd  \
# 14432                 com            NaN                   325
# 14433                 com            NaN                     5
# 14434                 com            NaN                   480
# 14435                 com            NaN                    25
# 14436                 com            NaN                    25
#
#                                               image_path
# 14432  /content/drive/MyDrive/Big Data/Project/Data/i...
# 14433  /content/drive/MyDrive/Big Data/Project/Data/i...
# 14434  /content/drive/MyDrive/Big Data/Project/Data/i...
# 14435  /content/drive/MyDrive/Big Data/Project/Data/i...
# 14436  /content/drive/MyDrive/Big Data/Project/Data/i...

# %% [markdown]
# I can confirm that the images that failed to download display a "404 Not Found" page, and the image file names correspond to the row index.

# %%
# View the specific rows where 'image_path' columns is equal to 'error' or 'invalid_url'
error_df = df[(df['image_path'] == 'error') | (df['image_path'] == 'invalid_url')]

error_df['image']
# Out:
# 411      http://www.raydworkshop.com/es-got/img/gots/go...
# 412      http://www.raydworkshop.com/es-got/img/gots/go...
# 2409     https://da1urhpfd469z.cloudfront.net/uploads/a...
# 2557     https://da1urhpfd469z.cloudfront.net/uploads/a...
# 2686     https://da1urhpfd469z.cloudfront.net/uploads/a...
#                                ...
# 14389    https://www.thetaxidermystore.com/media/catalo...
# 14390    https://www.thetaxidermystore.com/media/catalo...
# 14393    https://www.thetaxidermystore.com/media/catalo...
# 14394    https://www.thetaxidermystore.com/media/catalo...
# 14400    https://www.thetaxidermystore.com/media/catalo...
# Name: image, Length: 93, dtype: object

# %%
specific_url_df = df[df['image_path'] == '/content/drive/MyDrive/Big Data/Project/Data/image_413.jpg']

specific_url_df
# Out:
#                                                   name  \
# 413  bauers bonefishpermit by crab flats fly free n...
#
#                                                  title  \
# 413  bauers bonefishpermit by crab flats fly free n...
#
#                                                product  \
# 413  bauers bonefishpermit by crab flats fly free n...
#
#                                            description        domain  \
# 413  a accept acceptable add additional after align...  picclick.com
#
#            country        label_product  price currency production_date  \
# 413  United States  an animal body part    8.5      USD             NaN
#
#                                                  image  \
# 413  https://www.picclickimg.com/1RMAAOSwsrBeuzV7/B...
#
#                                                    url  \
# 413  http://picclick.com/Bauers-Flats-Crab-Bonefish...
#
#                     location domain_country_code domain_country  \
# 413  Boca Raton, Florida, US                 com            NaN
#
#      normalized_price_usd                                         image_path
# 413                     8  /content/drive/MyDrive/Big Data/Project/Data/i...

# %%
specific_url_df = df[df['image_path'] == '/content/drive/MyDrive/BigData/Project/data/image_412.jpg']
specific_url_df
# Out:
# Empty DataFrame
# Columns: [name, title, product, description, domain, country, label_product, price, currency, production_date, image, url, location, domain_country_code, domain_country, normalized_price_usd, image_path]
# Index: []

# %%
# Check the number of downloaded image files
import os

image_directory = '/content/drive/MyDrive/BigData/Project/data/'

all_files = os.listdir(image_directory)
jpg_files_count = sum(file.endswith('.jpg') for file in all_files)
print(f"Number of .jpg image files in the directory: {jpg_files_count}")
# Out:
# Number of .jpg image files in the directory: 14334

# %% [markdown]
# # Keras Applications
# Reference: https://keras.io/api/applications/

# %%
df = pd.read_csv('/content/drive/MyDrive/BigData/Project/data/image_path.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14437 entries, 0 to 14436
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  14437 non-null  object
#  1   title                 14437 non-null  object
#  2   product               14437 non-null  object
#  3   description           14436 non-null  object
#  4   domain                14437 non-null  object
#  5   country               12249 non-null  object
#  6   label_product         14437 non-null  object
#  7   price                 14437 non-null  float64
#  8   currency              14437 non-null  object
#  9   production_date       14 non-null     object
#  10  image                 14436 non-null  object
#  11  url                   14437 non-null  object
#  12  location              4738 non-null   object
#  13  domain_country_code   14437 non-null  object
#  14  domain_country        7590 non-null   object
#  15  normalized_price_usd  14437 non-null  int64
#  16  image_path            14437 non-null  object
# dtypes: float64(1), int64(1), object(15)
# memory usage: 1.9+ MB

# %% [markdown]
# ## ResNet50
#
# Understanding ResNet is essential for appreciating the advancements in computer vision. The ResNet architecture, a significant leap forward in this field, was first introduced by Kaiming He, Xiangyu Zhang, Shaoqing Ren, and Jian Sun in their landmark 2015 research paper on computer vision, titled ["Deep Residual Learning for Image Recognition"](https://arxiv.org/abs/1512.03385?context=cs). This innovative neural network model enables the creation of exceptionally deep networks, exceeding 150 layers in some configurations, though ResNet50, a popular variant, is specifically designed with 50 layers.
#
# Before the development of ResNet, it was theoretically believed that adding more layers to a neural network would reduce loss and increase accuracy. However, in practice, this led to a decrease in accuracy due to the "Vanishing Gradient Problem" encountered in Convolutional Neural Networks during backpropagation. ResNet addresses this problem through the implementation of Skip Connections, which involve adding the original input to the output of the convolutional block, thereby preserving the gradient flow through the network.

# %%
from tensorflow.keras.preprocessing import image
from keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions

# %%
model = ResNet50(weights='imagenet')

predictions = []

# Loop through the first 10 images
for i in range(10):
    img_path = f'/content/drive/MyDrive/BigData/Project/data/image_{i}.jpg'

    img = image.load_img(img_path, target_size=(224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)

    preds = model.predict(x)
    decoded_preds = decode_predictions(preds, top=3)[0]

    keywords = [pred[1] for pred in decoded_preds]
    predictions.append(', '.join(keywords))

df.loc[0:9, 'ResNet50'] = predictions

# Keep only the first 10 rows
df = df.iloc[0:10]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 [==============================] - 1s 0us/step
# 1/1 [==============================] - 2s 2s/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 327ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 309ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 290ms/step
# 1/1 [==============================] - 0s 292ms/step
# 1/1 [==============================] - 0s 336ms/step

# %%
df['ResNet50'].iloc[0:10]
# Out:
# 0                             mask, pug, corkscrew
# 1              ground_beetle, tiger_beetle, weevil
# 2              ground_beetle, weevil, tiger_beetle
# 3         tiger_beetle, ground_beetle, leaf_beetle
# 4         ground_beetle, tiger_beetle, leaf_beetle
# 5             jigsaw_puzzle, book_jacket, envelope
# 6         ground_beetle, dung_beetle, tiger_beetle
# 7               buckle, chambered_nautilus, shield
# 8                        pitcher, hook, hair_slide
# 9    magnetic_compass, combination_lock, barometer
# Name: ResNet50, dtype: object

# %%
# Now let's apply this to all the rows
# But this time, I will extract only the top one
# NO BATCH - 1h 26min 53s

# %%time

model = ResNet50(weights='imagenet')

df['ResNet50'] = np.nan

# Loop through all the images
for i in range(len(df)):
    try:
        img_path = f'/content/drive/MyDrive/BigData/Project/data/image_{i}.jpg'

        # Load and preprocess the image
        img = image.load_img(img_path, target_size=(224, 224))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)

        # Predict and decode the results
        preds = model.predict(x)
        decoded_preds = decode_predictions(preds, top=1)[0]  # Top 1 prediction
        top_pred = decoded_preds[0][1]
        df.at[i, 'ResNet50'] = top_pred

    except Exception as e:
        print(f"Error processing image at index {i}: {e}")
        continue
df.to_csv('/content/drive/MyDrive/Big Data/Project/resnet_50.csv', index=False)
df.info()
# Out:
# Streaming output truncated to the last 5000 lines.
# 1/1 [==============================] - 0s 423ms/step
# 1/1 [==============================] - 0s 431ms/step
# 1/1 [==============================] - 0s 358ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 326ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 350ms/step
# 1/1 [==============================] - 1s 562ms/step
# 1/1 [==============================] - 0s 474ms/step
# 1/1 [==============================] - 0s 420ms/step
# 1/1 [==============================] - 0s 331ms/step
# 1/1 [==============================] - 0s 369ms/step
# 1/1 [==============================] - 1s 641ms/step
# 1/1 [==============================] - 1s 636ms/step
# 1/1 [==============================] - 1s 711ms/step
# 1/1 [==============================] - 1s 638ms/step
# 1/1 [==============================] - 1s 678ms/step
# 1/1 [==============================] - 1s 552ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 328ms/step
# 1/1 [==============================] - 0s 256ms/step
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 241ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 308ms/step
# 1/1 [==============================] - 0s 238ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 252ms/step
# 1/1 [==============================] - 0s 380ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 401ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 359ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 817ms/step
# 1/1 [==============================] - 1s 663ms/step
# 1/1 [==============================] - 1s 672ms/step
# 1/1 [==============================] - 0s 369ms/step
# 1/1 [==============================] - 0s 423ms/step
# 1/1 [==============================] - 0s 416ms/step
# 1/1 [==============================] - 0s 465ms/step
# 1/1 [==============================] - 0s 436ms/step
# 1/1 [==============================] - 0s 383ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 297ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 298ms/step
# 1/1 [==============================] - 0s 339ms/step
# 1/1 [==============================] - 0s 333ms/step
# 1/1 [==============================] - 0s 365ms/step
# 1/1 [==============================] - 1s 541ms/step
# 1/1 [==============================] - 1s 542ms/step
# 1/1 [==============================] - 0s 447ms/step
# 1/1 [==============================] - 0s 499ms/step
# 1/1 [==============================] - 0s 476ms/step
# 1/1 [==============================] - 0s 442ms/step
# 1/1 [==============================] - 0s 299ms/step
# 1/1 [==============================] - 0s 274ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 186ms/step
# Error processing image at index 9577: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_9577.jpg'
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 304ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 302ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 360ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 297ms/step
# 1/1 [==============================] - 0s 338ms/step
# 1/1 [==============================] - 0s 339ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 309ms/step
# 1/1 [==============================] - 0s 310ms/step
# 1/1 [==============================] - 0s 309ms/step
# 1/1 [==============================] - 0s 298ms/step
# 1/1 [==============================] - 0s 310ms/step
# 1/1 [==============================] - 0s 306ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 304ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 341ms/step
# 1/1 [==============================] - 0s 310ms/step
# 1/1 [==============================] - 0s 283ms/step
# 1/1 [==============================] - 0s 305ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 305ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 306ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 339ms/step
# 1/1 [==============================] - 0s 297ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 258ms/step
# 1/1 [==============================] - 0s 464ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 294ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 340ms/step
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 280ms/step
# 1/1 [==============================] - 0s 301ms/step
# 1/1 [==============================] - 0s 331ms/step
# 1/1 [==============================] - 0s 310ms/step
# 1/1 [==============================] - 0s 295ms/step
# 1/1 [==============================] - 0s 298ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 295ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 259ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 1s 618ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 300ms/step
# 1/1 [==============================] - 0s 302ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 332ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 308ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 294ms/step
# 1/1 [==============================] - 0s 356ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 293ms/step
# 1/1 [==============================] - 0s 326ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 327ms/step
# 1/1 [==============================] - 0s 295ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 254ms/step
# 1/1 [==============================] - 0s 306ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 299ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 302ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 309ms/step
# 1/1 [==============================] - 0s 353ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 334ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 299ms/step
# 1/1 [==============================] - 0s 329ms/step
# 1/1 [==============================] - 0s 309ms/step
# 1/1 [==============================] - 0s 288ms/step
# 1/1 [==============================] - 0s 293ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 293ms/step
# 1/1 [==============================] - 0s 294ms/step
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 337ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 290ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 309ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 344ms/step
# 1/1 [==============================] - 0s 297ms/step
# 1/1 [==============================] - 0s 306ms/step
# 1/1 [==============================] - 0s 291ms/step
# 1/1 [==============================] - 0s 302ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 374ms/step
# 1/1 [==============================] - 0s 425ms/step
# 1/1 [==============================] - 0s 388ms/step
# 1/1 [==============================] - 0s 424ms/step
# 1/1 [==============================] - 0s 425ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 398ms/step
# 1/1 [==============================] - 0s 332ms/step
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 353ms/step
# 1/1 [==============================] - 0s 364ms/step
# 1/1 [==============================] - 0s 327ms/step
# 1/1 [==============================] - 0s 351ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 238ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 247ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 230ms/step
# 1/1 [==============================] - 0s 235ms/step
# 1/1 [==============================] - 0s 241ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 258ms/step
# 1/1 [==============================] - 0s 245ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 341ms/step
# 1/1 [==============================] - 0s 327ms/step
# 1/1 [==============================] - 0s 343ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 296ms/step
# 1/1 [==============================] - 0s 290ms/step
# 1/1 [==============================] - 0s 349ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 326ms/step
# 1/1 [==============================] - 0s 294ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 347ms/step
# 1/1 [==============================] - 0s 331ms/step
# 1/1 [==============================] - 0s 301ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 1s 629ms/step
# 1/1 [==============================] - 0s 272ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 351ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 334ms/step
# 1/1 [==============================] - 0s 306ms/step
# 1/1 [==============================] - 0s 352ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 327ms/step
# 1/1 [==============================] - 0s 334ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 1s 823ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 300ms/step
# 1/1 [==============================] - 0s 326ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 335ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 338ms/step
# 1/1 [==============================] - 0s 308ms/step
# 1/1 [==============================] - 0s 306ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 293ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 0s 306ms/step
# 1/1 [==============================] - 0s 305ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 327ms/step
# 1/1 [==============================] - 0s 310ms/step
# 1/1 [==============================] - 0s 326ms/step
# 1/1 [==============================] - 0s 329ms/step
# 1/1 [==============================] - 0s 294ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 298ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 284ms/step
# 1/1 [==============================] - 0s 296ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 302ms/step
# 1/1 [==============================] - 0s 286ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 290ms/step
# 1/1 [==============================] - 0s 289ms/step
# 1/1 [==============================] - 0s 301ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 358ms/step
# 1/1 [==============================] - 0s 305ms/step
# 1/1 [==============================] - 0s 305ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 332ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 299ms/step
# 1/1 [==============================] - 0s 301ms/step
# 1/1 [==============================] - 0s 299ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 294ms/step
# 1/1 [==============================] - 0s 327ms/step
# 1/1 [==============================] - 0s 288ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 284ms/step
# 1/1 [==============================] - 0s 310ms/step
# 1/1 [==============================] - 0s 305ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 306ms/step
# 1/1 [==============================] - 0s 297ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 301ms/step
# 1/1 [==============================] - 0s 301ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 300ms/step
# 1/1 [==============================] - 0s 343ms/step
# 1/1 [==============================] - 0s 339ms/step
# 1/1 [==============================] - 0s 334ms/step
# 1/1 [==============================] - 0s 341ms/step
# 1/1 [==============================] - 0s 306ms/step
# 1/1 [==============================] - 0s 309ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 309ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 304ms/step
# 1/1 [==============================] - 0s 296ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 350ms/step
# 1/1 [==============================] - 0s 304ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 284ms/step
# 1/1 [==============================] - 0s 305ms/step
# 1/1 [==============================] - 0s 264ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 1s 510ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 1s 506ms/step
# 1/1 [==============================] - 0s 256ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 241ms/step
# 1/1 [==============================] - 0s 300ms/step
# 1/1 [==============================] - 0s 328ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 295ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 332ms/step
# 1/1 [==============================] - 0s 284ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 331ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 258ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 246ms/step
# 1/1 [==============================] - 0s 276ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 304ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 298ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 300ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 333ms/step
# 1/1 [==============================] - 0s 298ms/step
# 1/1 [==============================] - 0s 293ms/step
# 1/1 [==============================] - 0s 304ms/step
# 1/1 [==============================] - 0s 230ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 181ms/step
# ...
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 183ms/step
# Error processing image at index 14245: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14245.jpg'
# Error processing image at index 14246: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14246.jpg'
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 184ms/step
# Error processing image at index 14254: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14254.jpg'
# Error processing image at index 14255: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14255.jpg'
# Error processing image at index 14256: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14256.jpg'
# Error processing image at index 14257: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14257.jpg'
# Error processing image at index 14258: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14258.jpg'
# Error processing image at index 14259: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14259.jpg'
# 1/1 [==============================] - 0s 287ms/step
# 1/1 [==============================] - 0s 302ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 288ms/step
# 1/1 [==============================] - 0s 298ms/step
# Error processing image at index 14267: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14267.jpg'
# 1/1 [==============================] - 0s 285ms/step
# 1/1 [==============================] - 0s 296ms/step
# 1/1 [==============================] - 0s 304ms/step
# Error processing image at index 14271: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14271.jpg'
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 311ms/step
# Error processing image at index 14274: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14274.jpg'
# Error processing image at index 14275: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14275.jpg'
# 1/1 [==============================] - 0s 302ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 308ms/step
# Error processing image at index 14279: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14279.jpg'
# Error processing image at index 14280: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14280.jpg'
# Error processing image at index 14281: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14281.jpg'
# Error processing image at index 14282: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14282.jpg'
# Error processing image at index 14283: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14283.jpg'
# Error processing image at index 14284: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14284.jpg'
# 1/1 [==============================] - 0s 298ms/step
# 1/1 [==============================] - 0s 297ms/step
# 1/1 [==============================] - 0s 296ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 230ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 185ms/step
# Error processing image at index 14302: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14302.jpg'
# Error processing image at index 14303: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14303.jpg'
# Error processing image at index 14304: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14304.jpg'
# Error processing image at index 14305: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14305.jpg'
# Error processing image at index 14306: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14306.jpg'
# Error processing image at index 14307: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14307.jpg'
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 187ms/step
# Error processing image at index 14312: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14312.jpg'
# Error processing image at index 14313: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14313.jpg'
# Error processing image at index 14314: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14314.jpg'
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 183ms/step
# Error processing image at index 14320: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14320.jpg'
# Error processing image at index 14321: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14321.jpg'
# Error processing image at index 14322: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14322.jpg'
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 183ms/step
# Error processing image at index 14330: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14330.jpg'
# Error processing image at index 14331: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14331.jpg'
# Error processing image at index 14332: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14332.jpg'
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 287ms/step
# Error processing image at index 14337: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14337.jpg'
# 1/1 [==============================] - 0s 344ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 333ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 347ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 333ms/step
# 1/1 [==============================] - 0s 334ms/step
# 1/1 [==============================] - 0s 329ms/step
# 1/1 [==============================] - 0s 298ms/step
# Error processing image at index 14352: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14352.jpg'
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 319ms/step
# Error processing image at index 14355: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14355.jpg'
# Error processing image at index 14356: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14356.jpg'
# Error processing image at index 14357: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14357.jpg'
# Error processing image at index 14358: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14358.jpg'
# Error processing image at index 14359: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14359.jpg'
# Error processing image at index 14360: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14360.jpg'
# Error processing image at index 14361: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14361.jpg'
# 1/1 [==============================] - 0s 255ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 184ms/step
# Error processing image at index 14367: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14367.jpg'
# Error processing image at index 14368: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14368.jpg'
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 195ms/step
# Error processing image at index 14379: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14379.jpg'
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 194ms/step
# Error processing image at index 14382: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14382.jpg'
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 183ms/step
# Error processing image at index 14389: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14389.jpg'
# Error processing image at index 14390: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14390.jpg'
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 179ms/step
# Error processing image at index 14393: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14393.jpg'
# Error processing image at index 14394: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14394.jpg'
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 194ms/step
# Error processing image at index 14400: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14400.jpg'
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 291ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 294ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 308ms/step
# 1/1 [==============================] - 0s 297ms/step
# 1/1 [==============================] - 0s 310ms/step
# 1/1 [==============================] - 0s 326ms/step
# 1/1 [==============================] - 0s 306ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 310ms/step
# 1/1 [==============================] - 0s 358ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 290ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 182ms/step
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14437 entries, 0 to 14436
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  14437 non-null  object
#  1   title                 14437 non-null  object
#  2   product               14437 non-null  object
#  3   description           14436 non-null  object
#  4   domain                14437 non-null  object
#  5   country               12249 non-null  object
#  6   label_product         14437 non-null  object
#  7   price                 14437 non-null  float64
#  8   currency              14437 non-null  object
#  9   production_date       14 non-null     object
#  10  image                 14436 non-null  object
#  11  url                   14437 non-null  object
#  12  location              4738 non-null   object
#  13  domain_country_code   14437 non-null  object
#  14  domain_country        7590 non-null   object
#  15  normalized_price_usd  14437 non-null  int64
#  16  image_path            14437 non-null  object
#  17  ResNet50              14334 non-null  object
# dtypes: float64(1), int64(1), object(16)
# memory usage: 2.0+ MB
# CPU times: user 1h 29min 12s, sys: 1min 27s, total: 1h 30min 40s
# Wall time: 1h 26min 53s

# %%
df.tail()
# Out:
#                                               name  \
# 14432  bag black braided cobra implora skin tassel
# 14433                from mussel polished thailand
# 14434               black implora ostrich skin xin
# 14435                            in lucite octopus
# 14436            accurate description great seller
#
#                                                    title  \
# 14432  bags christmas cobra free genuine natural ship...
# 14433                      from mussel polished thailand
# 14434  black christmas free genuine hides leather lea...
# 14435                                  in lucite octopus
# 14436  black collaboration hoodie mastermind shark sk...
#
#                                                  product description  \
# 14432  bags christmas cobra free genuine natural ship...        size
# 14433                      from mussel polished thailand        each
# 14434  black christmas free genuine hides leather lea...           h
# 14435                                  in lucite octopus           x
# 14436  black collaboration hoodie mastermind shark sk...         NaN
#
#              domain country        label_product   price currency  \
# 14432   implora.com     NaN  an animal body part  325.00      USD
# 14433  boneroom.com     NaN  an animal body part    5.00      USD
# 14434   implora.com     NaN  an animal body part  480.00      USD
# 14435  boneroom.com     NaN  an animal body part   25.00      USD
# 14436    ioffer.com     NaN  an animal body part   24.99      USD
#
#       production_date                                              image  \
# 14432             NaN               http://implora.com/images/0773-1.jpg
# 14433             NaN  http://www.boneroom.com/uploads/4/8/1/1/481182...
# 14434             NaN            http://implora.com/images/0503_02-1.jpg
# 14435             NaN  http://www.boneroom.com/uploads/4/8/1/1/481182...
# 14436             NaN  http://www.ioffer.com/rails/active_storage/blo...
#
#                                                      url location  \
# 14432  http://implora.com/product.asp?jd=Implora%20Bl...      NaN
# 14433  http://www.boneroom.com/store/p4584/Polished_m...      NaN
# 14434  http://implora.com/product.asp?jd=Implora%20Os...      NaN
# 14435  http://www.boneroom.com/store/p3874/Octopus_in...      NaN
# 14436  http://www.ioffer.com/vp/mastermind-x-collabor...      NaN
#
#       domain_country_code domain_country  normalized_price_usd  \
# 14432                 com            NaN                   325
# 14433                 com            NaN                     5
# 14434                 com            NaN                   480
# 14435                 com            NaN                    25
# 14436                 com            NaN                    25
#
#                                               image_path          ResNet50
# 14432  /content/drive/MyDrive/Big Data/Project/Data/i...           mailbag
# 14433  /content/drive/MyDrive/Big Data/Project/Data/i...              slug
# 14434  /content/drive/MyDrive/Big Data/Project/Data/i...  bulletproof_vest
# 14435  /content/drive/MyDrive/Big Data/Project/Data/i...            binder
# 14436  /content/drive/MyDrive/Big Data/Project/Data/i...              suit

# %% [markdown]
# ## VGG16
# VGG16 is a deep convolutional network for image recognition developed by Karen Simonyan and Andrew Zisserman of the University of Oxford in a paper titled [“Very Deep Convolutional Networks for Large-Scale Image Recognition”](https://arxiv.org/pdf/1409.1556.pdf) in 2014. The model achieves its high level of accuracy by employing a series of convolutional layers with small receptive fields (3x3 filters), followed by max-pooling layers. One of the key contributions of the VGG16 model is its simplicity, using this uniform architecture to reach a depth of 16 layers (13 convolutional and 3 fully connected layers).
#
# The VGG16 model was a runner-up in the 2014 ImageNet competition, but it became popular due to its simplicity and its capability to generalize. It can be used for a wide range of image recognition tasks and is particularly effective for capturing spatial hierarchies in images, which is crucial for identifying features in wildlife images. However, the VGG16 architecture is quite large in terms of the number of parameters, which can make it computationally intensive, especially in terms of memory usage.

# %%
df = pd.read_csv('/content/drive/MyDrive/BigData/Project/data/resnet_50.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14437 entries, 0 to 14436
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  14437 non-null  object
#  1   title                 14437 non-null  object
#  2   product               14437 non-null  object
#  3   description           14436 non-null  object
#  4   domain                14437 non-null  object
#  5   country               12249 non-null  object
#  6   label_product         14437 non-null  object
#  7   price                 14437 non-null  float64
#  8   currency              14437 non-null  object
#  9   production_date       14 non-null     object
#  10  image                 14436 non-null  object
#  11  url                   14437 non-null  object
#  12  location              4738 non-null   object
#  13  domain_country_code   14437 non-null  object
#  14  domain_country        7590 non-null   object
#  15  normalized_price_usd  14437 non-null  int64
#  16  image_path            14437 non-null  object
#  17  ResNet50              14334 non-null  object
# dtypes: float64(1), int64(1), object(16)
# memory usage: 2.0+ MB

# %%
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from keras.preprocessing import image

model = VGG16(weights='imagenet')

predictions = []

# Loop through the first 10 images
for i in range(10):
    img_path = f'/content/drive/MyDrive/BigData/Project/data/image_{i}.jpg'

    img = image.load_img(img_path, target_size=(224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)

    preds = model.predict(x)
    decoded_preds = decode_predictions(preds, top=3)[0]

    keywords = [pred[1] for pred in decoded_preds]
    predictions.append(', '.join(keywords))

df.loc[0:9, 'VGG16'] = predictions
df = df.iloc[0:10]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467096/553467096 [==============================] - 11s 0us/step
# 1/1 [==============================] - 1s 686ms/step
# 1/1 [==============================] - 1s 533ms/step
# 1/1 [==============================] - 1s 529ms/step
# 1/1 [==============================] - 1s 522ms/step
# 1/1 [==============================] - 1s 528ms/step
# 1/1 [==============================] - 1s 533ms/step
# 1/1 [==============================] - 1s 521ms/step
# 1/1 [==============================] - 1s 784ms/step
# 1/1 [==============================] - 1s 726ms/step
# 1/1 [==============================] - 1s 526ms/step

# %%
df['VGG16'].iloc[0:10]
# Out:
# 0            birdhouse, envelope, jigsaw_puzzle
# 1            ground_beetle, dung_beetle, weevil
# 2     ground_beetle, weevil, long-horned_beetle
# 3      ground_beetle, tiger_beetle, leaf_beetle
# 4       ground_beetle, dung_beetle, leaf_beetle
# 5              coho, leatherback_turtle, packet
# 6       ground_beetle, dung_beetle, leaf_beetle
# 7                         shield, buckle, screw
# 8                buckle, tiger_cat, cowboy_boot
# 9    magnetic_compass, wall_clock, analog_clock
# Name: VGG16, dtype: object

# %%
# BATCH & GPU: 1h 24min 42s
# RUNNING AGAIN: 2min 40s
# %%time

from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from keras.preprocessing import image

# Load the VGG16 model
model = VGG16(weights='imagenet')

def predict_batch(paths, model):
    imgs_array = []
    for img_path in paths:
        try:
            img = image.load_img(img_path, target_size=(224, 224))
            x = image.img_to_array(img)
            imgs_array.append(x)
        except Exception as e:
            print(f"Error processing image at path {img_path}: {e}")
            continue
    if len(imgs_array) == 0:  # Check if all images in the batch failed
        return [np.nan] * len(paths)
    imgs_array = np.array(imgs_array)
    imgs_array = preprocess_input(imgs_array)

    try:
        preds = model.predict(imgs_array)
        decoded = decode_predictions(preds, top=1)
        top_preds = [pred[0][1] if len(pred) > 0 else np.nan for pred in decoded]
        return top_preds
    except Exception as e:
        print(f"Error during prediction: {e}")
        return [np.nan] * len(paths)

# Batch processing
batch_size = 32
df['VGG16'] = np.nan

for i in range(0, len(df), batch_size):
    batch_paths = [f'/content/drive/MyDrive/BigData/Project/data/image_{j}.jpg' for j in range(i, min(i + batch_size, len(df)))]
    batch_preds = predict_batch(batch_paths, model)
    df.loc[i:i+len(batch_preds)-1, 'VGG16'] = batch_preds

df.to_csv('/content/drive/MyDrive/BigData/Project/data/vgg16.csv', index=False)
df.info()
# Out:
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_411.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_411.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_412.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_412.jpg'
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_2409.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_2409.jpg'
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_2557.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_2557.jpg'
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 40ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_2686.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_2686.jpg'
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_2731.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_2731.jpg'
# 1/1 [==============================] - 0s 26ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_2759.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_2759.jpg'
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_3212.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_3212.jpg'
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_3379.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_3379.jpg'
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_3484.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_3484.jpg'
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_3898.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_3898.jpg'
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 42ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_4514.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_4514.jpg'
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_4948.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_4948.jpg'
# 1/1 [==============================] - 0s 28ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_4983.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_4983.jpg'
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_5032.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_5032.jpg'
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_5722.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_5722.jpg'
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_7048.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_7048.jpg'
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_7198.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_7198.jpg'
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_7365.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_7365.jpg'
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_7708.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_7708.jpg'
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_8752.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_8752.jpg'
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_9577.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_9577.jpg'
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_10453.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_10453.jpg'
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 36ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_10783.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_10783.jpg'
# 1/1 [==============================] - 0s 38ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_10813.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_10813.jpg'
# 1/1 [==============================] - 0s 34ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_10819.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_10819.jpg'
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_10955.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_10955.jpg'
# 1/1 [==============================] - 0s 46ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_10993.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_10993.jpg'
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 43ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_11194.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_11194.jpg'
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_11562.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_11562.jpg'
# 1/1 [==============================] - 0s 32ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_11600.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_11600.jpg'
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_11844.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_11844.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_11871.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_11871.jpg'
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_12204.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_12204.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_12221.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_12221.jpg'
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_13364.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_13364.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_13366.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_13366.jpg'
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 46ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_13705.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_13705.jpg'
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 34ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_13874.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_13874.jpg'
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14051.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14051.jpg'
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 26ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14118.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14118.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14137.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14137.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14143.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14143.jpg'
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14189.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14189.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14194.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14194.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14197.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14197.jpg'
# 1/1 [==============================] - 0s 32ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14211.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14211.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14213.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14213.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14218.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14218.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14219.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14219.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14227.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14227.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14236.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14236.jpg'
# 1/1 [==============================] - 0s 25ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14245.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14245.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14246.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14246.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14254.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14254.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14255.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14255.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14256.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14256.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14257.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14257.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14258.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14258.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14259.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14259.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14267.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14267.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14271.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14271.jpg'
# 1/1 [==============================] - 0s 24ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14274.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14274.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14275.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14275.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14279.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14279.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14280.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14280.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14281.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14281.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14282.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14282.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14283.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14283.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14284.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14284.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14302.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14302.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14303.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14303.jpg'
# 1/1 [==============================] - 0s 26ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14304.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14304.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14305.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14305.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14306.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14306.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14307.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14307.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14312.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14312.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14313.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14313.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14314.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14314.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14320.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14320.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14321.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14321.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14322.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14322.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14330.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14330.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14331.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14331.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14332.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14332.jpg'
# 1/1 [==============================] - 0s 24ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14337.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14337.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14352.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14352.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14355.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14355.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14356.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14356.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14357.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14357.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14358.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14358.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14359.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14359.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14360.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14360.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14361.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14361.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14367.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14367.jpg'
# 1/1 [==============================] - 0s 28ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14368.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14368.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14379.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14379.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14382.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14382.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14389.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14389.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14390.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14390.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14393.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14393.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14394.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14394.jpg'
# 1/1 [==============================] - 0s 31ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14400.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14400.jpg'
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14437 entries, 0 to 14436
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  14437 non-null  object
#  1   title                 14437 non-null  object
#  2   product               14437 non-null  object
#  3   description           14436 non-null  object
#  4   domain                14437 non-null  object
#  5   country               12249 non-null  object
#  6   label_product         14437 non-null  object
#  7   price                 14437 non-null  float64
#  8   currency              14437 non-null  object
#  9   production_date       14 non-null     object
#  10  image                 14436 non-null  object
#  11  url                   14437 non-null  object
#  12  location              4738 non-null   object
#  13  domain_country_code   14437 non-null  object
#  14  domain_country        7590 non-null   object
#  15  normalized_price_usd  14437 non-null  int64
#  16  image_path            14437 non-null  object
#  17  ResNet50              14334 non-null  object
#  18  VGG16                 14334 non-null  object
# dtypes: float64(1), int64(1), object(17)
# memory usage: 2.1+ MB
# CPU times: user 2min 7s, sys: 4.76 s, total: 2min 11s
# Wall time: 2min 40s

# %%
df.head()
# Out:
#                                                 name  \
# 0  book coin great jaws roy scheider shark signed...
# 1  carabidae cychrini monongahelae ridingsii scap...
# 2  andrewsii carabidae carabinae cychrini germari...
# 3  carabidae form goldengreen irichroa rare scaph...
# 4  calosoma carabidae carabinae lato s sycophanth...
#
#                                                title  \
# 0  book coin great jaws picclick roy scheider sha...
# 1  carabidae cychrini monongahelae picclick ridin...
# 2  andrewsii carabidae carabinae cychrini germari...
# 3  carabidae form goldengreen irichroa picclick r...
# 4  calosoma carabidae carabinae lato picclick s s...
#
#                                              product  \
# 0  book coin great jaws picclick roy scheider sha...
# 1  carabidae cychrini monongahelae picclick ridin...
# 2  andrewsii carabidae carabinae cychrini germari...
# 3  carabidae form goldengreen irichroa picclick r...
# 4  calosoma carabidae carabinae lato picclick s s...
#
#                                          description        domain  \
# 0  a aaron abela ability able aboard about above ...  picclick.com
# 1  a ab abasinus abbreviatus abkhasicus abkhazia ...  picclick.com
# 2  a ab abasinus abbreviatus abkhasicus abkhazia ...  picclick.com
# 3  a ab abasinus abbreviatus abkhasicus abkhazia ...  picclick.com
# 4  a abbreviatus abhazia abkhasicus abkhazia abov...  picclick.com
#
#           country        label_product  price currency production_date  \
# 0  United Kingdom  an animal body part  15.74      USD             NaN
# 1   United States  an animal body part  49.99      USD             NaN
# 2   United States  an animal body part  49.99      USD             NaN
# 3   United States  an animal body part  49.99      USD             NaN
# 4   United States  an animal body part   9.99      USD             NaN
#
#                                                image  \
# 0  https://www.picclickimg.com/ne0AAOSwn4lim49Q/J...
# 1  https://www.picclickimg.com/7rEAAOSwAoNk6CFY/C...
# 2  https://www.picclickimg.com/uTYAAOSwhElk6CMq/C...
# 3  https://www.picclickimg.com/m6IAAOSwZNJk6B~b/C...
# 4  https://www.picclickimg.com/a5QAAOSwVGhiq~Ln/C...
#
#                                                  url  \
# 0  http://picclick.com/JAWS-Great-White-Shark-Sil...
# 1  http://picclick.com/Carabidae-Cychrini-Scaphin...
# 2  http://picclick.com/Carabidae-Carabinae-Cychri...
# 3  http://picclick.com/Carabidae-Scaphinotus-Iric...
# 4  http://picclick.com/Carabidae-Carabinae-Caloso...
#
#                                         location domain_country_code  \
# 0  Manchester, Take a look at my other items, GB                 com
# 1                      Jamison, Pennsylvania, US                 com
# 2                      Jamison, Pennsylvania, US                 com
# 3                      Jamison, Pennsylvania, US                 com
# 4                      Jamison, Pennsylvania, US                 com
#
#   domain_country  normalized_price_usd  \
# 0            NaN                    16
# 1            NaN                    50
# 2            NaN                    50
# 3            NaN                    50
# 4            NaN                    10
#
#                                           image_path       ResNet50  \
# 0  /content/drive/MyDrive/Big Data/Project/Data/i...           mask
# 1  /content/drive/MyDrive/Big Data/Project/Data/i...  ground_beetle
# 2  /content/drive/MyDrive/Big Data/Project/Data/i...  ground_beetle
# 3  /content/drive/MyDrive/Big Data/Project/Data/i...   tiger_beetle
# 4  /content/drive/MyDrive/Big Data/Project/Data/i...  ground_beetle
#
#            VGG16
# 0      birdhouse
# 1  ground_beetle
# 2  ground_beetle
# 3  ground_beetle
# 4  ground_beetle

# %%
df.tail()
# Out:
#                                               name  \
# 14432  bag black braided cobra implora skin tassel
# 14433                from mussel polished thailand
# 14434               black implora ostrich skin xin
# 14435                            in lucite octopus
# 14436            accurate description great seller
#
#                                                    title  \
# 14432  bags christmas cobra free genuine natural ship...
# 14433                      from mussel polished thailand
# 14434  black christmas free genuine hides leather lea...
# 14435                                  in lucite octopus
# 14436  black collaboration hoodie mastermind shark sk...
#
#                                                  product description  \
# 14432  bags christmas cobra free genuine natural ship...        size
# 14433                      from mussel polished thailand        each
# 14434  black christmas free genuine hides leather lea...           h
# 14435                                  in lucite octopus           x
# 14436  black collaboration hoodie mastermind shark sk...         NaN
#
#              domain country        label_product   price currency  \
# 14432   implora.com     NaN  an animal body part  325.00      USD
# 14433  boneroom.com     NaN  an animal body part    5.00      USD
# 14434   implora.com     NaN  an animal body part  480.00      USD
# 14435  boneroom.com     NaN  an animal body part   25.00      USD
# 14436    ioffer.com     NaN  an animal body part   24.99      USD
#
#       production_date                                              image  \
# 14432             NaN               http://implora.com/images/0773-1.jpg
# 14433             NaN  http://www.boneroom.com/uploads/4/8/1/1/481182...
# 14434             NaN            http://implora.com/images/0503_02-1.jpg
# 14435             NaN  http://www.boneroom.com/uploads/4/8/1/1/481182...
# 14436             NaN  http://www.ioffer.com/rails/active_storage/blo...
#
#                                                      url location  \
# 14432  http://implora.com/product.asp?jd=Implora%20Bl...      NaN
# 14433  http://www.boneroom.com/store/p4584/Polished_m...      NaN
# 14434  http://implora.com/product.asp?jd=Implora%20Os...      NaN
# 14435  http://www.boneroom.com/store/p3874/Octopus_in...      NaN
# 14436  http://www.ioffer.com/vp/mastermind-x-collabor...      NaN
#
#       domain_country_code domain_country  normalized_price_usd  \
# 14432                 com            NaN                   325
# 14433                 com            NaN                     5
# 14434                 com            NaN                   480
# 14435                 com            NaN                    25
# 14436                 com            NaN                    25
#
#                                               image_path          ResNet50  \
# 14432  /content/drive/MyDrive/Big Data/Project/Data/i...           mailbag
# 14433  /content/drive/MyDrive/Big Data/Project/Data/i...              slug
# 14434  /content/drive/MyDrive/Big Data/Project/Data/i...  bulletproof_vest
# 14435  /content/drive/MyDrive/Big Data/Project/Data/i...            binder
# 14436  /content/drive/MyDrive/Big Data/Project/Data/i...              suit
#
#        VGG16
# 14432  purse
# 14433  conch
# 14434  cliff
# 14435   iPod
# 14436  cloak

# %% [markdown]
# ## EfficientNetV2M
# EfficientNetV2 is an advancement in the field of scalable and efficient neural networks, introduced by Mingxing Tan and Quoc V. Le in their paper [“EfficientNetV2: Smaller Models and Faster Training”](https://arxiv.org/pdf/2104.00298.pdf). It represents an evolution of the original EfficientNet architecture, focusing on optimizing training speed and parameter efficiency. The "V2" version, particularly the 'L' variant (Large), is designed to be even more efficient and performant.
#
# EfficientNetV2M is a part of the EfficientNetV2 series, which is renowned for its advanced balance of accuracy and efficiency in image processing tasks. It employs a compound scaling method that systematically scales network depth, width, and resolution using fixed coefficients, optimizing performance within computational constraints. With a medium-sized architecture, EfficientNetV2M strikes a balance between the smaller and larger variants in the series, offering enhanced accuracy while maintaining reasonable computational demands. This model incorporates features like MBConv and Fused-MBConv blocks, enhancing training speed and model efficiency. EfficientNetV2M is well-suited for diverse machine learning tasks requiring high accuracy and moderate computational resources, making it ideal for applications in advanced image classification.

# %% [markdown]
# Regarding the processing time for many rows, I will consider running the predictions in batches and using GPU for faster processing.

# %%
df = pd.read_csv('/content/drive/MyDrive/BigData/Project/data/vgg16.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14437 entries, 0 to 14436
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  14437 non-null  object
#  1   title                 14437 non-null  object
#  2   product               14437 non-null  object
#  3   description           14436 non-null  object
#  4   domain                14437 non-null  object
#  5   country               12249 non-null  object
#  6   label_product         14437 non-null  object
#  7   price                 14437 non-null  float64
#  8   currency              14437 non-null  object
#  9   production_date       14 non-null     object
#  10  image                 14436 non-null  object
#  11  url                   14437 non-null  object
#  12  location              4738 non-null   object
#  13  domain_country_code   14437 non-null  object
#  14  domain_country        7590 non-null   object
#  15  normalized_price_usd  14437 non-null  int64
#  16  image_path            14437 non-null  object
#  17  ResNet50              14334 non-null  object
#  18  VGG16                 14334 non-null  object
# dtypes: float64(1), int64(1), object(17)
# memory usage: 2.1+ MB

# %%
from keras.preprocessing import image
from keras.applications.efficientnet_v2 import EfficientNetV2M, preprocess_input, decode_predictions

# Load the EfficientNetV2M model
model = EfficientNetV2M(weights='imagenet')

predictions = []

# Loop through the first 10 images
for i in range(10):
    img_path = f'/content/drive/MyDrive/BigData/Project/data/image_{i}.jpg'

    # Resize the image to 480x480 as expected by EfficientNetV2M
    img = image.load_img(img_path, target_size=(480, 480))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)

    preds = model.predict(x)
    decoded_preds = decode_predictions(preds, top=3)[0]

    keywords = [pred[1] for pred in decoded_preds]
    predictions.append(', '.join(keywords))

df.loc[0:9, 'EfficientNetV2M'] = predictions
df = df.iloc[0:10]
# Out:
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 78ms/step

# %%
df['EfficientNetV2M'].iloc[0:10]
# Out:
# 0          great_white_shark, mousetrap, tiger_shark
# 1    ground_beetle, tiger_beetle, long-horned_beetle
# 2    ground_beetle, tiger_beetle, long-horned_beetle
# 3    ground_beetle, tiger_beetle, long-horned_beetle
# 4    ground_beetle, tiger_beetle, long-horned_beetle
# 5        great_white_shark, tiger_shark, book_jacket
# 6    ground_beetle, tiger_beetle, long-horned_beetle
# 7              chambered_nautilus, trilobite, chiton
# 8                         triceratops, zebra, buckle
# 9                           puck, jersey, coffee_mug
# Name: EfficientNetV2M, dtype: object

# %%
# BATCH & GPU: 11min 31s
# %%time
from keras.preprocessing import image
from keras.applications.efficientnet_v2 import EfficientNetV2M, preprocess_input, decode_predictions

# Load the EfficientNetV2M model
model = EfficientNetV2M(weights='imagenet')

def predict_batch(paths, model):
    imgs_array = []
    for img_path in paths:
        try:
            # Resize the image to 480x480 for EfficientNetV2M
            img = image.load_img(img_path, target_size=(480, 480))
            x = image.img_to_array(img)
            imgs_array.append(x)
        except Exception as e:
            print(f"Error processing image at path {img_path}: {e}")
            continue
    if len(imgs_array) == 0:  # Check if all images in the batch failed
        return [np.nan] * len(paths)
    imgs_array = np.array(imgs_array)
    imgs_array = preprocess_input(imgs_array)

    try:
        preds = model.predict(imgs_array)
        decoded = decode_predictions(preds, top=1)
        top_preds = [pred[0][1] if len(pred) > 0 else np.nan for pred in decoded]
        return top_preds
    except Exception as e:
        print(f"Error during prediction: {e}")
        return [np.nan] * len(paths)

# Batch processing
batch_size = 32
df['EfficientNetV2M'] = np.nan

for i in range(0, len(df), batch_size):
    batch_paths = [f'/content/drive/MyDrive/BigData/Project/data/image_{j}.jpg' for j in range(i, min(i + batch_size, len(df)))]
    batch_preds = predict_batch(batch_paths, model)
    df.loc[i:i+len(batch_preds)-1, 'EfficientNetV2M'] = batch_preds

df.to_csv('/content/drive/MyDrive/Big Data/Project/efficientNetV2M.csv', index=False)
df.tail()
# Out:
# 1/1 [==============================] - 9s 9s/step
# 1/1 [==============================] - 0s 451ms/step
# 1/1 [==============================] - 0s 461ms/step
# 1/1 [==============================] - 0s 427ms/step
# 1/1 [==============================] - 0s 396ms/step
# 1/1 [==============================] - 0s 432ms/step
# 1/1 [==============================] - 0s 438ms/step
# 1/1 [==============================] - 0s 440ms/step
# 1/1 [==============================] - 0s 438ms/step
# 1/1 [==============================] - 0s 470ms/step
# 1/1 [==============================] - 1s 627ms/step
# 1/1 [==============================] - 1s 554ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_411.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_411.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_412.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_412.jpg'
# 1/1 [==============================] - 11s 11s/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 440ms/step
# 1/1 [==============================] - 0s 454ms/step
# 1/1 [==============================] - 0s 434ms/step
# 1/1 [==============================] - 0s 444ms/step
# 1/1 [==============================] - 0s 415ms/step
# 1/1 [==============================] - 0s 419ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 416ms/step
# 1/1 [==============================] - 0s 419ms/step
# 1/1 [==============================] - 0s 419ms/step
# 1/1 [==============================] - 0s 460ms/step
# 1/1 [==============================] - 1s 614ms/step
# 1/1 [==============================] - 0s 426ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 405ms/step
# 1/1 [==============================] - 0s 416ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 415ms/step
# 1/1 [==============================] - 0s 428ms/step
# 1/1 [==============================] - 0s 427ms/step
# 1/1 [==============================] - 0s 429ms/step
# 1/1 [==============================] - 0s 443ms/step
# 1/1 [==============================] - 0s 446ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 415ms/step
# 1/1 [==============================] - 0s 415ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 436ms/step
# 1/1 [==============================] - 0s 442ms/step
# 1/1 [==============================] - 0s 442ms/step
# 1/1 [==============================] - 0s 438ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 419ms/step
# 1/1 [==============================] - 0s 427ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 418ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 445ms/step
# 1/1 [==============================] - 0s 433ms/step
# 1/1 [==============================] - 0s 433ms/step
# 1/1 [==============================] - 0s 453ms/step
# 1/1 [==============================] - 0s 444ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 421ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 415ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 430ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_2409.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_2409.jpg'
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 420ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 415ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_2557.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_2557.jpg'
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 435ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_2686.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_2686.jpg'
# 1/1 [==============================] - 0s 428ms/step
# 1/1 [==============================] - 0s 447ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_2731.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_2731.jpg'
# 1/1 [==============================] - 0s 432ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_2759.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_2759.jpg'
# 1/1 [==============================] - 0s 463ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 448ms/step
# 1/1 [==============================] - 0s 433ms/step
# 1/1 [==============================] - 0s 444ms/step
# 1/1 [==============================] - 0s 436ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 400ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_3212.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_3212.jpg'
# 1/1 [==============================] - 0s 398ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 404ms/step
# 1/1 [==============================] - 0s 440ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_3379.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_3379.jpg'
# 1/1 [==============================] - 0s 436ms/step
# 1/1 [==============================] - 0s 445ms/step
# 1/1 [==============================] - 0s 432ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_3484.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_3484.jpg'
# 1/1 [==============================] - 0s 423ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 437ms/step
# 1/1 [==============================] - 0s 467ms/step
# 1/1 [==============================] - 0s 433ms/step
# 1/1 [==============================] - 0s 430ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 413ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_3898.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_3898.jpg'
# 1/1 [==============================] - 0s 403ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 417ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 440ms/step
# 1/1 [==============================] - 0s 433ms/step
# 1/1 [==============================] - 0s 432ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 404ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 432ms/step
# 1/1 [==============================] - 0s 432ms/step
# 1/1 [==============================] - 0s 431ms/step
# 1/1 [==============================] - 0s 438ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_4514.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_4514.jpg'
# 1/1 [==============================] - 0s 402ms/step
# 1/1 [==============================] - 0s 420ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 415ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 438ms/step
# 1/1 [==============================] - 0s 434ms/step
# 1/1 [==============================] - 0s 478ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 412ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_4948.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_4948.jpg'
# 1/1 [==============================] - 0s 403ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_4983.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_4983.jpg'
# 1/1 [==============================] - 0s 401ms/step
# 1/1 [==============================] - 0s 413ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_5032.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_5032.jpg'
# 1/1 [==============================] - 0s 400ms/step
# 1/1 [==============================] - 0s 405ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 443ms/step
# 1/1 [==============================] - 0s 429ms/step
# 1/1 [==============================] - 0s 425ms/step
# 1/1 [==============================] - 0s 432ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 440ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 434ms/step
# 1/1 [==============================] - 0s 442ms/step
# 1/1 [==============================] - 0s 433ms/step
# 1/1 [==============================] - 0s 436ms/step
# 1/1 [==============================] - 0s 492ms/step
# 1/1 [==============================] - 0s 419ms/step
# 1/1 [==============================] - 0s 413ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_5722.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_5722.jpg'
# 1/1 [==============================] - 0s 398ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 437ms/step
# 1/1 [==============================] - 0s 436ms/step
# 1/1 [==============================] - 1s 509ms/step
# 1/1 [==============================] - 0s 444ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 0s 436ms/step
# 1/1 [==============================] - 0s 435ms/step
# 1/1 [==============================] - 0s 421ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 435ms/step
# 1/1 [==============================] - 0s 487ms/step
# 1/1 [==============================] - 0s 485ms/step
# 1/1 [==============================] - 0s 439ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 403ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 433ms/step
# 1/1 [==============================] - 0s 434ms/step
# 1/1 [==============================] - 0s 430ms/step
# 1/1 [==============================] - 0s 443ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_7048.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_7048.jpg'
# 1/1 [==============================] - 0s 398ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 413ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_7198.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_7198.jpg'
# 1/1 [==============================] - 0s 396ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 437ms/step
# 1/1 [==============================] - 0s 444ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_7365.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_7365.jpg'
# 1/1 [==============================] - 0s 429ms/step
# 1/1 [==============================] - 0s 427ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 405ms/step
# 1/1 [==============================] - 0s 418ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 440ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_7708.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_7708.jpg'
# 1/1 [==============================] - 0s 429ms/step
# 1/1 [==============================] - 0s 444ms/step
# 1/1 [==============================] - 0s 440ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 403ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 433ms/step
# 1/1 [==============================] - 0s 441ms/step
# 1/1 [==============================] - 0s 436ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 405ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 405ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 421ms/step
# 1/1 [==============================] - 0s 449ms/step
# 1/1 [==============================] - 0s 450ms/step
# 1/1 [==============================] - 0s 443ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 405ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 404ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 437ms/step
# 1/1 [==============================] - 0s 441ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_8752.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_8752.jpg'
# 1/1 [==============================] - 0s 439ms/step
# 1/1 [==============================] - 0s 436ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 415ms/step
# 1/1 [==============================] - 0s 403ms/step
# 1/1 [==============================] - 0s 419ms/step
# 1/1 [==============================] - 0s 419ms/step
# 1/1 [==============================] - 0s 441ms/step
# 1/1 [==============================] - 0s 430ms/step
# 1/1 [==============================] - 1s 543ms/step
# 1/1 [==============================] - 0s 402ms/step
# 1/1 [==============================] - 1s 528ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 405ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 471ms/step
# 1/1 [==============================] - 0s 447ms/step
# 1/1 [==============================] - 0s 425ms/step
# 1/1 [==============================] - 0s 433ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 406ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_9577.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_9577.jpg'
# 1/1 [==============================] - 0s 398ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 404ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 442ms/step
# 1/1 [==============================] - 0s 429ms/step
# 1/1 [==============================] - 0s 431ms/step
# 1/1 [==============================] - 0s 401ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 445ms/step
# 1/1 [==============================] - 0s 458ms/step
# 1/1 [==============================] - 0s 429ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 495ms/step
# 1/1 [==============================] - 0s 405ms/step
# 1/1 [==============================] - 0s 432ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_10453.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_10453.jpg'
# 1/1 [==============================] - 0s 417ms/step
# 1/1 [==============================] - 0s 430ms/step
# 1/1 [==============================] - 0s 434ms/step
# 1/1 [==============================] - 0s 404ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 481ms/step
# 1/1 [==============================] - 0s 405ms/step
# 1/1 [==============================] - 0s 410ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_10783.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_10783.jpg'
# 1/1 [==============================] - 0s 427ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_10813.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_10813.jpg'
# 1/1 [==============================] - 0s 423ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_10819.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_10819.jpg'
# 1/1 [==============================] - 0s 429ms/step
# 1/1 [==============================] - 0s 405ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 421ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_10955.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_10955.jpg'
# 1/1 [==============================] - 0s 401ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_10993.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_10993.jpg'
# 1/1 [==============================] - 0s 400ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 405ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 441ms/step
# 1/1 [==============================] - 0s 431ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_11194.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_11194.jpg'
# 1/1 [==============================] - 0s 417ms/step
# 1/1 [==============================] - 0s 417ms/step
# 1/1 [==============================] - 0s 476ms/step
# 1/1 [==============================] - 0s 421ms/step
# 1/1 [==============================] - 0s 402ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 425ms/step
# 1/1 [==============================] - 0s 424ms/step
# 1/1 [==============================] - 0s 424ms/step
# 1/1 [==============================] - 0s 435ms/step
# 1/1 [==============================] - 0s 408ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_11562.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_11562.jpg'
# 1/1 [==============================] - 1s 614ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_11600.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_11600.jpg'
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 418ms/step
# 1/1 [==============================] - 0s 416ms/step
# 1/1 [==============================] - 0s 384ms/step
# 1/1 [==============================] - 0s 439ms/step
# 1/1 [==============================] - 0s 436ms/step
# 1/1 [==============================] - 0s 445ms/step
# 1/1 [==============================] - 0s 445ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_11844.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_11844.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_11871.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_11871.jpg'
# 1/1 [==============================] - 0s 428ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 420ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 441ms/step
# 1/1 [==============================] - 0s 451ms/step
# 1/1 [==============================] - 0s 449ms/step
# 1/1 [==============================] - 0s 448ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_12204.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_12204.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_12221.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_12221.jpg'
# 1/1 [==============================] - 0s 421ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 417ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 416ms/step
# 1/1 [==============================] - 0s 443ms/step
# 1/1 [==============================] - 0s 391ms/step
# 1/1 [==============================] - 0s 438ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 405ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 418ms/step
# 1/1 [==============================] - 0s 416ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 436ms/step
# 1/1 [==============================] - 0s 435ms/step
# 1/1 [==============================] - 0s 429ms/step
# 1/1 [==============================] - 0s 434ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 419ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 448ms/step
# 1/1 [==============================] - 0s 427ms/step
# 1/1 [==============================] - 0s 442ms/step
# 1/1 [==============================] - 0s 434ms/step
# 1/1 [==============================] - 0s 418ms/step
# 1/1 [==============================] - 0s 404ms/step
# 1/1 [==============================] - 0s 415ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_13364.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_13364.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_13366.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_13366.jpg'
# 1/1 [==============================] - 0s 427ms/step
# 1/1 [==============================] - 0s 418ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 437ms/step
# 1/1 [==============================] - 0s 424ms/step
# 1/1 [==============================] - 0s 448ms/step
# 1/1 [==============================] - 0s 428ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 414ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_13705.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_13705.jpg'
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 449ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_13874.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_13874.jpg'
# 1/1 [==============================] - 0s 425ms/step
# 1/1 [==============================] - 0s 436ms/step
# 1/1 [==============================] - 0s 432ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 417ms/step
# 1/1 [==============================] - 0s 415ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14051.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14051.jpg'
# 1/1 [==============================] - 0s 405ms/step
# 1/1 [==============================] - 0s 406ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14118.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14118.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14137.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14137.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14143.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14143.jpg'
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 433ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14189.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14189.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14194.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14194.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14197.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14197.jpg'
# 1/1 [==============================] - 0s 412ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14211.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14211.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14213.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14213.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14218.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14218.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14219.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14219.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14227.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14227.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14236.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14236.jpg'
# 1/1 [==============================] - 4s 4s/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14245.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14245.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14246.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14246.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14254.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14254.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14255.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14255.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14256.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14256.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14257.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14257.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14258.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14258.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14259.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14259.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14267.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14267.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14271.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14271.jpg'
# 1/1 [==============================] - 4s 4s/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14274.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14274.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14275.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14275.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14279.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14279.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14280.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14280.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14281.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14281.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14282.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14282.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14283.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14283.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14284.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14284.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14302.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14302.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14303.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14303.jpg'
# 1/1 [==============================] - 0s 312ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14304.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14304.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14305.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14305.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14306.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14306.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14307.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14307.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14312.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14312.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14313.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14313.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14314.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14314.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14320.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14320.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14321.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14321.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14322.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14322.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14330.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14330.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14331.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14331.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14332.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14332.jpg'
# 1/1 [==============================] - 3s 3s/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14337.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14337.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14352.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14352.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14355.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14355.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14356.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14356.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14357.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14357.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14358.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14358.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14359.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14359.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14360.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14360.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14361.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14361.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14367.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14367.jpg'
# 1/1 [==============================] - 0s 359ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14368.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14368.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14379.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14379.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14382.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14382.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14389.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14389.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14390.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14390.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14393.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14393.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14394.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14394.jpg'
# 1/1 [==============================] - 4s 4s/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14400.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14400.jpg'
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 1s 1s/step
# CPU times: user 8min 8s, sys: 2min 12s, total: 10min 21s
# Wall time: 11min 31s
#                                               name  \
# 14432  bag black braided cobra implora skin tassel
# 14433                from mussel polished thailand
# 14434               black implora ostrich skin xin
# 14435                            in lucite octopus
# 14436            accurate description great seller
#
#                                                    title  \
# 14432  bags christmas cobra free genuine natural ship...
# 14433                      from mussel polished thailand
# 14434  black christmas free genuine hides leather lea...
# 14435                                  in lucite octopus
# 14436  black collaboration hoodie mastermind shark sk...
#
#                                                  product description  \
# 14432  bags christmas cobra free genuine natural ship...        size
# 14433                      from mussel polished thailand        each
# 14434  black christmas free genuine hides leather lea...           h
# 14435                                  in lucite octopus           x
# 14436  black collaboration hoodie mastermind shark sk...         NaN
#
#              domain country        label_product   price currency  \
# 14432   implora.com     NaN  an animal body part  325.00      USD
# 14433  boneroom.com     NaN  an animal body part    5.00      USD
# 14434   implora.com     NaN  an animal body part  480.00      USD
# 14435  boneroom.com     NaN  an animal body part   25.00      USD
# 14436    ioffer.com     NaN  an animal body part   24.99      USD
#
#       production_date                                              image  \
# 14432             NaN               http://implora.com/images/0773-1.jpg
# 14433             NaN  http://www.boneroom.com/uploads/4/8/1/1/481182...
# 14434             NaN            http://implora.com/images/0503_02-1.jpg
# 14435             NaN  http://www.boneroom.com/uploads/4/8/1/1/481182...
# 14436             NaN  http://www.ioffer.com/rails/active_storage/blo...
#
#                                                      url location  \
# 14432  http://implora.com/product.asp?jd=Implora%20Bl...      NaN
# 14433  http://www.boneroom.com/store/p4584/Polished_m...      NaN
# 14434  http://implora.com/product.asp?jd=Implora%20Os...      NaN
# 14435  http://www.boneroom.com/store/p3874/Octopus_in...      NaN
# 14436  http://www.ioffer.com/vp/mastermind-x-collabor...      NaN
#
#       domain_country_code domain_country  normalized_price_usd  \
# 14432                 com            NaN                   325
# 14433                 com            NaN                     5
# 14434                 com            NaN                   480
# 14435                 com            NaN                    25
# 14436                 com            NaN                    25
#
#                                               image_path          ResNet50  \
# 14432  /content/drive/MyDrive/Big Data/Project/Data/i...           mailbag
# 14433  /content/drive/MyDrive/Big Data/Project/Data/i...              slug
# 14434  /content/drive/MyDrive/Big Data/Project/Data/i...  bulletproof_vest
# 14435  /content/drive/MyDrive/Big Data/Project/Data/i...            binder
# 14436  /content/drive/MyDrive/Big Data/Project/Data/i...              suit
#
#        VGG16 EfficientNetV2M
# 14432  purse           purse
# 14433  conch           conch
# 14434  cliff            swab
# 14435   iPod          isopod
# 14436  cloak      sweatshirt

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14437 entries, 0 to 14436
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  14437 non-null  object
#  1   title                 14437 non-null  object
#  2   product               14437 non-null  object
#  3   description           14436 non-null  object
#  4   domain                14437 non-null  object
#  5   country               12249 non-null  object
#  6   label_product         14437 non-null  object
#  7   price                 14437 non-null  float64
#  8   currency              14437 non-null  object
#  9   production_date       14 non-null     object
#  10  image                 14436 non-null  object
#  11  url                   14437 non-null  object
#  12  location              4738 non-null   object
#  13  domain_country_code   14437 non-null  object
#  14  domain_country        7590 non-null   object
#  15  normalized_price_usd  14437 non-null  int64
#  16  image_path            14437 non-null  object
#  17  ResNet50              14334 non-null  object
#  18  VGG16                 14334 non-null  object
#  19  EfficientNetV2M       14334 non-null  object
# dtypes: float64(1), int64(1), object(18)
# memory usage: 2.2+ MB

# %% [markdown]
# ## InceptionV3
# InceptionV3, developed by Christian Szegedy and others from Google, was introduced in the paper [“Rethinking the Inception Architecture for Computer Vision”](https://arxiv.org/pdf/1512.00567.pdf). This model is an iteration of the original Inception architecture, also known as GoogleNet, which won the 2014 ImageNet competition. InceptionV3 is known for its innovative use of “modules” within the network, which consist of parallel convolutional layers with different filter sizes, followed by a pooling layer. These modules allow the network to capture information at various scales and complexities.
#
# The InceptionV3 architecture makes improvements over its predecessors by factors like factorizing convolutions into smaller, more manageable operations and by optimizing the network structure for better utilization of computing resources. This model is widely recognized for its balance between accuracy and computational efficiency. It's particularly adept at handling large-scale and complex image recognition tasks.

# %%
df = pd.read_csv('/content/drive/MyDrive/BigData/Project/data/efficientNetV2M.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14437 entries, 0 to 14436
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  14437 non-null  object
#  1   title                 14437 non-null  object
#  2   product               14437 non-null  object
#  3   description           14436 non-null  object
#  4   domain                14437 non-null  object
#  5   country               12249 non-null  object
#  6   label_product         14437 non-null  object
#  7   price                 14437 non-null  float64
#  8   currency              14437 non-null  object
#  9   production_date       14 non-null     object
#  10  image                 14436 non-null  object
#  11  url                   14437 non-null  object
#  12  location              4738 non-null   object
#  13  domain_country_code   14437 non-null  object
#  14  domain_country        7590 non-null   object
#  15  normalized_price_usd  14437 non-null  int64
#  16  image_path            14437 non-null  object
#  17  ResNet50              14334 non-null  object
#  18  VGG16                 14334 non-null  object
#  19  EfficientNetV2M       14334 non-null  object
# dtypes: float64(1), int64(1), object(18)
# memory usage: 2.2+ MB

# %%
df.head(20)
# Out:
#                                                  name  \
# 0   book coin great jaws roy scheider shark signed...
# 1   carabidae cychrini monongahelae ridingsii scap...
# 2   andrewsii carabidae carabinae cychrini germari...
# 3   carabidae form goldengreen irichroa rare scaph...
# 4   calosoma carabidae carabinae lato s sycophanth...
# 5   coin great jaws retro roy s scheider shark sig...
# 6               carabidae carabinae carabus goryi usa
# 7   ad ancient antoninus boar calydonian coin ephe...
# 8   africa animal applique crafts embroidered iron...
# 9   applique diy embroidered ironon me nature patc...
# 10  funny graphic ladies megalodon shark tee tshir...
# 11  animal backpack clothing crocodile embroidered...
# 12  animal backpack clothing embroidered for hyena...
# 13  animal backpack clothing embroidered for irono...
# 14  animal backpack big cat clothing embroidered f...
# 15  animal backpack bear brown clothing embroidere...
# 16  antique coin mongolia mystic oz silver togrog ...
# 17         coin falcon mongolia oz silver togrog wild
# 18  all chrome colors great mirror ocean regular s...
# 19  acrylic amber asian beetle clear insect large ...
#
#                                                 title  \
# 0   book coin great jaws picclick roy scheider sha...
# 1   carabidae cychrini monongahelae picclick ridin...
# 2   andrewsii carabidae carabinae cychrini germari...
# 3   carabidae form goldengreen irichroa picclick r...
# 4   calosoma carabidae carabinae lato picclick s s...
# 5   coin great jaws picclick retro roy s scheider ...
# 6      carabidae carabinae carabus goryi picclick usa
# 7   ad ancient antoninus boar calydonian coin ephe...
# 8   africa animal applique crafts embroidered iron...
# 9   applique diy embroidered ironon me nature patc...
# 10  funny graphic ladies megalodon picclick shark ...
# 11  animal backpack clothing crocodile embroidered...
# 12  animal backpack clothing embroidered for hyena...
# 13  animal backpack clothing embroidered for irono...
# 14  animal backpack big cat clothing embroidered f...
# 15  animal backpack bear brown clothing embroidere...
# 16  antique coin mongolia mystic oz picclick silve...
# 17  coin falcon mongolia oz picclick silver togrog...
# 18  all chrome colors great mirror ocean picclick ...
# 19  acrylic amber asian beetle clear insect large ...
#
#                                               product  \
# 0   book coin great jaws picclick roy scheider sha...
# 1   carabidae cychrini monongahelae picclick ridin...
# 2   andrewsii carabidae carabinae cychrini germari...
# 3   carabidae form goldengreen irichroa picclick r...
# 4   calosoma carabidae carabinae lato picclick s s...
# 5   coin great jaws picclick retro roy s scheider ...
# 6      carabidae carabinae carabus goryi picclick usa
# 7   ad ancient antoninus boar calydonian coin ephe...
# 8   africa animal applique crafts embroidered iron...
# 9   applique diy embroidered ironon me nature patc...
# 10  funny graphic ladies megalodon picclick shark ...
# 11  animal backpack clothing crocodile embroidered...
# 12  animal backpack clothing embroidered for hyena...
# 13  animal backpack clothing embroidered for irono...
# 14  animal backpack big cat clothing embroidered f...
# 15  animal backpack bear brown clothing embroidere...
# 16  antique coin mongolia mystic oz picclick silve...
# 17  coin falcon mongolia oz picclick silver togrog...
# 18  all chrome colors great mirror ocean picclick ...
# 19  acrylic amber asian beetle clear insect large ...
#
#                                           description        domain  \
# 0   a aaron abela ability able aboard about above ...  picclick.com
# 1   a ab abasinus abbreviatus abkhasicus abkhazia ...  picclick.com
# 2   a ab abasinus abbreviatus abkhasicus abkhazia ...  picclick.com
# 3   a ab abasinus abbreviatus abkhasicus abkhazia ...  picclick.com
# 4   a abbreviatus abhazia abkhasicus abkhazia abov...  picclick.com
# 5   a abandoning able aboard about academy accent ...  picclick.com
# 6   a abbreviatus abkhazia above absentivus abyssi...  picclick.com
# 7   a ab abandoned abdicated abdication able about...  picclick.com
# 8   a about absolute abundance acadia accessory ac...  picclick.com
# 9   a about abundance acadia accessory activities ...  picclick.com
# 10  a able about above absolute abundance abundant...  picclick.com
# 11  a about absolute abundance accessory accuracy ...  picclick.com
# 12  a about absolute abundance accessory accuracy ...  picclick.com
# 13  a about absolute abundance accessory accuracy ...  picclick.com
# 14  a about absolute abundance accessory accuracy ...  picclick.com
# 15  a about absolute abundance accessory accuracy ...  picclick.com
# 16  ab aber abergeben abergeht abernimmt aberprafe...  picclick.com
# 17  ab aber abergeben abergeht abernimmt aberprafe...  picclick.com
# 18  a ability able about above abuse abuses abusin...  picclick.com
# 19  a about accept accidentally accordingly acer a...  picclick.com
#
#            country        label_product   price currency production_date  \
# 0   United Kingdom  an animal body part   15.74      USD             NaN
# 1    United States  an animal body part   49.99      USD             NaN
# 2    United States  an animal body part   49.99      USD             NaN
# 3    United States  an animal body part   49.99      USD             NaN
# 4    United States  an animal body part    9.99      USD             NaN
# 5   United Kingdom  an animal body part    2.41      USD             NaN
# 6    United States  an animal body part    5.99      USD             NaN
# 7    United States  an animal body part  100.00      USD             NaN
# 8    United States  an animal body part    4.95      USD             NaN
# 9    United States  an animal body part    5.95      USD             NaN
# 10   United States  an animal body part   14.95      USD             NaN
# 11   United States  an animal body part    5.87      USD             NaN
# 12   United States  an animal body part    5.87      USD             NaN
# 13   United States  an animal body part    5.87      USD             NaN
# 14   United States  an animal body part    5.87      USD             NaN
# 15   United States  an animal body part    6.87      USD             NaN
# 16         Germany  an animal body part  197.99      USD             NaN
# 17         Germany  an animal body part  188.50      USD             NaN
# 18   United States  an animal body part    3.95      USD             NaN
# 19           China  an animal body part   13.00      USD             NaN
#
#                                                 image  \
# 0   https://www.picclickimg.com/ne0AAOSwn4lim49Q/J...
# 1   https://www.picclickimg.com/7rEAAOSwAoNk6CFY/C...
# 2   https://www.picclickimg.com/uTYAAOSwhElk6CMq/C...
# 3   https://www.picclickimg.com/m6IAAOSwZNJk6B~b/C...
# 4   https://www.picclickimg.com/a5QAAOSwVGhiq~Ln/C...
# 5   https://www.picclickimg.com/qk4AAOSwFHJim5AB/J...
# 6   https://www.picclickimg.com/C48AAOSw5bBiKB9l/C...
# 7   https://www.picclickimg.com/ybUAAOSwp5JWVoj0/A...
# 8   https://www.picclickimg.com/htYAAOSwHxdkjFcl/R...
# 9   https://www.picclickimg.com/Yo0AAOSwHudgzeCh/T...
# 10  https://www.picclickimg.com/FVIAAOSwGCNbgYts/m...
# 11  https://www.picclickimg.com/D9QAAOSw~xllAPVY/N...
# 12  https://www.picclickimg.com/xwQAAOSw0c1lAPiu/S...
# 13  https://www.picclickimg.com/8iwAAOSwv41lAPe~/R...
# 14  https://www.picclickimg.com/h~oAAOSwp~llAPp1/L...
# 15  https://www.picclickimg.com/TZ4AAOSwq29lChd8/B...
# 16  https://www.picclickimg.com/~B4AAOSwfN1kHaAU/2...
# 17  https://www.picclickimg.com/8vQAAOSwto1kFzAp/M...
# 18  https://www.picclickimg.com/Qj4AAOSwP~tW6Ne1/S...
# 19  https://www.picclickimg.com/aDEAAOSwl~dhZSzC/I...
#
#                                                   url  \
# 0   http://picclick.com/JAWS-Great-White-Shark-Sil...
# 1   http://picclick.com/Carabidae-Cychrini-Scaphin...
# 2   http://picclick.com/Carabidae-Carabinae-Cychri...
# 3   http://picclick.com/Carabidae-Scaphinotus-Iric...
# 4   http://picclick.com/Carabidae-Carabinae-Caloso...
# 5   https://picclick.com/JAWS-Great-White-Shark-Si...
# 6   http://picclick.com/Carabidae-Carabinae-Carabu...
# 7   http://picclick.com/Antoninus-Pius-138AD-Ephes...
# 8   http://picclick.com/Rhino-Wild-Animal-Zoo-Embr...
# 9   http://picclick.com/Throw-Me-To-The-Wolves-Emb...
# 10  http://picclick.com/megalodon-tshirt-ladies-sh...
# 11  http://picclick.com/Nile-Crocodile-Patch-Embro...
# 12  http://picclick.com/Spotted-Hyena-Patch-Embroi...
# 13  http://picclick.com/Rock-Python-Patch-Embroide...
# 14  http://picclick.com/Leopard-Patch-Embroidered-...
# 15  http://picclick.com/Brown-Bear-Face-Patch-Embr...
# 16  http://picclick.com/Mongolia-2021-500-Togrog-M...
# 17  http://picclick.com/Mongolia-2023-500Togrog-FA...
# 18  http://picclick.com/Sea-Ocean-Great-white-shar...
# 19  http://picclick.com/Insect-Large-Acrylic-Neckl...
#
#                                          location domain_country_code  \
# 0   Manchester, Take a look at my other items, GB                 com
# 1                       Jamison, Pennsylvania, US                 com
# 2                       Jamison, Pennsylvania, US                 com
# 3                       Jamison, Pennsylvania, US                 com
# 4                       Jamison, Pennsylvania, US                 com
# 5               Take a Look at My Other Items, GB                 com
# 6                       Jamison, Pennsylvania, US                 com
# 7                         Rego Park, New York, US                 com
# 8                       Cookeville, Tennessee, US                 com
# 9                       Cookeville, Tennessee, US                 com
# 10                         San Antonio, Texas, US                 com
# 11                      Cookeville, Tennessee, US                 com
# 12                      Cookeville, Tennessee, US                 com
# 13                      Cookeville, Tennessee, US                 com
# 14                      Cookeville, Tennessee, US                 com
# 15                      Cookeville, Tennessee, US                 com
# 16                                     Berlin, DE                 com
# 17                                     Berlin, DE                 com
# 18                       Lafayette, Louisiana, US                 com
# 19                                  Hong Kong, HK                 com
#
#    domain_country  normalized_price_usd  \
# 0             NaN                    16
# 1             NaN                    50
# 2             NaN                    50
# 3             NaN                    50
# 4             NaN                    10
# 5             NaN                     2
# 6             NaN                     6
# 7             NaN                   100
# 8             NaN                     5
# 9             NaN                     6
# 10            NaN                    15
# 11            NaN                     6
# 12            NaN                     6
# 13            NaN                     6
# 14            NaN                     6
# 15            NaN                     7
# 16            NaN                   198
# 17            NaN                   188
# 18            NaN                     4
# 19            NaN                    13
#
#                                            image_path          ResNet50  \
# 0   /content/drive/MyDrive/Big Data/Project/Data/i...              mask
# 1   /content/drive/MyDrive/Big Data/Project/Data/i...     ground_beetle
# 2   /content/drive/MyDrive/Big Data/Project/Data/i...     ground_beetle
# 3   /content/drive/MyDrive/Big Data/Project/Data/i...      tiger_beetle
# 4   /content/drive/MyDrive/Big Data/Project/Data/i...     ground_beetle
# 5   /content/drive/MyDrive/Big Data/Project/Data/i...     jigsaw_puzzle
# 6   /content/drive/MyDrive/Big Data/Project/Data/i...     ground_beetle
# 7   /content/drive/MyDrive/Big Data/Project/Data/i...            buckle
# 8   /content/drive/MyDrive/Big Data/Project/Data/i...           pitcher
# 9   /content/drive/MyDrive/Big Data/Project/Data/i...  magnetic_compass
# 10  /content/drive/MyDrive/Big Data/Project/Data/i...        sunglasses
# 11  /content/drive/MyDrive/Big Data/Project/Data/i...       face_powder
# 12  /content/drive/MyDrive/Big Data/Project/Data/i...       face_powder
# 13  /content/drive/MyDrive/Big Data/Project/Data/i...        sidewinder
# 14  /content/drive/MyDrive/Big Data/Project/Data/i...            buckle
# 15  /content/drive/MyDrive/Big Data/Project/Data/i...            sandal
# 16  /content/drive/MyDrive/Big Data/Project/Data/i...           sundial
# 17  /content/drive/MyDrive/Big Data/Project/Data/i...         spotlight
# 18  /content/drive/MyDrive/Big Data/Project/Data/i...        hammerhead
# 19  /content/drive/MyDrive/Big Data/Project/Data/i...        hair_slide
#
#                VGG16     EfficientNetV2M
# 0          birdhouse   great_white_shark
# 1      ground_beetle       ground_beetle
# 2      ground_beetle       ground_beetle
# 3      ground_beetle       ground_beetle
# 4      ground_beetle       ground_beetle
# 5               coho   great_white_shark
# 6      ground_beetle       ground_beetle
# 7             shield  chambered_nautilus
# 8             buckle         triceratops
# 9   magnetic_compass                puck
# 10       bathing_cap          sunglasses
# 11            buckle              shield
# 12           cheetah              shield
# 13       night_snake        horned_viper
# 14           doormat              jaguar
# 15        brown_bear          brown_bear
# 16          sombrero         timber_wolf
# 17            shield              shield
# 18     motor_scooter         tiger_shark
# 19   cocktail_shaker  long-horned_beetle

# %%
from keras.applications.inception_v3 import InceptionV3, preprocess_input, decode_predictions
from keras.preprocessing import image

# Load the InceptionV3 model
model = InceptionV3(weights='imagenet')

predictions = []

# Loop through the first 10 images
for i in range(10):
    img_path = f'/content/drive/MyDrive/BigData/Project/data/image_{i}.jpg'

    img = image.load_img(img_path, target_size=(299, 299))  # InceptionV3 uses 299x299 input
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)

    preds = model.predict(x)
    decoded_preds = decode_predictions(preds, top=3)[0]

    keywords = [pred[1] for pred in decoded_preds]
    predictions.append(', '.join(keywords))

df.loc[0:9, 'InceptionV3'] = predictions
df.iloc[0:10]
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
#                                                 name  \
# 0  book coin great jaws roy scheider shark signed...
# 1  carabidae cychrini monongahelae ridingsii scap...
# 2  andrewsii carabidae carabinae cychrini germari...
# 3  carabidae form goldengreen irichroa rare scaph...
# 4  calosoma carabidae carabinae lato s sycophanth...
# 5  coin great jaws retro roy s scheider shark sig...
# 6              carabidae carabinae carabus goryi usa
# 7  ad ancient antoninus boar calydonian coin ephe...
# 8  africa animal applique crafts embroidered iron...
# 9  applique diy embroidered ironon me nature patc...
#
#                                                title  \
# 0  book coin great jaws picclick roy scheider sha...
# 1  carabidae cychrini monongahelae picclick ridin...
# 2  andrewsii carabidae carabinae cychrini germari...
# 3  carabidae form goldengreen irichroa picclick r...
# 4  calosoma carabidae carabinae lato picclick s s...
# 5  coin great jaws picclick retro roy s scheider ...
# 6     carabidae carabinae carabus goryi picclick usa
# 7  ad ancient antoninus boar calydonian coin ephe...
# 8  africa animal applique crafts embroidered iron...
# 9  applique diy embroidered ironon me nature patc...
#
#                                              product  \
# 0  book coin great jaws picclick roy scheider sha...
# 1  carabidae cychrini monongahelae picclick ridin...
# 2  andrewsii carabidae carabinae cychrini germari...
# 3  carabidae form goldengreen irichroa picclick r...
# 4  calosoma carabidae carabinae lato picclick s s...
# 5  coin great jaws picclick retro roy s scheider ...
# 6     carabidae carabinae carabus goryi picclick usa
# 7  ad ancient antoninus boar calydonian coin ephe...
# 8  africa animal applique crafts embroidered iron...
# 9  applique diy embroidered ironon me nature patc...
#
#                                          description        domain  \
# 0  a aaron abela ability able aboard about above ...  picclick.com
# 1  a ab abasinus abbreviatus abkhasicus abkhazia ...  picclick.com
# 2  a ab abasinus abbreviatus abkhasicus abkhazia ...  picclick.com
# 3  a ab abasinus abbreviatus abkhasicus abkhazia ...  picclick.com
# 4  a abbreviatus abhazia abkhasicus abkhazia abov...  picclick.com
# 5  a abandoning able aboard about academy accent ...  picclick.com
# 6  a abbreviatus abkhazia above absentivus abyssi...  picclick.com
# 7  a ab abandoned abdicated abdication able about...  picclick.com
# 8  a about absolute abundance acadia accessory ac...  picclick.com
# 9  a about abundance acadia accessory activities ...  picclick.com
#
#           country        label_product   price currency production_date  ...  \
# 0  United Kingdom  an animal body part   15.74      USD             NaN  ...
# 1   United States  an animal body part   49.99      USD             NaN  ...
# 2   United States  an animal body part   49.99      USD             NaN  ...
# 3   United States  an animal body part   49.99      USD             NaN  ...
# 4   United States  an animal body part    9.99      USD             NaN  ...
# 5  United Kingdom  an animal body part    2.41      USD             NaN  ...
# 6   United States  an animal body part    5.99      USD             NaN  ...
# 7   United States  an animal body part  100.00      USD             NaN  ...
# 8   United States  an animal body part    4.95      USD             NaN  ...
# 9   United States  an animal body part    5.95      USD             NaN  ...
#
#                                                  url  \
# 0  http://picclick.com/JAWS-Great-White-Shark-Sil...
# 1  http://picclick.com/Carabidae-Cychrini-Scaphin...
# 2  http://picclick.com/Carabidae-Carabinae-Cychri...
# 3  http://picclick.com/Carabidae-Scaphinotus-Iric...
# 4  http://picclick.com/Carabidae-Carabinae-Caloso...
# 5  https://picclick.com/JAWS-Great-White-Shark-Si...
# 6  http://picclick.com/Carabidae-Carabinae-Carabu...
# 7  http://picclick.com/Antoninus-Pius-138AD-Ephes...
# 8  http://picclick.com/Rhino-Wild-Animal-Zoo-Embr...
# 9  http://picclick.com/Throw-Me-To-The-Wolves-Emb...
#
#                                         location domain_country_code  \
# 0  Manchester, Take a look at my other items, GB                 com
# 1                      Jamison, Pennsylvania, US                 com
# 2                      Jamison, Pennsylvania, US                 com
# 3                      Jamison, Pennsylvania, US                 com
# 4                      Jamison, Pennsylvania, US                 com
# 5              Take a Look at My Other Items, GB                 com
# 6                      Jamison, Pennsylvania, US                 com
# 7                        Rego Park, New York, US                 com
# 8                      Cookeville, Tennessee, US                 com
# 9                      Cookeville, Tennessee, US                 com
#
#   domain_country normalized_price_usd  \
# 0            NaN                   16
# 1            NaN                   50
# 2            NaN                   50
# 3            NaN                   50
# 4            NaN                   10
# 5            NaN                    2
# 6            NaN                    6
# 7            NaN                  100
# 8            NaN                    5
# 9            NaN                    6
#
#                                           image_path          ResNet50  \
# 0  /content/drive/MyDrive/Big Data/Project/Data/i...              mask
# 1  /content/drive/MyDrive/Big Data/Project/Data/i...     ground_beetle
# 2  /content/drive/MyDrive/Big Data/Project/Data/i...     ground_beetle
# 3  /content/drive/MyDrive/Big Data/Project/Data/i...      tiger_beetle
# 4  /content/drive/MyDrive/Big Data/Project/Data/i...     ground_beetle
# 5  /content/drive/MyDrive/Big Data/Project/Data/i...     jigsaw_puzzle
# 6  /content/drive/MyDrive/Big Data/Project/Data/i...     ground_beetle
# 7  /content/drive/MyDrive/Big Data/Project/Data/i...            buckle
# 8  /content/drive/MyDrive/Big Data/Project/Data/i...           pitcher
# 9  /content/drive/MyDrive/Big Data/Project/Data/i...  magnetic_compass
#
#               VGG16     EfficientNetV2M  \
# 0         birdhouse   great_white_shark
# 1     ground_beetle       ground_beetle
# 2     ground_beetle       ground_beetle
# 3     ground_beetle       ground_beetle
# 4     ground_beetle       ground_beetle
# 5              coho   great_white_shark
# 6     ground_beetle       ground_beetle
# 7            shield  chambered_nautilus
# 8            buckle         triceratops
# 9  magnetic_compass                puck
#
#                                          InceptionV3
# 0             great_white_shark, packet, tiger_shark
# 1            ground_beetle, dung_beetle, water_tower
# 2           ground_beetle, tiger_beetle, dung_beetle
# 3           ground_beetle, tiger_beetle, dung_beetle
# 4           ground_beetle, tiger_beetle, dung_beetle
# 5       comic_book, killer_whale, leatherback_turtle
# 6           ground_beetle, tiger_beetle, dung_beetle
# 7  chambered_nautilus, hen-of-the-woods, brain_coral
# 8                  buckle, jigsaw_puzzle, hair_slide
# 9                      puck, face_powder, wall_clock
#
# [10 rows x 21 columns]

# %%
df['InceptionV3'].iloc[0:10]
# Out:
# 0               great_white_shark, packet, tiger_shark
# 1              ground_beetle, dung_beetle, water_tower
# 2             ground_beetle, tiger_beetle, dung_beetle
# 3             ground_beetle, tiger_beetle, dung_beetle
# 4             ground_beetle, tiger_beetle, dung_beetle
# 5         comic_book, killer_whale, leatherback_turtle
# 6             ground_beetle, tiger_beetle, dung_beetle
# 7    chambered_nautilus, hen-of-the-woods, brain_coral
# 8                    buckle, jigsaw_puzzle, hair_slide
# 9                        puck, face_powder, wall_clock
# Name: InceptionV3, dtype: object

# %%
# BATCH & GPU: 3min 17s
# %%time

from keras.preprocessing import image
from keras.applications.inception_v3 import InceptionV3, preprocess_input, decode_predictions

# Load the InceptionV3 model
model = InceptionV3(weights='imagenet')

def predict_batch(paths, model):
    imgs_array = []
    for img_path in paths:
        try:
            img = image.load_img(img_path, target_size=(299, 299))
            x = image.img_to_array(img)
            imgs_array.append(x)
        except Exception as e:
            print(f"Error processing image at path {img_path}: {e}")
            continue
    if len(imgs_array) == 0:  # Check if all images in the batch failed
        return [np.nan] * len(paths)
    imgs_array = np.array(imgs_array)
    imgs_array = preprocess_input(imgs_array)

    try:
        preds = model.predict(imgs_array)
        decoded = decode_predictions(preds, top=1)
        top_preds = [pred[0][1] if len(pred) > 0 else np.nan for pred in decoded]
        return top_preds
    except Exception as e:
        print(f"Error during prediction: {e}")
        return [np.nan] * len(paths)

# Batch processing
batch_size = 32
df['InceptionV3'] = np.nan

for i in range(0, len(df), batch_size):
    batch_paths = [f'/content/drive/MyDrive/BigData/Project/data/image_{j}.jpg' for j in range(i, min(i + batch_size, len(df)))]
    batch_preds = predict_batch(batch_paths, model)
    df.loc[i:i+len(batch_preds)-1, 'InceptionV3'] = batch_preds

df.to_csv('/content/drive/MyDrive/BigData/Project/data/inceptionv3.csv', index=False)
df.tail()
# Out:
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 53ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_411.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_411.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_412.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_412.jpg'
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 53ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_2409.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_2409.jpg'
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 39ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_2557.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_2557.jpg'
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 51ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_2686.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_2686.jpg'
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 61ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_2731.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_2731.jpg'
# 1/1 [==============================] - 0s 55ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_2759.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_2759.jpg'
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 52ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_3212.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_3212.jpg'
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_3379.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_3379.jpg'
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 42ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_3484.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_3484.jpg'
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 41ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_3898.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_3898.jpg'
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 64ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_4514.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_4514.jpg'
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 57ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_4948.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_4948.jpg'
# 1/1 [==============================] - 0s 66ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_4983.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_4983.jpg'
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 56ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_5032.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_5032.jpg'
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_5722.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_5722.jpg'
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_7048.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_7048.jpg'
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_7198.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_7198.jpg'
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 41ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_7365.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_7365.jpg'
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 70ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_7708.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_7708.jpg'
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 72ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_8752.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_8752.jpg'
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 39ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_9577.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_9577.jpg'
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 50ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_10453.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_10453.jpg'
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_10783.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_10783.jpg'
# 1/1 [==============================] - 0s 44ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_10813.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_10813.jpg'
# 1/1 [==============================] - 0s 58ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_10819.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_10819.jpg'
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 41ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_10955.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_10955.jpg'
# 1/1 [==============================] - 0s 44ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_10993.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_10993.jpg'
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 53ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_11194.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_11194.jpg'
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 55ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_11562.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_11562.jpg'
# 1/1 [==============================] - 0s 41ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_11600.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_11600.jpg'
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 54ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_11844.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_11844.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_11871.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_11871.jpg'
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 44ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_12204.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_12204.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_12221.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_12221.jpg'
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 49ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_13364.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_13364.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_13366.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_13366.jpg'
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 55ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_13705.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_13705.jpg'
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_13874.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_13874.jpg'
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14051.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14051.jpg'
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 71ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14118.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14118.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14137.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14137.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14143.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14143.jpg'
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 42ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14189.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14189.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14194.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14194.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14197.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14197.jpg'
# 1/1 [==============================] - 0s 40ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14211.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14211.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14213.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14213.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14218.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14218.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14219.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14219.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14227.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14227.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14236.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14236.jpg'
# 1/1 [==============================] - 2s 2s/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14245.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14245.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14246.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14246.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14254.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14254.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14255.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14255.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14256.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14256.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14257.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14257.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14258.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14258.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14259.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14259.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14267.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14267.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14271.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14271.jpg'
# 1/1 [==============================] - 2s 2s/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14274.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14274.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14275.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14275.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14279.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14279.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14280.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14280.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14281.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14281.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14282.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14282.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14283.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14283.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14284.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14284.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14302.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14302.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14303.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14303.jpg'
# 1/1 [==============================] - 0s 42ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14304.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14304.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14305.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14305.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14306.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14306.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14307.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14307.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14312.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14312.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14313.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14313.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14314.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14314.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14320.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14320.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14321.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14321.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14322.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14322.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14330.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14330.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14331.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14331.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14332.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14332.jpg'
# 1/1 [==============================] - 2s 2s/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14337.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14337.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14352.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14352.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14355.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14355.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14356.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14356.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14357.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14357.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14358.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14358.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14359.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14359.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14360.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14360.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14361.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14361.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14367.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14367.jpg'
# 1/1 [==============================] - 0s 52ms/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14368.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14368.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14379.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14379.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14382.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14382.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14389.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14389.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14390.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14390.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14393.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14393.jpg'
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14394.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14394.jpg'
# 1/1 [==============================] - 2s 2s/step
# Error processing image at path /content/drive/MyDrive/Big Data/Project/Data/image_14400.jpg: [Errno 2] No such file or directory: '/content/drive/MyDrive/Big Data/Project/Data/image_14400.jpg'
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 1s 1s/step
# CPU times: user 2min 30s, sys: 17.6 s, total: 2min 48s
# Wall time: 3min 17s
#                                               name  \
# 14432  bag black braided cobra implora skin tassel
# 14433                from mussel polished thailand
# 14434               black implora ostrich skin xin
# 14435                            in lucite octopus
# 14436            accurate description great seller
#
#                                                    title  \
# 14432  bags christmas cobra free genuine natural ship...
# 14433                      from mussel polished thailand
# 14434  black christmas free genuine hides leather lea...
# 14435                                  in lucite octopus
# 14436  black collaboration hoodie mastermind shark sk...
#
#                                                  product description  \
# 14432  bags christmas cobra free genuine natural ship...        size
# 14433                      from mussel polished thailand        each
# 14434  black christmas free genuine hides leather lea...           h
# 14435                                  in lucite octopus           x
# 14436  black collaboration hoodie mastermind shark sk...         NaN
#
#              domain country        label_product   price currency  \
# 14432   implora.com     NaN  an animal body part  325.00      USD
# 14433  boneroom.com     NaN  an animal body part    5.00      USD
# 14434   implora.com     NaN  an animal body part  480.00      USD
# 14435  boneroom.com     NaN  an animal body part   25.00      USD
# 14436    ioffer.com     NaN  an animal body part   24.99      USD
#
#       production_date  ...                                                url  \
# 14432             NaN  ...  http://implora.com/product.asp?jd=Implora%20Bl...
# 14433             NaN  ...  http://www.boneroom.com/store/p4584/Polished_m...
# 14434             NaN  ...  http://implora.com/product.asp?jd=Implora%20Os...
# 14435             NaN  ...  http://www.boneroom.com/store/p3874/Octopus_in...
# 14436             NaN  ...  http://www.ioffer.com/vp/mastermind-x-collabor...
#
#       location domain_country_code domain_country normalized_price_usd  \
# 14432      NaN                 com            NaN                  325
# 14433      NaN                 com            NaN                    5
# 14434      NaN                 com            NaN                  480
# 14435      NaN                 com            NaN                   25
# 14436      NaN                 com            NaN                   25
#
#                                               image_path          ResNet50  \
# 14432  /content/drive/MyDrive/Big Data/Project/Data/i...           mailbag
# 14433  /content/drive/MyDrive/Big Data/Project/Data/i...              slug
# 14434  /content/drive/MyDrive/Big Data/Project/Data/i...  bulletproof_vest
# 14435  /content/drive/MyDrive/Big Data/Project/Data/i...            binder
# 14436  /content/drive/MyDrive/Big Data/Project/Data/i...              suit
#
#        VGG16 EfficientNetV2M       InceptionV3
# 14432  purse           purse           mailbag
# 14433  conch           conch             conch
# 14434  cliff            swab  bulletproof_vest
# 14435   iPod          isopod              rule
# 14436  cloak      sweatshirt        sweatshirt
#
# [5 rows x 21 columns]

# %% [markdown]
# # Comparison of Deep Learning Models
#
# The ImageNet dataset is one of the most widely used datasets for training deep learning models in image recognition tasks, providing a diverse range of images.
#
# Each of the models — ResNet50, VGG16, EfficientNetV2M, and InceptionV3 — were typically trained on the ImageNet dataset,
#
# - **ResNet50**: Trained on the ImageNet database, which contains over 14 million images categorized into more than 20,000 categories. It was part of the model's success in the ILSVRC (ImageNet Large Scale Visual Recognition Challenge).
#
# - **VGG16**: Also trained on the ImageNet dataset. The VGG16 model was one of the top performers in the 2014 ILSVRC competition, mainly due to its deep architecture trained on this extensive and varied dataset.
#
# - **EfficientNetV2M**: The EfficientNet models, including the V2 series, were trained on ImageNet. The EfficientNetV2 models introduced additional improvements and optimizations, but they continued to leverage the ImageNet dataset for training, which provides a broad and challenging range of image recognition tasks.
#
# - **InceptionV3**: Like the others, InceptionV3 was trained on the ImageNet dataset. Its unique architecture was particularly well-suited to the diverse and complex images found in this dataset, allowing it to achieve high accuracy in classification tasks.

# %%
df = pd.read_csv('/content/drive/MyDrive/BigData/Project/data/inceptionv3.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14437 entries, 0 to 14436
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  14437 non-null  object
#  1   title                 14437 non-null  object
#  2   product               14437 non-null  object
#  3   description           14436 non-null  object
#  4   domain                14437 non-null  object
#  5   country               12249 non-null  object
#  6   label_product         14437 non-null  object
#  7   price                 14437 non-null  float64
#  8   currency              14437 non-null  object
#  9   production_date       14 non-null     object
#  10  image                 14436 non-null  object
#  11  url                   14437 non-null  object
#  12  location              4738 non-null   object
#  13  domain_country_code   14437 non-null  object
#  14  domain_country        7590 non-null   object
#  15  normalized_price_usd  14437 non-null  int64
#  16  image_path            14437 non-null  object
#  17  ResNet50              14334 non-null  object
#  18  VGG16                 14334 non-null  object
#  19  EfficientNetV2M       14334 non-null  object
#  20  InceptionV3           14334 non-null  object
# dtypes: float64(1), int64(1), object(19)
# memory usage: 2.3+ MB

# %%
df.head()
# Out:
#                                                 name  \
# 0  book coin great jaws roy scheider shark signed...
# 1  carabidae cychrini monongahelae ridingsii scap...
# 2  andrewsii carabidae carabinae cychrini germari...
# 3  carabidae form goldengreen irichroa rare scaph...
# 4  calosoma carabidae carabinae lato s sycophanth...
#
#                                                title  \
# 0  book coin great jaws picclick roy scheider sha...
# 1  carabidae cychrini monongahelae picclick ridin...
# 2  andrewsii carabidae carabinae cychrini germari...
# 3  carabidae form goldengreen irichroa picclick r...
# 4  calosoma carabidae carabinae lato picclick s s...
#
#                                              product  \
# 0  book coin great jaws picclick roy scheider sha...
# 1  carabidae cychrini monongahelae picclick ridin...
# 2  andrewsii carabidae carabinae cychrini germari...
# 3  carabidae form goldengreen irichroa picclick r...
# 4  calosoma carabidae carabinae lato picclick s s...
#
#                                          description        domain  \
# 0  a aaron abela ability able aboard about above ...  picclick.com
# 1  a ab abasinus abbreviatus abkhasicus abkhazia ...  picclick.com
# 2  a ab abasinus abbreviatus abkhasicus abkhazia ...  picclick.com
# 3  a ab abasinus abbreviatus abkhasicus abkhazia ...  picclick.com
# 4  a abbreviatus abhazia abkhasicus abkhazia abov...  picclick.com
#
#           country        label_product  price currency production_date  ...  \
# 0  United Kingdom  an animal body part  15.74      USD             NaN  ...
# 1   United States  an animal body part  49.99      USD             NaN  ...
# 2   United States  an animal body part  49.99      USD             NaN  ...
# 3   United States  an animal body part  49.99      USD             NaN  ...
# 4   United States  an animal body part   9.99      USD             NaN  ...
#
#                                                  url  \
# 0  http://picclick.com/JAWS-Great-White-Shark-Sil...
# 1  http://picclick.com/Carabidae-Cychrini-Scaphin...
# 2  http://picclick.com/Carabidae-Carabinae-Cychri...
# 3  http://picclick.com/Carabidae-Scaphinotus-Iric...
# 4  http://picclick.com/Carabidae-Carabinae-Caloso...
#
#                                         location domain_country_code  \
# 0  Manchester, Take a look at my other items, GB                 com
# 1                      Jamison, Pennsylvania, US                 com
# 2                      Jamison, Pennsylvania, US                 com
# 3                      Jamison, Pennsylvania, US                 com
# 4                      Jamison, Pennsylvania, US                 com
#
#   domain_country normalized_price_usd  \
# 0            NaN                   16
# 1            NaN                   50
# 2            NaN                   50
# 3            NaN                   50
# 4            NaN                   10
#
#                                           image_path       ResNet50  \
# 0  /content/drive/MyDrive/Big Data/Project/Data/i...           mask
# 1  /content/drive/MyDrive/Big Data/Project/Data/i...  ground_beetle
# 2  /content/drive/MyDrive/Big Data/Project/Data/i...  ground_beetle
# 3  /content/drive/MyDrive/Big Data/Project/Data/i...   tiger_beetle
# 4  /content/drive/MyDrive/Big Data/Project/Data/i...  ground_beetle
#
#            VGG16    EfficientNetV2M        InceptionV3
# 0      birdhouse  great_white_shark  great_white_shark
# 1  ground_beetle      ground_beetle      ground_beetle
# 2  ground_beetle      ground_beetle      ground_beetle
# 3  ground_beetle      ground_beetle      ground_beetle
# 4  ground_beetle      ground_beetle      ground_beetle
#
# [5 rows x 21 columns]

# %%
df = df[['ResNet50', 'VGG16', 'EfficientNetV2M', 'InceptionV3']]
df.head()
# Out:
#         ResNet50          VGG16    EfficientNetV2M        InceptionV3
# 0           mask      birdhouse  great_white_shark  great_white_shark
# 1  ground_beetle  ground_beetle      ground_beetle      ground_beetle
# 2  ground_beetle  ground_beetle      ground_beetle      ground_beetle
# 3   tiger_beetle  ground_beetle      ground_beetle      ground_beetle
# 4  ground_beetle  ground_beetle      ground_beetle      ground_beetle

# %% [markdown]
# ## Check the NULL entries

# %%
# Count the number of NaN (NULL) entries
num_null_resnet = df['ResNet50'].isna().sum()
num_null_vgg = df['VGG16'].isna().sum()
num_null_efficient = df['EfficientNetV2M'].isna().sum()
num_null_inception = df['InceptionV3'].isna().sum()


print("Number of NULL entries in 'ResNet50':", num_null_resnet)
print("Number of NULL entries in 'VGG16':", num_null_vgg)
print("Number of NULL entries in 'EfficientNetV2M':", num_null_efficient)
print("Number of NULL entries in 'InceptionV3':", num_null_inception)
# Out:
# Number of NULL entries in 'ResNet50': 103
# Number of NULL entries in 'VGG16': 103
# Number of NULL entries in 'EfficientNetV2M': 103
# Number of NULL entries in 'InceptionV3': 103

# %% [markdown]
# ## Pre-processing Terms
# When we examine the unique items in the column (in this case, 'ResNet50'), we notice that when a term consists of more than two words, these words are connected with an underscore '_'.
#
# Since our goal is to identify animal species, we will extract the last word in multi-word terms like 'great_white_shark' (in this case, 'shark') and replace the underscores with spaces.

# %%
df['ResNet50'].unique()
# Out:
# array(['mask', 'ground_beetle', 'tiger_beetle', 'jigsaw_puzzle', 'buckle',
#        'pitcher', 'magnetic_compass', 'sunglasses', 'face_powder',
#        'sidewinder', 'sandal', 'sundial', 'spotlight', 'hammerhead',
#        'hair_slide', 'ibex', 'bolo_tie', 'black_widow', 'quill', 'vase',
#        'conch', 'pillow', 'rhinoceros_beetle', 'purse', 'chiffonier',
#        'pedestal', 'stove', 'cowboy_boot', 'wallet', 'padlock',
#        'oil_filter', 'washbasin', 'speedboat', 'baseball', 'book_jacket',
#        'Loafer', 'soap_dispenser', 'hook', 'great_white_shark',
#        'tiger_shark', 'iron', 'banded_gecko', 'ladybug', 'screw',
#        'envelope', 'necklace', 'binder', 'shoji', 'barn_spider',
#        'ping-pong_ball', 'chain_mail', 'Afghan_hound', 'coffeepot',
#        'web_site', 'eft', 'cockroach', 'German_shepherd',
#        'standard_schnauzer', 'keeshond', 'scorpion', 'ski', 'whistle',
#        'timber_wolf', 'dung_beetle', 'packet', 'can_opener', 'tick',
#        'safety_pin', 'triceratops', 'dalmatian', 'gar', 'perfume',
#        'Siamese_cat', 'thunder_snake', 'coil', 'medicine_chest',
#        'fire_screen', 'pick', 'leaf_beetle', 'hammer', 'oxygen_mask',
#        'coho', 'vizsla', 'pencil_sharpener', 'nematode', 'holster',
#        'maillot', 'shield', 'neck_brace', 'chain', 'diaper', 'rotisserie',
#        'knot', 'ant', 'sea_lion', 'bow', 'pretzel', 'bathtub', 'modem',
#        'African_chameleon', 'jersey', 'dial_telephone',
#        'combination_lock', 'hermit_crab', 'microphone', 'ringlet',
#        'electric_ray', 'fur_coat', 'basenji', 'television',
#        'sea_cucumber', 'stupa', 'megalith', 'mushroom', 'trilobite',
#        'pickelhaube', 'malamute', 'wolf_spider', 'shovel',
#        'academic_gown', 'window_screen', 'table_lamp', 'ostrich',
#        'thimble', 'letter_opener', 'hand_blower', 'lipstick', 'carton',
#        'brown_bear', 'kuvasz', 'tailed_frog', 'corkscrew', 'handkerchief',
#        'lycaenid', 'bald_eagle', 'coyote', 'French_loaf', 'cash_machine',
#        'slot', 'American_alligator', 'tray', 'Petri_dish', 'screwdriver',
#        'feather_boa', 'reel', 'frilled_lizard', 'wool', 'warplane',
#        'scabbard', 'gong', 'bookshop', 'rule', 'Norwegian_elkhound',
#        'cowboy_hat', 'barracouta', nan, 'beer_bottle', 'spindle',
#        'Band_Aid', 'folding_chair', 'chest', 'paddle', 'pencil_box',
#        'broom', 'pot', 'iPod', 'analog_clock', 'acorn', 'clog', 'flute',
#        'jeep', 'king_snake', 'knee_pad', 'bonnet', 'balloon', 'ocarina',
#        'stole', 'ski_mask', 'miniskirt', 'jean', 'ballpoint',
#        'hen-of-the-woods', 'Chihuahua', 'bolete', 'caldron', 'slug',
#        'Great_Dane', 'snail', 'honeycomb', 'breastplate', 'warthog',
#        'puck', 'goldfish', 'fiddler_crab', 'apron', 'night_snake',
#        'Eskimo_dog', 'terrapin', 'Christmas_stocking', 'Maltese_dog',
#        'lighter', 'goblet', 'coral_reef', 'space_shuttle', 'white_wolf',
#        'sunglass', 'papillon', 'oscilloscope', 'hatchet',
#        'shower_curtain', 'backpack', 'rubber_eraser', 'Arabian_camel',
#        'car_mirror', 'recreational_vehicle', 'horned_viper',
#        'African_crocodile', 'sports_car', 'water_buffalo', 'jaguar',
#        'starfish', 'punching_bag', 'crayfish', 'limpkin', 'dough',
#        'oystercatcher', 'cougar', 'comic_book', 'mailbag', 'paintbrush',
#        'redshank', 'chocolate_sauce', 'nail', 'wardrobe', 'hair_spray',
#        'isopod', 'parachute', 'drum', 'loupe', 'safe', 'toilet_seat',
#        'lotion', 'leafhopper', 'coffee_mug', 'crash_helmet', 'piggy_bank',
#        'tennis_ball', 'sea_urchin', 'brass', 'lacewing', 'lionfish',
#        'lampshade', 'dishrag', 'harvestman', 'buckeye', 'picket_fence',
#        'dowitcher', 'strainer', 'hog', 'cup', 'switch', 'pug', 'tripod',
#        'albatross', 'gyromitra', 'Scotch_terrier', 'doormat',
#        'red-breasted_merganser', 'Lakeland_terrier', 'great_grey_owl',
#        'ballplayer', 'dumbbell', 'mitten', 'grey_fox', 'prayer_rug',
#        'macaw', 'airship', 'boxer', 'plate', 'wooden_spoon', 'seat_belt',
#        'confectionery', 'studio_couch', 'acoustic_guitar', 'vulture',
#        'teddy', 'velvet', 'hamper', 'schooner', 'toilet_tissue', 'radio',
#        'overskirt', 'Brittany_spaniel', 'English_foxhound', 'barrow',
#        'giant_panda', 'platypus', 'white_stork', 'llama', 'scale',
#        'church', 'refrigerator', 'tiger', 'shower_cap', 'banana',
#        'electric_guitar', 'lorikeet', 'hotdog', 'convertible', 'seashore',
#        'long-horned_beetle', 'stingray', 'hen', 'sweatshirt', 'rock_crab',
#        'maraca', 'hippopotamus', 'pill_bottle', 'lakeside',
#        'Irish_setter', 'Staffordshire_bullterrier', 'zebra', 'gown',
#        'ruffed_grouse', 'dining_table', 'cardigan', 'groenendael', 'tub',
#        'rock_beauty', 'rocking_chair', 'orangutan', 'alp', 'minivan',
#        'cock', 'hard_disc', 'Pomeranian', 'brassiere', 'mongoose',
#        'altar', 'menu', 'plastic_bag', 'nipple', 'poncho', 'paper_towel',
#        'cradle', 'vestment', 'porcupine', 'fountain_pen', 'swab',
#        'kimono', 'prairie_chicken', 'schipperke', 'grille',
#        'crossword_puzzle', 'saltshaker', 'violin', 'Indian_cobra',
#        'cricket', 'cheetah', 'jellyfish', 'killer_whale', 'Weimaraner',
#        'bulletproof_vest', 'eggnog', 'American_chameleon', 'ice_bear',
#        'beaker', 'Komodo_dragon', 'goose', 'green_mamba',
#        'ringneck_snake', 'digital_watch', 'park_bench', 'shopping_basket',
#        'sarong', 'amphibian', 'harmonica', 'stretcher', 'hummingbird',
#        'chambered_nautilus', 'candle', 'plane', 'weevil',
#        'swimming_trunks', 'home_theater', 'bison', 'peacock', 'cassette',
#        'hartebeest', 'patio', 'leatherback_turtle', 'wig',
#        'Rhodesian_ridgeback', 'Granny_Smith', 'bib', 'Brabancon_griffon',
#        'Airedale', 'bakery', 'stinkhorn', 'chiton', 'wall_clock',
#        'running_shoe', 'malinois', 'groom', 'abaya', 'red_wine',
#        'African_grey', 'grey_whale', 'polecat', 'ladle', 'Irish_terrier',
#        'tree_frog', 'bath_towel', 'guillotine', 'cliff', 'Angora',
#        'dhole', 'Egyptian_cat', 'sombrero', 'Dungeness_crab', 'centipede',
#        'water_ouzel', 'mantis', 'common_iguana', 'agama', 'matchstick',
#        'mousetrap', 'pomegranate', 'lion', 'mortar', 'coral_fungus',
#        'king_penguin', 'crane', 'oxcart', 'Polaroid_camera',
#        'grasshopper', 'Samoyed', 'lynx', 'vacuum', 'marmot', 'monitor',
#        'joystick', 'mouse', 'trench_coat', 'quail', 'earthstar',
#        'Indian_elephant', 'green_lizard', 'bell_pepper', 'street_sign',
#        'pole', 'cardoon', 'alligator_lizard', 'sleeping_bag',
#        'Persian_cat', 'spider_web', 'king_crab', 'gazelle', 'hourglass',
#        'vending_machine', 'gas_pump', 'geyser', 'suit', 'rifle', 'pajama',
#        'microwave', 'English_setter', 'bucket', 'armadillo', 'muzzle',
#        'umbrella', 'sock', 'washer', 'cleaver', 'meat_loaf',
#        'rain_barrel', 'shoe_shop', 'greenhouse', 'tabby', 'four-poster',
#        'red_wolf', 'cuirass', 'colobus', 'ear', 'bullfrog', 'snorkel',
#        'damselfly', 'ashcan', 'ram', 'cocktail_shaker', 'radio_telescope',
#        'plate_rack', 'eel', 'bubble', 'pool_table', 'stopwatch', 'crate',
#        'fox_squirrel', 'toyshop', 'bow_tie', 'cabbage_butterfly',
#        'trombone', 'pinwheel', 'notebook', 'cicada', "carpenter's_kit",
#        'CD_player', 'harp', 'bearskin', 'Boston_bull', 'pay-phone',
#        'standard_poodle', 'bottlecap', 'hand-held_computer',
#        'hognose_snake', 'printer', 'bulbul', 'tarantula', 'breakwater',
#        'swing', 'fly', 'loggerhead', 'ox', 'echidna', 'barber_chair',
#        'Bedlington_terrier', 'cloak', 'impala', 'wallaby', 'abacus',
#        'disk_brake', 'lab_coat', 'lemon', 'mountain_bike',
#        'soft-coated_wheaten_terrier', 'screen', 'totem_pole', 'moped',
#        'Ibizan_hound', 'projectile', 'head_cabbage', 'loudspeaker',
#        'bloodhound', 'Saint_Bernard', 'fountain', 'syringe', 'barn',
#        'dogsled', 'flamingo', 'common_newt', 'bookcase', 'canoe',
#        'miniature_schnauzer', 'Norwich_terrier', 'American_black_bear',
#        'mailbox', 'water_bottle', 'plunger', 'box_turtle', 'submarine',
#        'quilt', 'digital_clock', 'komondor', 'meerkat', 'Windsor_tie',
#        'espresso_maker', 'Tibetan_mastiff', 'chain_saw',
#        'cellular_telephone', 'Arctic_fox', 'Siberian_husky', 'toaster',
#        'toy_poodle', 'banjo', 'sorrel', 'spatula', 'scoreboard',
#        'bull_mastiff', 'aircraft_carrier', 'hamster', 'lawn_mower',
#        'corn', 'Pembroke', 'cucumber', 'tractor', 'sturgeon', 'sandbar',
#        'obelisk', 'basset', 'black-footed_ferret', 'cab',
#        'military_uniform', 'bicycle-built-for-two', 'bikini',
#        'sliding_door', 'puffer', 'rapeseed', 'stethoscope', 'guinea_pig',
#        'worm_fence', 'panpipe', 'waffle_iron', 'forklift', 'window_shade',
#        'barometer', 'ice_cream', 'cinema', 'cocker_spaniel', 'beagle',
#        'golden_retriever', 'goldfinch', 'space_heater', 'cauliflower',
#        'birdhouse', 'mixing_bowl', 'American_lobster', 'strawberry',
#        'barbell', 'gasmask', 'binoculars', 'Blenheim_spaniel', 'gondola',
#        'Kerry_blue_terrier', 'barbershop', 'tobacco_shop', 'barrel',
#        'tank', 'photocopier', 'balance_beam', 'projector', 'wombat',
#        'hare', 'reflex_camera', 'daisy', 'throne', 'crutch', 'revolver',
#        'chow', 'tile_roof', 'fig', 'racer', 'otter', 'electric_fan',
#        'Gila_monster', 'half_track', 'African_elephant', 'manhole_cover',
#        'assault_rifle', 'slide_rule', 'sewing_machine', 'golf_ball',
#        'entertainment_center', 'Bouvier_des_Flandres', 'pop_bottle',
#        'Saluki', 'croquet_ball', 'dock', 'sunscreen', 'rugby_ball',
#        'Scottish_deerhound', 'drumstick', 'tench', 'parking_meter',
#        'skunk', 'desk', 'mosquito_net', 'limousine', 'tricycle', 'plow',
#        'Dutch_oven', 'vine_snake', 'walking_stick', 'English_springer',
#        'soup_bowl', 'wing', 'snowmobile', 'cello', 'power_drill',
#        'gorilla', 'espresso', 'butcher_shop', 'castle', 'bathing_cap',
#        'badger', 'remote_control', 'volcano', 'Irish_wolfhound',
#        'bassinet', 'golfcart', 'Labrador_retriever', 'weasel',
#        'Bernese_mountain_dog', 'flatworm', 'radiator', 'hoopskirt',
#        'affenpinscher', 'custard_apple', 'scuba_diver', 'axolotl',
#        'chime', 'palace', 'wreck', 'trimaran', 'proboscis_monkey',
#        'water_jug', 'koala', 'desktop_computer', 'bee', 'robin',
#        'computer_keyboard', 'Great_Pyrenees', 'snow_leopard',
#        'parallel_bars', 'spiny_lobster', 'ice_lolly', 'maze',
#        'French_bulldog', 'kelpie', 'ptarmigan', 'thresher',
#        'wire-haired_fox_terrier', 'Mexican_hairless', 'soccer_ball',
#        'drilling_platform', 'mortarboard', 'Norfolk_terrier', 'stage',
#        'hip', 'Australian_terrier', 'teapot', 'sea_snake', 'frying_pan',
#        'tape_player', 'car_wheel', 'Gordon_setter', 'dingo',
#        'sulphur_butterfly', 'borzoi', 'Dandie_Dinmont', 'laptop',
#        'Chesapeake_Bay_retriever', 'bullet_train', 'house_finch',
#        'library', 'thatch', 'collie', 'broccoli', 'measuring_cup',
#        'bustard', 'tow_truck', 'airliner', 'wood_rabbit',
#        'sulphur-crested_cockatoo', 'admiral', 'grocery_store',
#        'solar_dish', 'three-toed_sloth', 'jay', 'whiskey_jug', 'Pekinese',
#        'Welsh_springer_spaniel', 'fireboat', 'whippet', 'china_cabinet',
#        "potter's_wheel", 'moving_van', 'missile', 'beaver', 'dugong',
#        'container_ship', 'redbone', 'bobsled', 'wok', 'torch', 'go-kart',
#        'pineapple', 'motor_scooter', 'wine_bottle', 'Cardigan', 'upright',
#        'lifeboat', 'sea_anemone', 'maypole', 'bassoon', "jack-o'-lantern",
#        'file', 'spaghetti_squash', 'stone_wall', 'suspension_bridge',
#        'bittern', 'yurt', 'cassette_player', 'horse_cart', 'snowplow',
#        'bluetick', 'Irish_water_spaniel', 'titi', 'mud_turtle',
#        'zucchini', 'junco', 'mashed_potato', 'chickadee', 'toy_terrier',
#        'black_swan', 'prison', 'indri', 'sea_slug', 'apiary',
#        'black_grouse', 'traffic_light', 'steam_locomotive', 'sax',
#        'football_helmet', 'consomme', 'electric_locomotive', 'valley',
#        'hay', 'patas', 'cairn', 'typewriter_keyboard', 'hornbill', 'dam',
#        'German_short-haired_pointer'], dtype=object)

# %%
def create_comma_separated(term):
    if pd.isna(term):
        return term  # Return NaN as is
    full_term = term.replace('_', ' ')
    last_word = term.split('_')[-1]
    return f"{full_term}, {last_word}"

df['ResNet50_'] = df['ResNet50'].apply(create_comma_separated)
df['VGG16_'] = df['VGG16'].apply(create_comma_separated)
df['EfficientNetV2M_'] = df['EfficientNetV2M'].apply(create_comma_separated)
df['InceptionV3_'] = df['InceptionV3'].apply(create_comma_separated)

df.head()
# Out:
#         ResNet50          VGG16    EfficientNetV2M        InceptionV3  \
# 0           mask      birdhouse  great_white_shark  great_white_shark
# 1  ground_beetle  ground_beetle      ground_beetle      ground_beetle
# 2  ground_beetle  ground_beetle      ground_beetle      ground_beetle
# 3   tiger_beetle  ground_beetle      ground_beetle      ground_beetle
# 4  ground_beetle  ground_beetle      ground_beetle      ground_beetle
#
#                ResNet50_                 VGG16_          EfficientNetV2M_  \
# 0             mask, mask   birdhouse, birdhouse  great white shark, shark
# 1  ground beetle, beetle  ground beetle, beetle     ground beetle, beetle
# 2  ground beetle, beetle  ground beetle, beetle     ground beetle, beetle
# 3   tiger beetle, beetle  ground beetle, beetle     ground beetle, beetle
# 4  ground beetle, beetle  ground beetle, beetle     ground beetle, beetle
#
#                InceptionV3_
# 0  great white shark, shark
# 1     ground beetle, beetle
# 2     ground beetle, beetle
# 3     ground beetle, beetle
# 4     ground beetle, beetle

# %%
df.to_csv('/content/drive/MyDrive/BigData/Project/data/combined_models.csv', index=False)

# %% [markdown]
# ## Visualization: Top-10 Most Common Keywords

# %%
def extract_last_element(comma_separated_string):
    if pd.isna(comma_separated_string):
        return comma_separated_string  # Return NaN as is
    elements = comma_separated_string.split(',')
    return elements[-1].strip()  # Remove leading/trailing whitespace

# %%
# Extract the last elements and find unique values
unique_last_elements = pd.Series(df['ResNet50_'].apply(extract_last_element)).unique()[:20]

unique_last_elements
# Out:
# array(['mask', 'beetle', 'puzzle', 'buckle', 'pitcher', 'compass',
#        'sunglasses', 'powder', 'sidewinder', 'sandal', 'sundial',
#        'spotlight', 'hammerhead', 'slide', 'ibex', 'tie', 'widow',
#        'quill', 'vase', 'conch'], dtype=object)

# %%
# Now, we can check general unique elements
num_unique_resnet50 = len(pd.Series(df['ResNet50_'].apply(extract_last_element)).unique())
num_unique_vgg16 = len(pd.Series(df['VGG16_'].apply(extract_last_element)).unique())
num_unique_efficientnetv2m = len(pd.Series(df['EfficientNetV2M_'].apply(extract_last_element)).unique())
num_unique_inceptionv3 = len(pd.Series(df['InceptionV3_'].apply(extract_last_element)).unique())

print("Number of unique last entries in 'ResNet50' : ", num_unique_resnet50)
print("Number of unique last entries in 'VGG16' : ", num_unique_vgg16)
print("Number of unique last entries in 'EfficientNetV2M' : ", num_unique_efficientnetv2m)
print("Number of unique last entries in 'InceptionV3' : ", num_unique_inceptionv3)
# Out:
# Number of unique last entries in 'ResNet50' :  706
# Number of unique last entries in 'VGG16' :  709
# Number of unique last entries in 'EfficientNetV2M' :  642
# Number of unique last entries in 'InceptionV3' :  695

# %%
# Top 10 common keywords in a pie chart
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2, 2, figsize=(15, 12))

def plot_top_10_pie_chart(ax, column_name, data_frame):
    top_10 = data_frame[column_name].apply(extract_last_element).value_counts().head(10)
    ax.pie(top_10, labels=top_10.index, autopct='%1.1f%%', startangle=140)
    ax.set_title(f'Top 10 Common Keywords in {column_name}', pad=30)
    ax.axis('equal')

plot_top_10_pie_chart(axs[0, 0], 'ResNet50_', df)
plot_top_10_pie_chart(axs[0, 1], 'VGG16_', df)
plot_top_10_pie_chart(axs[1, 0], 'EfficientNetV2M_', df)
plot_top_10_pie_chart(axs[1, 1], 'InceptionV3_', df)

plt.show()

# %%
# Top 10 common keywords in a bar chart
def plot_top_10_bar_chart(ax, column_name, data_frame):
    top_10 = data_frame[column_name].apply(extract_last_element).value_counts().head(10)
    bars = ax.bar(top_10.index, top_10.values)
    ax.set_title(f'Top 10 Common Keywords in {column_name}')
    ax.set_xlabel('Keywords')
    ax.set_ylabel('Count')
    ax.tick_params(axis='x', rotation=45)
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width()/2, yval, int(yval), va='bottom', ha='center')

# Creating a 2x2 matrix of subplots for bar charts
fig, axs = plt.subplots(2, 2, figsize=(15, 12), gridspec_kw={'hspace': 0.5, 'left': 0.05, 'right': 0.95})

plot_top_10_bar_chart(axs[0, 0], 'ResNet50_', df)
plot_top_10_bar_chart(axs[0, 1], 'VGG16_', df)
plot_top_10_bar_chart(axs[1, 0], 'EfficientNetV2M_', df)
plot_top_10_bar_chart(axs[1, 1], 'InceptionV3_', df)

plt.show()

# %% [markdown]
# # Extract predicted keywords
# The new column 'combined_keyword' contains the most overlapped second element (keyword) from each row of the ResNet50_, VGG16_, EfficientNetV2M_, and InceptionV3_ columns. If there's a clear majority, only the most common keyword is selected; otherwise, all unique keywords are listed.
#
# - For rows where one keyword is dominant (like 'shark' or 'bear'), only that keyword is listed.
# - For rows with diverse keywords (like different animal names), all unique keywords are combined.

# %%
df = pd.read_csv('/content/drive/MyDrive/BigData/Project/data/combined_models.csv')
df.head()
# Out:
#         ResNet50          VGG16    EfficientNetV2M        InceptionV3  \
# 0           mask      birdhouse  great_white_shark  great_white_shark
# 1  ground_beetle  ground_beetle      ground_beetle      ground_beetle
# 2  ground_beetle  ground_beetle      ground_beetle      ground_beetle
# 3   tiger_beetle  ground_beetle      ground_beetle      ground_beetle
# 4  ground_beetle  ground_beetle      ground_beetle      ground_beetle
#
#                ResNet50_                 VGG16_          EfficientNetV2M_  \
# 0             mask, mask   birdhouse, birdhouse  great white shark, shark
# 1  ground beetle, beetle  ground beetle, beetle     ground beetle, beetle
# 2  ground beetle, beetle  ground beetle, beetle     ground beetle, beetle
# 3   tiger beetle, beetle  ground beetle, beetle     ground beetle, beetle
# 4  ground beetle, beetle  ground beetle, beetle     ground beetle, beetle
#
#                InceptionV3_
# 0  great white shark, shark
# 1     ground beetle, beetle
# 2     ground beetle, beetle
# 3     ground beetle, beetle
# 4     ground beetle, beetle

# %%
from collections import Counter

# Select the most overlapped keyword or list all if no overlap
def select_most_overlapped_keyword_specific_columns(row):
    specific_columns = ['ResNet50_', 'VGG16_', 'EfficientNetV2M_', 'InceptionV3_']
    keywords = [extract_last_element(row[col]) for col in specific_columns if not pd.isna(row[col])]

    if not keywords:  # If the list is empty (all values were NaN)
        return float('nan')  # Return NaN

    keyword_counts = Counter(keywords)
    most_common = keyword_counts.most_common()

    # If the most common keyword appears more than once, select it
    if most_common[0][1] > 1:
        return most_common[0][0]
    # Otherwise, return all unique keywords
    return ', '.join(set(keywords))

df['combined_keyword'] = df.apply(select_most_overlapped_keyword_specific_columns, axis=1)

df.to_csv('/content/drive/MyDrive/BigData/Project/data/combined_models_keyword.csv', index=False)
df.head()
# Out:
#         ResNet50          VGG16    EfficientNetV2M        InceptionV3  \
# 0           mask      birdhouse  great_white_shark  great_white_shark
# 1  ground_beetle  ground_beetle      ground_beetle      ground_beetle
# 2  ground_beetle  ground_beetle      ground_beetle      ground_beetle
# 3   tiger_beetle  ground_beetle      ground_beetle      ground_beetle
# 4  ground_beetle  ground_beetle      ground_beetle      ground_beetle
#
#                ResNet50_                 VGG16_          EfficientNetV2M_  \
# 0             mask, mask   birdhouse, birdhouse  great white shark, shark
# 1  ground beetle, beetle  ground beetle, beetle     ground beetle, beetle
# 2  ground beetle, beetle  ground beetle, beetle     ground beetle, beetle
# 3   tiger beetle, beetle  ground beetle, beetle     ground beetle, beetle
# 4  ground beetle, beetle  ground beetle, beetle     ground beetle, beetle
#
#                InceptionV3_ combined_keyword
# 0  great white shark, shark            shark
# 1     ground beetle, beetle           beetle
# 2     ground beetle, beetle           beetle
# 3     ground beetle, beetle           beetle
# 4     ground beetle, beetle           beetle

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14437 entries, 0 to 14436
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ResNet50          14334 non-null  object
#  1   VGG16             14334 non-null  object
#  2   EfficientNetV2M   14334 non-null  object
#  3   InceptionV3       14334 non-null  object
#  4   ResNet50_         14334 non-null  object
#  5   VGG16_            14334 non-null  object
#  6   EfficientNetV2M_  14334 non-null  object
#  7   InceptionV3_      14334 non-null  object
#  8   combined_keyword  14419 non-null  object
# dtypes: object(9)
# memory usage: 1015.2+ KB

# %% [markdown]
# ## The interesting insights about top-1 predictions of these 4 deep learning models
# - **One Common Keyword (11,594 rows)**: This represents approximately 80.8% of the cases. In these instances, all four models either agreed on a single prediction or had no more than one unique prediction after processing the second element of each prediction. This high level of agreement suggests that for the majority of the data, the models are consistent in their predictions, indicating reliability and certainty in these particular instances.
# - **More Than Two Keywords (2,825 rows)**: This accounts for approximately 19.7% of the cases.

# %%
df_with_multiple_keywords = df[df['combined_keyword'].str.split(',').str.len() > 1]

df_with_multiple_keywords
# Out:
#             ResNet50         VGG16    EfficientNetV2M  InceptionV3  \
# 5      jigsaw_puzzle          coho  great_white_shark   comic_book
# 12       face_powder       cheetah             shield      doormat
# 14            buckle       doormat             jaguar      leopard
# 16           sundial      sombrero        timber_wolf       shield
# 20              ibex     corkscrew            gazelle  book_jacket
# ...              ...           ...                ...          ...
# 14422      trilobite          tick        barn_spider  black_widow
# 14425          quill         acorn         sea_urchin        conch
# 14427       strainer           dam       handkerchief        stole
# 14428          stole  horned_viper              conch      ocarina
# 14435         binder          iPod             isopod         rule
#
#                    ResNet50_                VGG16_  \
# 5      jigsaw puzzle, puzzle            coho, coho
# 12       face powder, powder      cheetah, cheetah
# 14            buckle, buckle      doormat, doormat
# 16          sundial, sundial    sombrero, sombrero
# 20                ibex, ibex  corkscrew, corkscrew
# ...                      ...                   ...
# 14422   trilobite, trilobite            tick, tick
# 14425           quill, quill          acorn, acorn
# 14427     strainer, strainer              dam, dam
# 14428           stole, stole   horned viper, viper
# 14435         binder, binder            iPod, iPod
#
#                  EfficientNetV2M_         InceptionV3_  \
# 5        great white shark, shark     comic book, book
# 12                 shield, shield     doormat, doormat
# 14                 jaguar, jaguar     leopard, leopard
# 16              timber wolf, wolf       shield, shield
# 20               gazelle, gazelle  book jacket, jacket
# ...                           ...                  ...
# 14422         barn spider, spider   black widow, widow
# 14425          sea urchin, urchin         conch, conch
# 14427  handkerchief, handkerchief         stole, stole
# 14428                conch, conch     ocarina, ocarina
# 14435              isopod, isopod           rule, rule
#
#                          combined_keyword
# 5               shark, coho, book, puzzle
# 12       cheetah, shield, doormat, powder
# 14       buckle, leopard, doormat, jaguar
# 16        wolf, sundial, sombrero, shield
# 20       gazelle, corkscrew, jacket, ibex
# ...                                   ...
# 14422      widow, spider, tick, trilobite
# 14425         acorn, urchin, conch, quill
# 14427  dam, strainer, stole, handkerchief
# 14428        conch, viper, stole, ocarina
# 14435          binder, iPod, isopod, rule
#
# [2825 rows x 9 columns]

# %%
df_with_one_keywords = df[df['combined_keyword'].str.split(',').str.len() < 2]

df_with_one_keywords
# Out:
#                ResNet50          VGG16    EfficientNetV2M        InceptionV3  \
# 0                  mask      birdhouse  great_white_shark  great_white_shark
# 1         ground_beetle  ground_beetle      ground_beetle      ground_beetle
# 2         ground_beetle  ground_beetle      ground_beetle      ground_beetle
# 3          tiger_beetle  ground_beetle      ground_beetle      ground_beetle
# 4         ground_beetle  ground_beetle      ground_beetle      ground_beetle
# ...                 ...            ...                ...                ...
# 14431          necklace            NaN                NaN                NaN
# 14432           mailbag          purse              purse            mailbag
# 14433              slug          conch              conch              conch
# 14434  bulletproof_vest          cliff               swab   bulletproof_vest
# 14436              suit          cloak         sweatshirt         sweatshirt
#
#                     ResNet50_                 VGG16_  \
# 0                  mask, mask   birdhouse, birdhouse
# 1       ground beetle, beetle  ground beetle, beetle
# 2       ground beetle, beetle  ground beetle, beetle
# 3        tiger beetle, beetle  ground beetle, beetle
# 4       ground beetle, beetle  ground beetle, beetle
# ...                       ...                    ...
# 14431      necklace, necklace                    NaN
# 14432        mailbag, mailbag           purse, purse
# 14433              slug, slug           conch, conch
# 14434  bulletproof vest, vest           cliff, cliff
# 14436              suit, suit           cloak, cloak
#
#                EfficientNetV2M_              InceptionV3_ combined_keyword
# 0      great white shark, shark  great white shark, shark            shark
# 1         ground beetle, beetle     ground beetle, beetle           beetle
# 2         ground beetle, beetle     ground beetle, beetle           beetle
# 3         ground beetle, beetle     ground beetle, beetle           beetle
# 4         ground beetle, beetle     ground beetle, beetle           beetle
# ...                         ...                       ...              ...
# 14431                       NaN                       NaN         necklace
# 14432              purse, purse          mailbag, mailbag          mailbag
# 14433              conch, conch              conch, conch            conch
# 14434                swab, swab    bulletproof vest, vest             vest
# 14436    sweatshirt, sweatshirt    sweatshirt, sweatshirt       sweatshirt
#
# [11594 rows x 9 columns]

# %% [markdown]
# ## Extract keywords relevant to animal species
# > Reference: https://checklist.cites.org/#/en
#
# We need to define a list of keywords that considered relevant to animal species. This list will be used to filter and extract the relevant keywords from each entry in the 'combined_keyword' column.

# %% [markdown]
# ### Creating a List of Specific Animal Names
# 1. Filter by Kingdom is "Animalia"
# 2. Make a Species Name List from "EnglishNames"

# %%
file_path = '/content/drive/MyDrive/BigData/Project/data/Species-EnglishNames.csv'
species_df = pd.read_csv(file_path, low_memory=False)

# %%
animalia_df = species_df[species_df['Kingdom'] == 'Animalia']
non_null_count = animalia_df['EnglishNames'].notnull().sum()

print(non_null_count)
# Out:
# 4366

# %%
# Filter for 'Animalia' in the 'Kingdom' column
animalia_df = species_df[species_df['Kingdom'] == 'Animalia'][['EnglishNames', 'All_DistributionFullNames']]

# Define the function to split names
def split_names(names):
    if isinstance(names, float):  # Checking for NaN
        return []
    return [name.strip() for name in names.split(',')]

animalia_df['Split Names'] = animalia_df['EnglishNames'].apply(split_names)
animal_list_df = animalia_df.explode('Split Names').rename(columns={'Split Names': 'Specific Names'})

# Dropping NaN values in 'Specific Names'
animal_list_df = animal_list_df.dropna(subset=['Specific Names'])

# Dropping the now-redundant 'EnglishNames' column
animal_list_df.drop(['EnglishNames'], axis=1, inplace=True)

# 8752 rows
animal_list_df.to_csv('/content/drive/MyDrive/BigData/Project/data/animal_list.csv', index=False)
animal_list_df
# Out:
#                               All_DistributionFullNames  \
# 1     El Salvador, Guatemala, Honduras, Mexico, Nica...
# 3                                             Guatemala
# 5                                                Mexico
# 6                                             Guatemala
# 7                                                Mexico
# ...                                                 ...
# 7784                                          Australia
# 7784                                          Australia
# 7784                                          Australia
# 7784                                          Australia
# 7784                                          Australia
#
#                            Specific Names
# 1             Emerald-chinned Hummingbird
# 3      Anzuetoi arboreal alligator lizard
# 5      Bogert's arboreal alligator lizard
# 6             Campbell's alligator lizard
# 7     Chiszar's Arboreal Alligator Lizard
# ...                                   ...
# 7784          Central Australian rock rat
# 7784                     Central rock-rat
# 7784                     Central Rock Rat
# 7784        Central Thick-tailed Rock Rat
# 7784            Macdonnell Range Rock-rat
#
# [8752 rows x 2 columns]

# %%
# 8489 rows
len(animal_list_df['Specific Names'].unique())
# Out:
# 8489

# %% [markdown]
# Since there are some duplicate values in 'Specific Names', we will normalize the values in this column and remove the duplicates.
# - Central rock-rat
# - Central Rock Rat

# %%
# Check non-alphabet characters
non_alpha_chars = animal_list_df['Specific Names'].str.extractall(r'([^A-Za-z\s])')[0].unique()

non_alpha_chars
# Out:
# array(['-', "'", 'í', 'é', 'ô', '.', '’', 'á', '(', ')', '/', 'ü', '`',
#        '́', 'ö', 'è', 'ó', 'ú', 'ç', 'ñ'], dtype=object)

# %%
specified_chars = ["(", ")", "/", ".", "`", "́"]
filtered_rows_individual = animal_list_df[animal_list_df['Specific Names'].apply(lambda x: any(char in x for char in specified_chars))]

filtered_rows_individual
# Out:
#                               All_DistributionFullNames  \
# 564                    Saint Vincent and the Grenadines
# 564                    Saint Vincent and the Grenadines
# 575                                         Saint Lucia
# 575                                         Saint Lucia
# 686                                           Australia
# 984                                               Kenya
# 987                                           Sri Lanka
# 1355                                           Colombia
# 1709                                          Sri Lanka
# 1709                                          Sri Lanka
# 3601  Fiji, Indonesia, Japan, Northern Mariana Islan...
# 3815                                             Mexico
# 3816                                           Colombia
# 3819                                             Mexico
# 3822  Belize, Colombia, Costa Rica, Ecuador, Guatema...
# 3846                 Kenya, United Republic of Tanzania
# 4628             Australia, Indonesia, Papua New Guinea
# 5642                   Bolivia (Plurinational State of)
# 6484                                       Brazil, Peru
# 6496     Bolivia (Plurinational State of), Brazil, Peru
# 7000                    China, India, Myanmar, Thailand
#
#                                          Specific Names
# 564                                  St. vincent amazon
# 564                                  St. vincent parrot
# 575                                    St. lucia amazon
# 575                                    St. lucia parrot
# 686                            Children's (Rock) Python
# 984                                Mt. Kenya bush viper
# 987                              Sri lankan/ceylon rose
# 1355                   Rio Apaporis (Spectacled) Caiman
# 1709                        Karunaratne's (horn) lizard
# 1709                             Karu's (horned) lizard
# 3601                            Pontoh`s pygmy seahorse
# 3815                              Creaser ́s Mud Turtle
# 3816                                 Dunn ́s Mud Turtle
# 3819                              Herrera ́s mud turtle
# 3822  White-lipped Mud Turtle (Northern and Suthern ...
# 3846               Mt. Kilimanjaro two-horned chameleon
# 4628                          Amethystine (Rock) Python
# 5642                            GoldenPalace.com Monkey
# 6484                White/crandall's saddleback tamarin
# 6496                  Bolivian/peruvian squirrel monkey
# 7000                               Mrs. Hume's pheasant

# %%
animal_list_df = pd.read_csv('/content/drive/MyDrive/BigData/Project/data/animal_list.csv')
animal_list_df
# Out:
#                               All_DistributionFullNames  \
# 0     El Salvador, Guatemala, Honduras, Mexico, Nica...
# 1                                             Guatemala
# 2                                                Mexico
# 3                                             Guatemala
# 4                                                Mexico
# ...                                                 ...
# 8747                                          Australia
# 8748                                          Australia
# 8749                                          Australia
# 8750                                          Australia
# 8751                                          Australia
#
#                            Specific Names
# 0             Emerald-chinned Hummingbird
# 1      Anzuetoi arboreal alligator lizard
# 2      Bogert's arboreal alligator lizard
# 3             Campbell's alligator lizard
# 4     Chiszar's Arboreal Alligator Lizard
# ...                                   ...
# 8747          Central Australian rock rat
# 8748                     Central rock-rat
# 8749                     Central Rock Rat
# 8750        Central Thick-tailed Rock Rat
# 8751            Macdonnell Range Rock-rat
#
# [8752 rows x 2 columns]

# %%
import unicodedata

def normalize_name(name):
    name = name.lower()

    # Replacing specified characters
    name = name.replace('’', "'").replace('`', "'")

    # Normalizing non-standard characters to closest ASCII representation
    name = unicodedata.normalize('NFKD', name).encode('ascii', 'ignore').decode('ascii')

    # Keeping only alphabets and spaces
    name = ''.join([char for char in name if char.isalpha() or char.isspace()])

    return name

# %%
# Step 1: Remove all special characters including numbers, keep only lowercase alphabets
def remove_special_characters(name):
    return ''.join([char.lower() for char in name if char.isalpha()])

animal_list_df['Specific Names_'] = animal_list_df['Specific Names'].apply(remove_special_characters)

# Step 2: Keep the row with the most special characters in case of duplicates
# Central rock-rat > Central Rock Rat
animal_list_df['Special Char Count'] = animal_list_df['Specific Names'].apply(lambda x: len([char for char in x if not char.isalpha() and not char.isspace()]))
animal_list_df.sort_values(by=['Specific Names_', 'Special Char Count'], ascending=[True, False], inplace=True)

# Dropping duplicates, keeping the one with the most special characters
animal_list_df.drop_duplicates(subset=['Specific Names_'], keep='first', inplace=True)
animal_list_df.reset_index(drop=True, inplace=True)

# Step 3: Apply the normalize_name function
animal_list_df['Specific Names Normalized'] = animal_list_df['Specific Names'].apply(normalize_name)

animal_list_df
# Out:
#                               All_DistributionFullNames  \
# 0     Angola, Botswana, Central African Republic, Dj...
# 1                                               Bahamas
# 2     Australia, Christmas Island, Indonesia, Maurit...
# 3                                Madagascar, Seychelles
# 4                                                 Italy
# ...                                                 ...
# 8125    Malawi, Mozambique, United Republic of Tanzania
# 8126  Argentina, Belize, Bolivia (Plurinational Stat...
# 8127  Albania, Algeria, Angola, Argentina, Australia...
# 8128                 Eswatini, Mozambique, South Africa
# 8129                                       South Africa
#
#                    Specific Names            Specific Names_  \
# 0                        Aardwolf                   aardwolf
# 1                Abaco Island Boa             abacoislandboa
# 2                  Abbott's Booby               abbottsbooby
# 3              Abbott's Day Gecko            abbottsdaygecko
# 4                 Abruzzo Chamois             abruzzochamois
# ...                           ...                        ...
# 8125        Zomba pygmy chameleon        zombapygmychameleon
# 8126             Zone-tailed Hawk             zonetailedhawk
# 8127         Zorro thresher shark         zorrothreshershark
# 8128  Zoutpansberg Girdled Lizard  zoutpansberggirdledlizard
# 8129     Zululand Dwarf Chameleon     zululanddwarfchameleon
#
#       Special Char Count    Specific Names Normalized
# 0                      0                     aardwolf
# 1                      0             abaco island boa
# 2                      1                abbotts booby
# 3                      1            abbotts day gecko
# 4                      0              abruzzo chamois
# ...                  ...                          ...
# 8125                   0        zomba pygmy chameleon
# 8126                   1              zonetailed hawk
# 8127                   0         zorro thresher shark
# 8128                   0  zoutpansberg girdled lizard
# 8129                   0     zululand dwarf chameleon
#
# [8130 rows x 5 columns]

# %%
animal_list_df.to_csv('/content/drive/MyDrive/BigData/Project/data/specific_animal_list_normalized.csv', index=False)

# %% [markdown]
# - Before normalization: 8752 rows
# - After normalization: 8130 rows

# %% [markdown]
# ### Creating a List of General Animal Names
# From the 'Specific Names Normalized' column, we can extract the last word.

# %%
animal_list_df = pd.read_csv('/content/drive/MyDrive/BigData/Project/data/specific_animal_list_normalized.csv')
animal_list_df
# Out:
#                               All_DistributionFullNames  \
# 0     Angola, Botswana, Central African Republic, Dj...
# 1                                               Bahamas
# 2     Australia, Christmas Island, Indonesia, Maurit...
# 3                                Madagascar, Seychelles
# 4                                                 Italy
# ...                                                 ...
# 8125    Malawi, Mozambique, United Republic of Tanzania
# 8126  Argentina, Belize, Bolivia (Plurinational Stat...
# 8127  Albania, Algeria, Angola, Argentina, Australia...
# 8128                 Eswatini, Mozambique, South Africa
# 8129                                       South Africa
#
#                    Specific Names            Specific Names_  \
# 0                        Aardwolf                   aardwolf
# 1                Abaco Island Boa             abacoislandboa
# 2                  Abbott's Booby               abbottsbooby
# 3              Abbott's Day Gecko            abbottsdaygecko
# 4                 Abruzzo Chamois             abruzzochamois
# ...                           ...                        ...
# 8125        Zomba pygmy chameleon        zombapygmychameleon
# 8126             Zone-tailed Hawk             zonetailedhawk
# 8127         Zorro thresher shark         zorrothreshershark
# 8128  Zoutpansberg Girdled Lizard  zoutpansberggirdledlizard
# 8129     Zululand Dwarf Chameleon     zululanddwarfchameleon
#
#       Special Char Count    Specific Names Normalized
# 0                      0                     aardwolf
# 1                      0             abaco island boa
# 2                      1                abbotts booby
# 3                      1            abbotts day gecko
# 4                      0              abruzzo chamois
# ...                  ...                          ...
# 8125                   0        zomba pygmy chameleon
# 8126                   1              zonetailed hawk
# 8127                   0         zorro thresher shark
# 8128                   0  zoutpansberg girdled lizard
# 8129                   0     zululand dwarf chameleon
#
# [8130 rows x 5 columns]

# %%
# Extracting the last word for the 'General Names Normalized' column
animal_list_df['General Names Normalized'] = animal_list_df['Specific Names Normalized'].apply(lambda x: x.split()[-1] if x else None)

animal_list_df[['Specific Names Normalized', 'General Names Normalized']]
# Out:
#         Specific Names Normalized General Names Normalized
# 0                        aardwolf                 aardwolf
# 1                abaco island boa                      boa
# 2                   abbotts booby                    booby
# 3               abbotts day gecko                    gecko
# 4                 abruzzo chamois                  chamois
# ...                           ...                      ...
# 8125        zomba pygmy chameleon                chameleon
# 8126              zonetailed hawk                     hawk
# 8127         zorro thresher shark                    shark
# 8128  zoutpansberg girdled lizard                   lizard
# 8129     zululand dwarf chameleon                chameleon
#
# [8130 rows x 2 columns]

# %%
unique_general_species = animal_list_df['General Names Normalized'].unique()
unique_general_species
# Out:
# array(['aardwolf', 'boa', 'booby', 'gecko', 'chamois', 'owl', 'lovebird',
#        'tarantula', 'achoque', 'iguana', 'eagle', 'addax', 'gazelle',
#        'cuscus', 'flyingfox', 'hawkowl', 'coquette', 'sturgeon', 'fox',
#        'tortoise', 'urial', 'ass', 'owlet', 'baza', 'barb', 'fish',
#        'python', 'caracal', 'chameleon', 'civet', 'otter', 'duck',
#        'crocodile', 'cuckoofalcon', 'cuckoohawk', 'eagleowl', 'elephant',
#        'fisheagle', 'cat', 'goshawk', 'grassowl', 'parrot', 'gymnogene',
#        'harrierhawk', 'hawkeagle', 'hobby', 'houbara', 'bustard',
#        'lizard', 'lion', 'sparrowhawk', 'hawk', 'manatee', 'marshharrier',
#        'penguin', 'coral', 'pygmyfalcon', 'buzzard', 'monitor',
#        'scopsowl', 'serpenteagle', 'turtle', 'kite', 'wedgefish',
#        'vulture', 'woodowl', 'seal', 'gibbon', 'mangabey', 'agouti',
#        'lampmussel', 'naiad', 'mussel', 'curassow', 'toad', 'lemur',
#        'goose', 'parakeet', 'mouse', 'bushbaby', 'galago', 'hummingbird',
#        'monkey', 'alligators', 'deer', 'weasel', 'argali', 'frog',
#        'howler', 'parrotlet', 'pygmyowl', 'umbrellabird', 'matamata',
#        'dolphin', 'amazons', 'amberfish', 'kingparrot', 'alligator',
#        'bear', 'flamingo', 'kestrel', 'lynx', 'pronghorn', 'mountaingem',
#        'sunangel', 'woodstar', 'ampalagua', 'falcon', 'tiger', 'anaconda',
#        'sheep', 'boobook', 'cobra', 'cockoftherock', 'condor', 'emerald',
#        'armadillo', 'hillstar', 'tamarin', 'tapir', 'titi', 'wolf',
#        'newt', 'salamander', 'whale', 'frigatebird', 'colobus',
#        'angonoka', 'angwantibo', 'guitarfish', 'anoa', 'mango', 'baboon',
#        'aoudad', 'caiman', 'apes', 'apollo', 'butterfly', 'monkeyface',
#        'terrapin', 'oryx', 'boto', 'arapaima', 'mantella', 'redpoll',
#        'astrapia', 'parotia', 'tegu', 'constrictor', 'pheasant',
#        'marmoset', 'teyou', 'arowana', 'arraia', 'arrau', 'macaque',
#        'viper', 'loris', 'hornbill', 'bonytongue', 'buffalo', 'ibis',
#        'dragon', 'ibex', 'snake', 'dog', 'rabbit', 'grebe', 'devilray',
#        'ridley', 'shark', 'thresher', 'echidna', 'prairiechicken', 'teal',
#        'harrier', 'conure', 'lungfish', 'maskedowl', 'ringneck', 'avahi',
#        'axolotl', 'ayeaye', 'zorro', 'babiroussa', 'babirusa', 'wapiti',
#        'baiji', 'saki', 'uacari', 'uakari', 'grivet', 'vervet', 'myna',
#        'starling', 'screechowl', 'cotinga', 'duiker', 'harewallaby',
#        'langur', 'linsang', 'musang', 'pitta', 'snakeeagle', 'surili',
#        'barbthroat', 'turaco', 'sphaero', 'barasingha', 'ape', 'stag',
#        'seahorse', 'cockatoo', 'rockfowl', 'bandicoot', 'forestfalcon',
#        'honeybuzzard', 'warbler', 'batagur', 'bateleur', 'black', 'white',
#        'whales', 'beakhead', 'bearcat', 'helmetcrest', 'mountaineer',
#        'clam', 'bears', 'sheartail', 'marten', 'beluga', 'florican',
#        'ray', 'mastigure', 'besra', 'bharal', 'glory', 'lory',
#        'shovelnose', 'sideneck', 'skink', 'stingray', 'bilby',
#        'binturong', 'paradise', 'birdwing', 'thornbill', 'korhaan',
#        'pangolin', 'thorntail', 'whistlingduck', 'amazon',
#        'hangingparrot', 'sicklebill', 'streamertail', 'woodduck',
#        'buzzardkite', 'harriereagle', 'plovercrest', 'puffleg',
#        'blackbuck', 'capuchin', 'caracara', 'chachalaca', 'buzzardeagle',
#        'corals', 'crownedcrane', 'fairy', 'porpoise', 'blackfish',
#        'albatross', 'ferret', 'pipingguan', 'squirrel', 'caique',
#        'tragopan', 'sunbeam', 'inca', 'guenon', 'jacobin', 'sawback',
#        'falconet', 'metaltail', 'muntjac', 'aracari', 'crane', 'swan',
#        'pajuil', 'penelopina', 'rhinoceros', 'douc', 'bat', 'stork',
#        'trainbearer', 'teatfish', 'brilliant', 'finch', 'hermit',
#        'treekangaroo', 'fishowl', 'dove', 'pigeon', 'blesbok',
#        'blossomcrown', 'bluetongue', 'macaw', 'birdofparadise',
#        'bluebonnet', 'bluebuck', 'sapphire', 'lorikeet', 'crownedpigeon',
#        'racquettail', 'woodnymph', 'figparrot', 'lancebill', 'rackettail',
#        'treefrog', 'bluethroat', 'goldentail', 'starfrontlet',
#        'starthroat', 'grassparakeet', 'bobcat', 'bobwhite', 'quail',
#        'bockadam', 'sloth', 'bonobo', 'bontebok', 'boodie', 'orangutan',
#        'peacockpheasant', 'shrew', 'treeshrew', 'softshell', 'bottlehead',
#        'padloper', 'boutu', 'ruby', 'tigerparrot', 'wallaby', 'corella',
#        'brolga', 'comet', 'plumeleteer', 'whaler', 'tuatara',
#        'earedpheasant', 'mongoose', 'mouselemur', 'cucumber', 'violetear',
#        'bettong', 'ratkangaroo', 'budgerigar', 'sabrewing', 'pygmyparrot',
#        'coronet', 'bullfinch', 'bunch', 'bungarra', 'bushbabies',
#        'bustards', 'cachalot', 'cachelot', 'caimans', 'lark', 'callimico',
#        'chameleo', 'goanna', 'griffon', 'zebra', 'cascabel',
#        'rattlesnake', 'snowcock', 'cats', 'tur', 'maleo', 'brocket',
#        'rat', 'rockrat', 'ceratodus', 'peccary', 'toucan', 'keelback',
#        'cheetah', 'gray', 'guemal', 'huemul', 'pudu', 'chimpanzee',
#        'chimpanzees', 'hat', 'chinchilla', 'goral', 'hwamei', 'impeyan',
#        'monal', 'paddlefish', 'serow', 'swordfish', 'swallowtail',
#        'xenosaur', 'chingungo', 'chinkara', 'chiru', 'chousingha',
#        'chungungo', 'angelfish', 'leopard', 'clubshell', 'tit',
#        'coatimundi', 'cochito', 'cockatiel', 'cockatoos', 'coelacanth',
#        'coffinback', 'colasisi', 'barnowl', 'bayowl', 'blackhawk',
#        'crossbill', 'eel', 'hippopotamus', 'jackal', 'linnet',
#        'nightingale', 'ostrich', 'peafowl', 'phalanger', 'guan', 'rhea',
#        'thrush', 'rorqual', 'rosefinch', 'sawfish', 'sifaka', 'estrella',
#        'corsac', 'cougar', 'rustbrown', 'cranes', 'argus',
#        'hornedpheasant', 'rosella', 'shiningparrot', 'topaz', 'manucode',
#        'newts', 'crocodiles', 'crocoteju', 'grassquit', 'treeduck',
#        'cuiui', 'culpeo', 'bean', 'curlyhair', 'riffleshell', 'stingrat',
#        'mouflon', 'dalgyte', 'pelican', 'chantinggoshawk', 'hydrocoral',
#        'hog', 'devilfish', 'dhaman', 'dhole', 'tarsier', 'djamdjam',
#        'djoongari', 'dolphins', 'dormilona', 'thickknee', 'douroucouli',
#        'dragonfish', 'lizardet', 'drill', 'drum', 'dugong', 'chimpazee',
#        'dziggetai', 'eagles', 'falanouc', 'gorilla', 'riflebird',
#        'piedtail', 'elk', 'liocichla', 'snail', 'scorpion', 'ermine',
#        'curlew', 'esok', 'blackbird', 'blackcap', 'oriole', 'siskin',
#        'skylark', 'spoonbill', 'wren', 'bunting', 'goldfinch', 'leech',
#        'robin', 'serin', 'falcons', 'gavial', 'gharial', 'manapare',
#        'potto', 'waterrat', 'fanaloka', 'fanalouc', 'pocketbook', 'adder',
#        'awlbill', 'finback', 'pigtoe', 'finner', 'firecoral', 'flamingos',
#        'flatback', 'chestnut', 'kakariki', 'fosa', 'fossa', 'antelope',
#        'franciscana', 'freshie', 'talapoin', 'galagos', 'galah', 'susu',
#        'gator', 'gaur', 'hammerhai', 'ghorkhar', 'anteater', 'bechedemer',
#        'catfish', 'clams', 'wrasse', 'panda', 'carp', 'zonure', 'giboya',
#        'monster', 'giraffe', 'blackcockatoo', 'goat', 'rodrigues',
#        'kaiserihind', 'gombessa', 'jewelfront', 'grayback', 'grayfish',
#        'froghawk', 'brushturkey', 'mobula', 'melampitta', 'rhino',
#        'sootyowl', 'goura', 'hammerhead', 'sapphirewing', 'avadavat',
#        'firecrown', 'greenblossom', 'shell', 'goldenthroat', 'carib',
#        'tayra', 'junglefowl', 'picathartes', 'ox', 'guaiabero', 'guanaco',
#        'spinytailed', 'redrump', 'guereza', 'guitarfishes', 'gyrfalcon',
#        'hackleback', 'paradisecrow', 'hamadryad', 'sharks', 'hangul',
#        'hardhead', 'hawks', 'hellbender', 'honeyeater', 'frutoso', 'eye',
#        'marmot', 'muskdeer', 'hare', 'hoemother', 'badger', 'visorbearer',
#        'lizards', 'sungem', 'horsefish', 'monkeys', 'huillin', 'skunk',
#        'hummingbirds', 'humphead', 'idmi', 'temoleh', 'bison', 'bullfrog',
#        'eggeater', 'lutung', 'flapshell', 'indris', 'jabiru', 'jacquot',
#        'jacuruxi', 'jaguar', 'jaguarundi', 'sparrow', 'kagu', 'kaka',
#        'kakapo', 'kawekaweau', 'kea', 'kelesa', 'khur', 'kiang',
#        'kinkajou', 'kipunji', 'lourie', 'kodkod', 'kokomo', 'kolinsky',
#        'kouprey', 'kulan', 'chamaeleon', 'blanco', 'lammergeier',
#        'lammergeyer', 'lanner', 'marsupialmouse', 'hippo', 'lemurs',
#        'latimeria', 'leatherback', 'lechwe', 'lemonfish', 'bristlebird',
#        'sandshark', 'whitethroat', 'kangaroo', 'lesula', 'spari', 'likh',
#        'loggerhead', 'mako', 'dunnart', 'paradigalla', 'sminthopsis',
#        'sylph', 'bird', 'rail', 'woodhen', 'satinbird', 'lories',
#        'lorikeets', 'lorises', 'paca', 'luth', 'bleedingheart', 'macaws',
#        'weakfish', 'lappetface', 'quetzal', 'mal', 'mala', 'piedhornbill',
#        'rose', 'malbrouck', 'fowl', 'megapode', 'mandrill',
#        'mangotaniwha', 'mangoururoa', 'pitviper', 'maning', 'monk',
#        'margay', 'turtles', 'markhor', 'marl', 'sureli', 'spatuletail',
#        'masacuate', 'paradiseflycatcher', 'laughingthrush', 'merlin',
#        'merrin', 'blackvelvet', 'fireleg', 'flameknee', 'porcupine',
#        'beauty', 'orangeknee', 'prairiedog', 'redknee', 'redleg',
#        'rosegrey', 'rustelg', 'simpona', 'imperialpigeon', 'eclectus',
#        'saiga', 'horse', 'colorado', 'lechuza', 'morepork', 'avocetbill',
#        'agama', 'velvetbreast', 'muggar', 'mugger', 'munning', 'muriqui',
#        'musseldigger', 'mussurana', 'mutum', 'napoleonfish', 'narwhal',
#        'nene', 'vultures', 'shikra', 'nilgai', 'scrubbird', 'greenshank',
#        'coati', 'wombat', 'tamandua', 'nyan', 'treesnail', 'spinytail',
#        'turkey', 'ocelot', 'legs', 'oncilla', 'ora', 'pimpleback', 'orca',
#        'ormala', 'orong', 'osetr', 'osprey', 'ottercivet', 'ounce',
#        'jawa', 'paddlefishes', 'lilliput', 'seaeagle', 'panther',
#        'parakeets', 'parrots', 'peccaries', 'fishingowl', 'peregrine',
#        'perentie', 'leafmonkey', 'chuckwalla', 'azurecrown', 'conch',
#        'pinkmucket', 'pirarucu', 'pygmychameleon', 'porbeagle',
#        'porpoises', 'redfish', 'puma', 'whitetip', 'pythons', 'ratel',
#        'razorback', 'leiothrix', 'mesia', 'flycatcher', 'catbear',
#        'cardinal', 'gull', 'rhinoceroses', 'coarl', 'ripsack', 'pebbler',
#        'brushwarbler', 'rorquals', 'parrakeet', 'mynah', 'roughleg',
#        'boas', 'blueflycatcher', 'niltava', 'crabhawk', 'rockthrush',
#        'japan', 'toucanet', 'saker', 'uakaris', 'saladang', 'sanzinia',
#        'saola', 'sasin', 'beetle', 'sawfishes', 'cow', 'pony',
#        'secretarybird', 'serval', 'tanager', 'sevruga', 'shapu', 'ship',
#        'shoebill', 'shovelfish', 'siamang', 'sifakas', 'acerodon',
#        'silkycrow', 'simakobou', 'slasher', 'snowcap', 'tinamou',
#        'turlte', 'elephantseal', 'tigrina', 'spadefish', 'spar',
#        'sphenodon', 'hazards', 'standardwing', 'sterlet', 'stinkpot',
#        'stoat', 'bulbul', 'hyaena', 'hyena', 'sturgeons', 'sunfish',
#        'sungazer', 'surucucu', 'swamper', 'swingletail', 'swiveltail',
#        'tagua', 'takh', 'takin', 'tamarau', 'tamaraw', 'tamarou',
#        'tantalus', 'tapirs', 'tartaruga', 'taruca', 'thamin', 'thrasher',
#        'tjoeboela', 'tomistoma', 'tortoises', 'totoaba', 'barbet',
#        'shrews', 'woodpecker', 'trumpetbird', 'blossom', 'tucuxi',
#        'turgidblossom', 'uaddan', 'vaquita', 'vicugna', 'vicuna',
#        'waldrapp', 'walrus', 'wanderoo', 'turt', 'fanshell', 'scrubird',
#        'whiptail', 'silvereye', 'whiteeye', 'catspaw', 'whitedeath',
#        'rivermartin', 'pointer', 'shama', 'wartyback', 'wildcat', 'yak',
#        'wishiwilly', 'woma', 'woodlark', 'woylie', 'wurrup',
#        'yellowhammer', 'rustrump'], dtype=object)

# %%
len(unique_general_species)
# Out:
# 906

# %% [markdown]
# We can conclude that, according to CITES (the Convention on International Trade in Endangered Species of Wild Fauna and Flora), there are 906 general animal species classified as endangered.

# %%
animal_list_df.to_csv('/content/drive/MyDrive/BigData/Project/data/final_animal_list_normalized', index=False)
animal_list_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8130 entries, 0 to 8129
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   All_DistributionFullNames  8047 non-null   object
#  1   Specific Names             8130 non-null   object
#  2   Specific Names_            8130 non-null   object
#  3   Special Char Count         8130 non-null   int64
#  4   Specific Names Normalized  8130 non-null   object
#  5   General Names Normalized   8130 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 381.2+ KB

# %%
# Dropping the specified columns
animal_list_df = animal_list_df.drop(['Specific Names_', 'Special Char Count'], axis=1)
animal_list_df = animal_list_df.rename(columns={'All_DistributionFullNames': 'Distribution Country'})

csv_file_path = '/content/drive/MyDrive/BigData/Project/data/final_animal_list.csv'
animal_list_df.to_csv(csv_file_path, index=False)

# %% [markdown]
# ### Fuzzy Matching (String Similarity)
# > Fuzzy matching algorithms, particularly those used in libraries like rapidfuzz or fuzzywuzzy, are generally designed to handle variations in case (uppercase vs. lowercase) and can effectively manage minor typos or variations in the spelling of words. This capability is part of what makes fuzzy matching useful for comparing strings where exact matches are not expected due to inconsistencies or human error in the data.
#
# Fuzzy matching algorithms often rely on string **similarity metrics**, such as Levenshtein Distance, Jaro-Winkler, or Cosine Similarity. These metrics calculate a score based on how many edits (additions, deletions, substitutions) are required to transform one string into another, or they measure the similarity in character sequences.
#
# One of the most common metrics used in fuzzy matching is the **Levenshtein Distance**. It measures the minimum number of single-character edits required to change one word into another. The lower the number, the more similar the two strings are.

# %%
animal_df = pd.read_csv('/content/drive/MyDrive/BigData/Project/data/final_animal_list.csv')
animal_df.head()
# Out:
#                                 Distribution Country      Specific Names  \
# 0  Angola, Botswana, Central African Republic, Dj...            Aardwolf
# 1                                            Bahamas    Abaco Island Boa
# 2  Australia, Christmas Island, Indonesia, Maurit...      Abbott's Booby
# 3                             Madagascar, Seychelles  Abbott's Day Gecko
# 4                                              Italy     Abruzzo Chamois
#
#   Specific Names Normalized General Names Normalized
# 0                  aardwolf                 aardwolf
# 1          abaco island boa                      boa
# 2             abbotts booby                    booby
# 3         abbotts day gecko                    gecko
# 4           abruzzo chamois                  chamois

# %%
combined_df = pd.read_csv('/content/drive/MyDrive/BigData/Project/data/combined_models_keyword.csv')
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14437 entries, 0 to 14436
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ResNet50          14334 non-null  object
#  1   VGG16             14334 non-null  object
#  2   EfficientNetV2M   14334 non-null  object
#  3   InceptionV3       14334 non-null  object
#  4   ResNet50_         14334 non-null  object
#  5   VGG16_            14334 non-null  object
#  6   EfficientNetV2M_  14334 non-null  object
#  7   InceptionV3_      14334 non-null  object
#  8   combined_keyword  14419 non-null  object
# dtypes: object(9)
# memory usage: 1015.2+ KB

# %%
combined_df.head(10)
# Out:
#            ResNet50             VGG16     EfficientNetV2M         InceptionV3  \
# 0              mask         birdhouse   great_white_shark   great_white_shark
# 1     ground_beetle     ground_beetle       ground_beetle       ground_beetle
# 2     ground_beetle     ground_beetle       ground_beetle       ground_beetle
# 3      tiger_beetle     ground_beetle       ground_beetle       ground_beetle
# 4     ground_beetle     ground_beetle       ground_beetle       ground_beetle
# 5     jigsaw_puzzle              coho   great_white_shark          comic_book
# 6     ground_beetle     ground_beetle       ground_beetle       ground_beetle
# 7            buckle            shield  chambered_nautilus  chambered_nautilus
# 8           pitcher            buckle         triceratops              buckle
# 9  magnetic_compass  magnetic_compass                puck                puck
#
#                    ResNet50_                     VGG16_  \
# 0                 mask, mask       birdhouse, birdhouse
# 1      ground beetle, beetle      ground beetle, beetle
# 2      ground beetle, beetle      ground beetle, beetle
# 3       tiger beetle, beetle      ground beetle, beetle
# 4      ground beetle, beetle      ground beetle, beetle
# 5      jigsaw puzzle, puzzle                 coho, coho
# 6      ground beetle, beetle      ground beetle, beetle
# 7             buckle, buckle             shield, shield
# 8           pitcher, pitcher             buckle, buckle
# 9  magnetic compass, compass  magnetic compass, compass
#
#                EfficientNetV2M_                  InceptionV3_  \
# 0      great white shark, shark      great white shark, shark
# 1         ground beetle, beetle         ground beetle, beetle
# 2         ground beetle, beetle         ground beetle, beetle
# 3         ground beetle, beetle         ground beetle, beetle
# 4         ground beetle, beetle         ground beetle, beetle
# 5      great white shark, shark              comic book, book
# 6         ground beetle, beetle         ground beetle, beetle
# 7  chambered nautilus, nautilus  chambered nautilus, nautilus
# 8      triceratops, triceratops                buckle, buckle
# 9                    puck, puck                    puck, puck
#
#             combined_keyword
# 0                      shark
# 1                     beetle
# 2                     beetle
# 3                     beetle
# 4                     beetle
# 5  shark, coho, puzzle, book
# 6                     beetle
# 7                   nautilus
# 8                     buckle
# 9                    compass

# %% [markdown]
# In the code below, `rapidfuzz.process.extract` finds the best matches from `animal_df['General Names Normalized']` for each unique keyword in `combined_df['combined_keyword']`.
#
# - **animal_df**: Contains the specific animal species names and general animal species names, which are derived from the former column.
# - **combined_df**: Represents the most commonly predicted keywords from four deep learning models. It can contain multiple keywords in a single record.

# %%
from rapidfuzz import process, fuzz

# Find best matches
def find_matches(query, choices, limit=1, score_cutoff=80):
    return process.extract(query, choices, scorer=fuzz.WRatio, limit=limit, score_cutoff=score_cutoff)

# %% [markdown]
# #### combined_keyword & General Names Normalized

# %%
results_general = []

# Loop through each unique keyword and find the best match
for keyword in combined_df['combined_keyword'].unique():
    matches = find_matches(keyword, animal_df['General Names Normalized'].unique())
    for match in matches:
        matched_name, score, _ = match
        results_general.append({'combined_keyword': keyword, 'general_name': matched_name, 'score_combined_general': score})

result_general_df = pd.DataFrame(results_general, columns=['combined_keyword', 'general_name', 'score_combined_general'])
result_general_df.head()
# Out:
#             combined_keyword general_name  score_combined_general
# 0                      shark        shark                   100.0
# 1                     beetle       beetle                   100.0
# 2  shark, coho, puzzle, book        shark                    90.0
# 3                    compass          ass                    90.0
# 4                 sunglasses          ass                    90.0

# %% [markdown]
# #### ResNet50_ & Specific Names Normalized

# %%
results_resnet_specific = []

# Loop through each unique keyword and find the best match
for keyword in combined_df['ResNet50_'].unique():
    matches = find_matches(keyword, animal_df['Specific Names Normalized'].unique())
    for match in matches:
        matched_name, score, _ = match
        results_resnet_specific.append({'resnet50_keyword': keyword, 'specific_name': matched_name, 'score_resnet50_specific': score})

results_resnet_specific_df = pd.DataFrame(results_resnet_specific, columns=['resnet50_keyword', 'specific_name', 'score_resnet50_specific'])
results_resnet_specific_df.head()
# Out:
#          resnet50_keyword                        specific_name  \
# 0   ground beetle, beetle  grandidiers madagascar ground gecko
# 1    tiger beetle, beetle                                tiger
# 2  sunglasses, sunglasses                                  ass
# 3  hammerhead, hammerhead                           hammerhead
# 4      black widow, widow       argentine black and white tegu
#
#    score_resnet50_specific
# 0                     85.5
# 1                     90.0
# 2                     90.0
# 3                     90.0
# 4                     85.5

# %% [markdown]
# #### VGG16_ & Specific Names Normalized

# %%
results_vgg_specific = []

# Loop through each unique keyword and find the best match
for keyword in combined_df['VGG16_'].unique():
    matches = find_matches(keyword, animal_df['Specific Names Normalized'].unique())
    for match in matches:
        matched_name, score, _ = match
        results_vgg_specific.append({'vgg16_keyword': keyword, 'specific_name': matched_name, 'score_vgg16_specific': score})

results_vgg_specific_df = pd.DataFrame(results_vgg_specific, columns=['vgg16_keyword', 'specific_name', 'score_vgg16_specific'])
results_vgg_specific_df.head()
# Out:
#              vgg16_keyword                        specific_name  \
# 0    ground beetle, beetle  grandidiers madagascar ground gecko
# 1         cheetah, cheetah                              cheetah
# 2       night snake, snake         central american coral snake
# 3         brown bear, bear                           brown bear
# 4  cocktail shaker, shaker                                saker
#
#    score_vgg16_specific
# 0                  85.5
# 1                  90.0
# 2                  85.5
# 3                  90.0
# 4                  80.0

# %% [markdown]
# #### EfficientNetV2M_ & Specific Names Normalized

# %%
results_efficientNet_specific = []

# Loop through each unique keyword and find the best match
for keyword in combined_df['EfficientNetV2M_'].unique():
    matches = find_matches(keyword, animal_df['Specific Names Normalized'].unique())
    for match in matches:
        matched_name, score, _ = match
        results_efficientNet_specific.append({'efficientNetV2M_keyword': keyword, 'specific_name': matched_name, 'score_efficientNetV2M_specific': score})

results_efficientNet_specific_df = pd.DataFrame(results_efficientNet_specific, columns=['efficientNetV2M_keyword', 'specific_name', 'score_efficientNetV2M_specific'])
results_efficientNet_specific_df.head()
# Out:
#     efficientNetV2M_keyword                        specific_name  \
# 0  great white shark, shark                    great white shark
# 1     ground beetle, beetle  grandidiers madagascar ground gecko
# 2    sunglasses, sunglasses                                  ass
# 3       horned viper, viper                          horned guan
# 4            jaguar, jaguar                               jaguar
#
#    score_efficientNetV2M_specific
# 0                            95.0
# 1                            85.5
# 2                            90.0
# 3                            85.5
# 4                            90.0

# %% [markdown]
# #### InceptionV3_	& Specific Names Normalized

# %%
results_inception_specific = []

# Loop through each unique keyword and find the best match
for keyword in combined_df['InceptionV3_'].unique():
    matches = find_matches(keyword, animal_df['Specific Names Normalized'].unique())
    for match in matches:
        matched_name, score, _ = match
        results_inception_specific.append({'inceptionV3_keyword': keyword, 'specific_name': matched_name, 'score_inceptionV3_specific': score})

results_inception_specific_df = pd.DataFrame(results_inception_specific, columns=['inceptionV3_keyword', 'specific_name', 'score_inceptionV3_specific'])
results_inception_specific_df.head()
# Out:
#         inceptionV3_keyword                        specific_name  \
# 0  great white shark, shark                    great white shark
# 1     ground beetle, beetle  grandidiers madagascar ground gecko
# 2        sunglass, sunglass                                  ass
# 3          leopard, leopard                              leopard
# 4          brown bear, bear                           brown bear
#
#    score_inceptionV3_specific
# 0                        95.0
# 1                        85.5
# 2                        90.0
# 3                        90.0
# 4                        90.0

# %% [markdown]
# #### Combine multiple dataframes into a single dataframe

# %%
result_df = pd.concat([result_general_df,
                       results_resnet_specific_df,
                       results_vgg_specific_df,
                       results_efficientNet_specific_df,
                       results_inception_specific_df],
                      ignore_index=True)

result_df.to_csv('/content/drive/MyDrive/BigData/Project/data/image_classification.csv', index=False)
result_df
# Out:
#                combined_keyword general_name  score_combined_general  \
# 0                         shark        shark                   100.0
# 1                        beetle       beetle                   100.0
# 2     shark, coho, puzzle, book        shark                    90.0
# 3                       compass          ass                    90.0
# 4                    sunglasses          ass                    90.0
# ...                         ...          ...                     ...
# 2338                        NaN          NaN                     NaN
# 2339                        NaN          NaN                     NaN
# 2340                        NaN          NaN                     NaN
# 2341                        NaN          NaN                     NaN
# 2342                        NaN          NaN                     NaN
#
#      resnet50_keyword                        specific_name  \
# 0                 NaN                                  NaN
# 1                 NaN                                  NaN
# 2                 NaN                                  NaN
# 3                 NaN                                  NaN
# 4                 NaN                                  NaN
# ...               ...                                  ...
# 2338              NaN                         truck wrasse
# 2339              NaN                               cougar
# 2340              NaN                               indris
# 2341              NaN                                  ass
# 2342              NaN  rio aguan valley spinytailed iguana
#
#       score_resnet50_specific vgg16_keyword  score_vgg16_specific  \
# 0                         NaN           NaN                   NaN
# 1                         NaN           NaN                   NaN
# 2                         NaN           NaN                   NaN
# 3                         NaN           NaN                   NaN
# 4                         NaN           NaN                   NaN
# ...                       ...           ...                   ...
# 2338                      NaN           NaN                   NaN
# 2339                      NaN           NaN                   NaN
# 2340                      NaN           NaN                   NaN
# 2341                      NaN           NaN                   NaN
# 2342                      NaN           NaN                   NaN
#
#      efficientNetV2M_keyword  score_efficientNetV2M_specific  \
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        NaN                             NaN
# 3                        NaN                             NaN
# 4                        NaN                             NaN
# ...                      ...                             ...
# 2338                     NaN                             NaN
# 2339                     NaN                             NaN
# 2340                     NaN                             NaN
# 2341                     NaN                             NaN
# 2342                     NaN                             NaN
#
#        inceptionV3_keyword  score_inceptionV3_specific
# 0                      NaN                         NaN
# 1                      NaN                         NaN
# 2                      NaN                         NaN
# 3                      NaN                         NaN
# 4                      NaN                         NaN
# ...                    ...                         ...
# 2338  garbage truck, truck                   85.500000
# 2339        cougar, cougar                   90.000000
# 2340          indri, indri                   81.818182
# 2341    passenger car, car                   90.000000
# 2342        valley, valley                   85.500000
#
# [2343 rows x 12 columns]

# %% [markdown]
# # Animal Species Analysis

# %% [markdown]
# ## Top-10 Species: Figures

# %%
sorted_df_combined_general = result_general_df.sort_values(by='score_combined_general', ascending=False)
sorted_df_combined_general.head(10)
# Out:
#      combined_keyword general_name  score_combined_general
# 0               shark        shark                   100.0
# 1168          pointer      pointer                   100.0
# 163                ox           ox                   100.0
# 165             panda        panda                   100.0
# 172             tiger        tiger                   100.0
# 175          lorikeet     lorikeet                   100.0
# 180             snail        snail                   100.0
# 532            weasel       weasel                   100.0
# 183          stingray     stingray                   100.0
# 853          thresher     thresher                   100.0

# %%
sorted_df_resnet_specific = results_resnet_specific_df.sort_values(by='score_resnet50_specific', ascending=False)
sorted_df_resnet_specific.head(10)
# Out:
#                resnet50_keyword       specific_name  score_resnet50_specific
# 103  leatherback turtle, turtle  leatherback turtle                     95.0
# 8      great white shark, shark   great white shark                     95.0
# 63          great grey owl, owl      great grey owl                     95.0
# 69             vulture, vulture                 tur                     90.0
# 190            gorilla, gorilla             gorilla                     90.0
# 84         brassiere, brassiere                 ass                     90.0
# 83         orangutan, orangutan                 ora                     90.0
# 78   hippopotamus, hippopotamus        hippopotamus                     90.0
# 183        assault rifle, rifle                 ass                     90.0
# 185        drumstick, drumstick                drum                     90.0

# %%
sorted_df_vgg_specific = results_vgg_specific_df.sort_values(by='score_vgg16_specific', ascending=False)
sorted_df_vgg_specific.head(10)
# Out:
#                   vgg16_keyword       specific_name  score_vgg16_specific
# 95   leatherback turtle, turtle  leatherback turtle                  95.0
# 224         great grey owl, owl      great grey owl                  95.0
# 42     great white shark, shark   great white shark                  95.0
# 247          passenger car, car                 ass                  90.0
# 188        goldfinch, goldfinch           goldfinch                  90.0
# 91         brassiere, brassiere                 ass                  90.0
# 179              basset, basset                 ass                  90.0
# 87           malinois, malinois                 mal                  90.0
# 86           bearskin, bearskin               bears                  90.0
# 84           giant panda, panda         giant panda                  90.0

# %%
sorted_df_efficient_specific = results_efficientNet_specific_df.sort_values(by='score_efficientNetV2M_specific', ascending=False)
sorted_df_efficient_specific.head(10)
# Out:
#         efficientNetV2M_keyword       specific_name  \
# 0      great white shark, shark   great white shark
# 195         great grey owl, owl      great grey owl
# 85   leatherback turtle, turtle  leatherback turtle
# 69          killer whale, whale        killer whale
# 83               red wolf, wolf                wolf
# 164          bearskin, bearskin               bears
# 165            car wheel, wheel                 eel
# 77                     eel, eel                 eel
# 76   hippopotamus, hippopotamus        hippopotamus
# 74             cheetah, cheetah             cheetah
#
#      score_efficientNetV2M_specific
# 0                              95.0
# 195                            95.0
# 85                             95.0
# 69                             90.0
# 83                             90.0
# 164                            90.0
# 165                            90.0
# 77                             90.0
# 76                             90.0
# 74                             90.0

# %%
sorted_df_inception_specific = results_inception_specific_df.sort_values(by='score_inceptionV3_specific', ascending=False)
sorted_df_inception_specific.head(10)
# Out:
#             inceptionV3_keyword       specific_name  \
# 0      great white shark, shark   great white shark
# 38   leatherback turtle, turtle  leatherback turtle
# 117         great grey owl, owl      great grey owl
# 88           cassette, cassette                 ass
# 185            gorilla, gorilla             gorilla
# 187       potter's wheel, wheel                 eel
# 82         brassiere, brassiere                 ass
# 81           malamute, malamute                 mal
# 189     cassette player, player                 ass
# 78   hippopotamus, hippopotamus        hippopotamus
#
#      score_inceptionV3_specific
# 0                          95.0
# 38                         95.0
# 117                        95.0
# 88                         90.0
# 185                        90.0
# 187                        90.0
# 82                         90.0
# 81                         90.0
# 189                        90.0
# 78                         90.0

# %% [markdown]
# The name(s) that appear most frequently across these dataframes:
# - **General species**: shark
# - **Specific species**: leatherback turtle

# %%
# Function to get the last word of a string
def get_last_word(name):
    return name.split()[-1] if isinstance(name, str) and name else name

# %%
# General speecies
top_name_combined_general = sorted_df_combined_general['general_name'].iloc[0]
top_name_resnet_specific = get_last_word(sorted_df_resnet_specific['specific_name'].iloc[0])
top_name_vgg_specific = get_last_word(sorted_df_vgg_specific['specific_name'].iloc[0])
top_name_efficient_specific = get_last_word(sorted_df_efficient_specific['specific_name'].iloc[0])
top_name_inception_specific = get_last_word(sorted_df_inception_specific['specific_name'].iloc[0])

top_names = [top_name_combined_general, top_name_resnet_specific, top_name_vgg_specific, top_name_efficient_specific, top_name_inception_specific]

from collections import Counter
name_counts = Counter(top_names)

most_common_name, count = name_counts.most_common(1)[0]
print(f"The most common general species is '{most_common_name}', appearing {count} times.")
# Out:
# The most common general species is 'shark', appearing 3 times.

# %%
# Specific species
top_name_resnet_specific = sorted_df_resnet_specific['specific_name'].iloc[0]
top_name_vgg_specific = sorted_df_vgg_specific['specific_name'].iloc[0]
top_name_efficient_specific = sorted_df_efficient_specific['specific_name'].iloc[0]
top_name_inception_specific = sorted_df_inception_specific['specific_name'].iloc[0]

top_names = [top_name_resnet_specific, top_name_vgg_specific, top_name_efficient_specific, top_name_inception_specific]

from collections import Counter
name_counts = Counter(top_names)

most_common_name, count = name_counts.most_common(1)[0]
print(f"The most common specific species is '{most_common_name}' appearing {count} times.")
# Out:
# The most common specific species is 'leatherback turtle' appearing 2 times.

# %% [markdown]
# ## Top-10 Species: Visualization

# %%
import matplotlib.pyplot as plt

def get_last_word(name):
    return name.split()[-1] if isinstance(name, str) else name

# For general species - consider the last word for specific dataframes
general_top10_combined = sorted_df_combined_general['general_name'].value_counts().head(10)
general_top10_resnet = sorted_df_resnet_specific['specific_name'].apply(get_last_word).value_counts().head(10)
general_top10_vgg = sorted_df_vgg_specific['specific_name'].apply(get_last_word).value_counts().head(10)
general_top10_efficient = sorted_df_efficient_specific['specific_name'].apply(get_last_word).value_counts().head(10)
general_top10_inception = sorted_df_inception_specific['specific_name'].apply(get_last_word).value_counts().head(10)

# For specific species
specific_top10_resnet = sorted_df_resnet_specific['specific_name'].value_counts().head(10)
specific_top10_vgg = sorted_df_vgg_specific['specific_name'].value_counts().head(10)
specific_top10_efficient = sorted_df_efficient_specific['specific_name'].value_counts().head(10)
specific_top10_inception = sorted_df_inception_specific['specific_name'].value_counts().head(10)

# %%
general_data = pd.DataFrame({
    'General': general_top10_combined,
    'ResNet50': general_top10_resnet,
    'VGG16': general_top10_vgg,
    'EfficientNetV2M': general_top10_efficient,
    'InceptionV3': general_top10_inception
}).fillna(0)

specific_data = pd.DataFrame({
    'ResNet50': specific_top10_resnet,
    'VGG16': specific_top10_vgg,
    'EfficientNetV2M': specific_top10_efficient,
    'InceptionV3': specific_top10_inception
}).fillna(0)

def plot_top10_species(data, title):
    data.plot(kind='bar', stacked=True, figsize=(15, 8))
    plt.xlabel('Species')
    plt.ylabel('Count')
    plt.title(title)
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

plot_top10_species(general_data, 'Top-10 General Species in Each Model')
plot_top10_species(specific_data, 'Top-10 Specific Species in Each Model')

# %%
def plot_top10_species(data, title):
    ax = data.plot(kind='barh', stacked=True, figsize=(15, 8))

    plt.xlabel('Count')
    plt.ylabel('Dataframes')
    plt.title(title)

    plt.tight_layout()

    # Annotate the count on the bars
    for p in ax.patches:
        width = p.get_width()  # Width of the bar (the count)
        if width > 0:  # Only label the bar if width is greater than 0
            plt.text(p.get_x() + width/2,
                     p.get_y() + p.get_height()/2,
                     f'{int(width)}',
                     ha='center',
                     va='center')

    plt.show()

general_data = general_data.T
specific_data = specific_data.T

plot_top10_species(general_data, 'Top-10 General Species in Each Model')
plot_top10_species(specific_data, 'Top-10 Specific Species in Each Model')

# %% [markdown]
# ## Country Distribution
# Note: `df['specific_name']` is equal to `country_df['Speicific Names Normalized']`

# %%
country_df = pd.read_csv('/content/drive/MyDrive/BigData/Project/data/final_animal_list.csv')
country_df
# Out:
#                                    Distribution Country  \
# 0     Angola, Botswana, Central African Republic, Dj...
# 1                                               Bahamas
# 2     Australia, Christmas Island, Indonesia, Maurit...
# 3                                Madagascar, Seychelles
# 4                                                 Italy
# ...                                                 ...
# 8125    Malawi, Mozambique, United Republic of Tanzania
# 8126  Argentina, Belize, Bolivia (Plurinational Stat...
# 8127  Albania, Algeria, Angola, Argentina, Australia...
# 8128                 Eswatini, Mozambique, South Africa
# 8129                                       South Africa
#
#                    Specific Names    Specific Names Normalized  \
# 0                        Aardwolf                     aardwolf
# 1                Abaco Island Boa             abaco island boa
# 2                  Abbott's Booby                abbotts booby
# 3              Abbott's Day Gecko            abbotts day gecko
# 4                 Abruzzo Chamois              abruzzo chamois
# ...                           ...                          ...
# 8125        Zomba pygmy chameleon        zomba pygmy chameleon
# 8126             Zone-tailed Hawk              zonetailed hawk
# 8127         Zorro thresher shark         zorro thresher shark
# 8128  Zoutpansberg Girdled Lizard  zoutpansberg girdled lizard
# 8129     Zululand Dwarf Chameleon     zululand dwarf chameleon
#
#      General Names Normalized
# 0                    aardwolf
# 1                         boa
# 2                       booby
# 3                       gecko
# 4                     chamois
# ...                       ...
# 8125                chameleon
# 8126                     hawk
# 8127                    shark
# 8128                   lizard
# 8129                chameleon
#
# [8130 rows x 4 columns]

# %%
df = pd.read_csv('/content/drive/MyDrive/BigData/Project/data/image_classification.csv')
df
# Out:
#                combined_keyword general_name  score_combined_general  \
# 0                         shark        shark                   100.0
# 1                        beetle       beetle                   100.0
# 2     shark, coho, puzzle, book        shark                    90.0
# 3                       compass          ass                    90.0
# 4                    sunglasses          ass                    90.0
# ...                         ...          ...                     ...
# 2338                        NaN          NaN                     NaN
# 2339                        NaN          NaN                     NaN
# 2340                        NaN          NaN                     NaN
# 2341                        NaN          NaN                     NaN
# 2342                        NaN          NaN                     NaN
#
#      resnet50_keyword                        specific_name  \
# 0                 NaN                                  NaN
# 1                 NaN                                  NaN
# 2                 NaN                                  NaN
# 3                 NaN                                  NaN
# 4                 NaN                                  NaN
# ...               ...                                  ...
# 2338              NaN                         truck wrasse
# 2339              NaN                               cougar
# 2340              NaN                               indris
# 2341              NaN                                  ass
# 2342              NaN  rio aguan valley spinytailed iguana
#
#       score_resnet50_specific vgg16_keyword  score_vgg16_specific  \
# 0                         NaN           NaN                   NaN
# 1                         NaN           NaN                   NaN
# 2                         NaN           NaN                   NaN
# 3                         NaN           NaN                   NaN
# 4                         NaN           NaN                   NaN
# ...                       ...           ...                   ...
# 2338                      NaN           NaN                   NaN
# 2339                      NaN           NaN                   NaN
# 2340                      NaN           NaN                   NaN
# 2341                      NaN           NaN                   NaN
# 2342                      NaN           NaN                   NaN
#
#      efficientNetV2M_keyword  score_efficientNetV2M_specific  \
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        NaN                             NaN
# 3                        NaN                             NaN
# 4                        NaN                             NaN
# ...                      ...                             ...
# 2338                     NaN                             NaN
# 2339                     NaN                             NaN
# 2340                     NaN                             NaN
# 2341                     NaN                             NaN
# 2342                     NaN                             NaN
#
#        inceptionV3_keyword  score_inceptionV3_specific
# 0                      NaN                         NaN
# 1                      NaN                         NaN
# 2                      NaN                         NaN
# 3                      NaN                         NaN
# 4                      NaN                         NaN
# ...                    ...                         ...
# 2338  garbage truck, truck                   85.500000
# 2339        cougar, cougar                   90.000000
# 2340          indri, indri                   81.818182
# 2341    passenger car, car                   90.000000
# 2342        valley, valley                   85.500000
#
# [2343 rows x 12 columns]

# %%
def split_countries(distribution):
    if isinstance(distribution, str):
        return distribution.split(',')
    else:
        return []

country_df['Country_List'] = country_df['Distribution Country'].apply(split_countries)

countries_exploded_df = country_df.explode('Country_List')
countries_exploded_df['Country_List'] = countries_exploded_df['Country_List'].str.strip()

# %%
countries_exploded_df
# Out:
#                                    Distribution Country  \
# 0     Angola, Botswana, Central African Republic, Dj...
# 0     Angola, Botswana, Central African Republic, Dj...
# 0     Angola, Botswana, Central African Republic, Dj...
# 0     Angola, Botswana, Central African Republic, Dj...
# 0     Angola, Botswana, Central African Republic, Dj...
# ...                                                 ...
# 8127  Albania, Algeria, Angola, Argentina, Australia...
# 8128                 Eswatini, Mozambique, South Africa
# 8128                 Eswatini, Mozambique, South Africa
# 8128                 Eswatini, Mozambique, South Africa
# 8129                                       South Africa
#
#                    Specific Names    Specific Names Normalized  \
# 0                        Aardwolf                     aardwolf
# 0                        Aardwolf                     aardwolf
# 0                        Aardwolf                     aardwolf
# 0                        Aardwolf                     aardwolf
# 0                        Aardwolf                     aardwolf
# ...                           ...                          ...
# 8127         Zorro thresher shark         zorro thresher shark
# 8128  Zoutpansberg Girdled Lizard  zoutpansberg girdled lizard
# 8128  Zoutpansberg Girdled Lizard  zoutpansberg girdled lizard
# 8128  Zoutpansberg Girdled Lizard  zoutpansberg girdled lizard
# 8129     Zululand Dwarf Chameleon     zululand dwarf chameleon
#
#      General Names Normalized              Country_List
# 0                    aardwolf                    Angola
# 0                    aardwolf                  Botswana
# 0                    aardwolf  Central African Republic
# 0                    aardwolf                  Djibouti
# 0                    aardwolf                     Egypt
# ...                       ...                       ...
# 8127                    shark                     Yemen
# 8128                   lizard                  Eswatini
# 8128                   lizard                Mozambique
# 8128                   lizard              South Africa
# 8129                chameleon              South Africa
#
# [82991 rows x 5 columns]

# %% [markdown]
# ### General Species

# %%
countries_exploded_df['Country_List'] = countries_exploded_df['Country_List'].astype(str).str.strip()

general_name_matches = pd.merge(
    df[['general_name']],
    countries_exploded_df[['General Names Normalized', 'Country_List']],
    left_on='general_name',
    right_on='General Names Normalized',
    how='inner'
)

# Count the number of unique general names matched
general_name_count = general_name_matches['general_name'].nunique()

print(f'Number of unique general names matched: {general_name_count}')
# Out:
# Number of unique general names matched: 220

# %%
import pandas as pd

def chunker(seq, size):
    """Yield successive chunks from seq."""
    for i in range(0, len(seq), size):
        yield seq[i:i + size]


countries_exploded_df['Country_List'] = countries_exploded_df['Country_List'].astype(str).str.strip()

general_name_matches = pd.merge(
    df[['general_name']],
    countries_exploded_df[['General Names Normalized', 'Country_List']],
    left_on='general_name',
    right_on='General Names Normalized',
    how='inner'
)

unique_general_names = list(general_name_matches['general_name'].unique())

general_name_count = len(unique_general_names)

print(f'Number of unique general names matched: {general_name_count}')

# Print the unique general names in chunks of 15
print('Unique General Names Matched:')
for chunk in chunker(unique_general_names, 15):
    print(', '.join(chunk))
# Out:
# Number of unique general names matched: 220
# Unique General Names Matched:
# shark, beetle, ass, cheetah, leopard, bear, wolf, hammerhead, gazelle, mouse, conch, maskedowl, shoebill, gecko, screechowl
# newt, sheep, ray, rat, white, terrapin, cockatiel, monitor, sideneck, skink, capuchin, tarantula, lion, scorpion, coatimundi
# cucumber, bears, crocodile, ostrich, snail, frog, chameleon, eagle, boa, sloth, alligator, treekangaroo, helmetcrest, toucan, quail
# dugong, elk, antelope, fish, bottlehead, vulture, mal, snake, padloper, bluebonnet, cardinal, butterfly, turtle, hog, crabhawk
# beauty, dog, cockoftherock, whale, rhea, boobook, bustard, caracal, buffalo, jaguar, saker, hat, drum, muggar, elephant
# rose, porcupine, albatross, barb, sevruga, macaw, sturgeon, ship, hippopotamus, ape, guitarfish, ox, lynx, panda, constrictor
# tiger, lorikeet, stingray, woodhen, blackvelvet, armadillo, hare, baboon, squirrel, salamander, orangutan, mongoose, hammerhai, fox, prairiechicken
# cobra, pointer, iguana, pelican, bunch, cat, ibex, kiang, treesnail, loggerhead, black, buzzardkite, lizard, coati, rosegrey
# lampmussel, axolotl, peacockpheasant, agama, ora, chiru, python, wallaby, orong, ratel, shovelnose, goose, stork, viper, crocoteju
# marmot, napoleonfish, eel, skunk, pinkmucket, penguin, otter, pronghorn, bearcat, hummingbird, bison, rackettail, badger, zebra, mala
# rabbit, drill, crane, spari, takin, sasin, flamingo, dragon, kite, harrier, bullfinch, weasel, cascabel, colorado, monkey
# griffon, dhole, goldfinch, bird, horse, sunbeam, stag, wombat, riflebird, seahorse, treefrog, acerodon, fanaloka, swingletail, hyena
# deer, falconet, owl, carib, gorilla, chestnut, barbet, pangolin, gator, pigeon, thresher, sicklebill, lemonfish, ferret, gibbon
# paddlefish, spatuletail, titi, whiptail, echidna, streamertail, cockatoo, chimpanzee, guenon, honeyeater, anteater, harewallaby, eye, bat, potto
# sawback, spoonbill, cougar, florican, imperialpigeon, barnowl, flyingfox, swan, monster, finch

# %%
country_match_counts = general_name_matches['Country_List'].value_counts().reset_index()
country_match_counts.columns = ['Country', 'Match_Count']

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Merge the world map with the match counts
world = world.merge(country_match_counts, left_on='name', right_on='Country', how='left')

fig, ax = plt.subplots(1, 1, figsize=(15, 10))
world.boundary.plot(ax=ax)
world.plot(column='Match_Count', ax=ax, legend=True,
           legend_kwds={'label': "Number of General Species Matches by Country",
                        'orientation': "horizontal"})

plt.show()
# Out:
# <ipython-input-19-8fa46552a788>:4: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %% [markdown]
# ### Specific Species

# %%
from collections import Counter

specific_name_columns = [
    'resnet50_keyword',
    'vgg16_keyword',
    'efficientNetV2M_keyword',
    'inceptionV3_keyword'
]

countries_exploded_df['Specific Names Normalized'] = countries_exploded_df['Specific Names Normalized'].astype(str)

specific_name_matches_counter = Counter()
all_specific_name_matches = pd.DataFrame()

for keyword_column in specific_name_columns:
    df[keyword_column] = df[keyword_column].astype(str)

    specific_name_column = df.columns[df.columns.get_loc(keyword_column) + 1]
    df[specific_name_column] = df[specific_name_column].astype(str)

    # Merge df with countries_exploded_df to find matches
    specific_name_matches = pd.merge(
        df[[specific_name_column]],
        countries_exploded_df[['Specific Names Normalized', 'Country_List']],
        left_on=specific_name_column,
        right_on='Specific Names Normalized',
        how='inner'
    )
    all_specific_name_matches = all_specific_name_matches.append(specific_name_matches)
    specific_name_matches_counter.update(specific_name_matches[specific_name_column].dropna().unique())

# Drop duplicates if any
all_specific_name_matches.drop_duplicates(inplace=True)
print(f'Number of unique specific names matched: {sum(specific_name_matches_counter.values())}')

for column, count in specific_name_matches_counter.items():
    print(f'Number of unique matches for {column}: {count}')
# Out:
# Number of unique specific names matched: 195
# Number of unique matches for grandidiers madagascar ground gecko: 1
# Number of unique matches for tiger: 1
# Number of unique matches for ass: 1
# Number of unique matches for hammerhead: 1
# Number of unique matches for argentine black and white tegu: 1
# Number of unique matches for mediterranean pillow coral: 1
# Number of unique matches for black rhinoceros: 1
# Number of unique matches for sasin: 1
# Number of unique matches for great white shark: 1
# Number of unique matches for banded arboreal alligator lizard: 1
# Number of unique matches for barn owl: 1
# Number of unique matches for ball python: 1
# Number of unique matches for timber wolf: 1
# Number of unique matches for andean cat: 1
# Number of unique matches for thunder snake: 1
# Number of unique matches for fire corals: 1
# Number of unique matches for amber mountain leaf chameleon: 1
# Number of unique matches for lion: 1
# Number of unique matches for african chameleon: 1
# Number of unique matches for hermit ibis: 1
# Number of unique matches for box ray: 1
# Number of unique matches for afroaustralian fur seal: 1
# Number of unique matches for grey sea eagle: 1
# Number of unique matches for marenzellers mushroom coral: 1
# Number of unique matches for mal: 1
# Number of unique matches for wolf: 1
# Number of unique matches for alabama lamp pearly mussel: 1
# Number of unique matches for ostrich: 1
# Number of unique matches for brown bear: 1
# Number of unique matches for amazonian poisonarrow frog: 1
# Number of unique matches for bald eagle: 1
# Number of unique matches for gator: 1
# Number of unique matches for argentine boa constrictor: 1
# Number of unique matches for eel: 1
# Number of unique matches for agra lizard: 1
# Number of unique matches for central american coral snake: 1
# Number of unique matches for emerald green snail: 1
# Number of unique matches for blue dog: 1
# Number of unique matches for terrapin: 1
# Number of unique matches for kiang: 1
# Number of unique matches for ora: 1
# Number of unique matches for takin: 1
# Number of unique matches for rubber boa: 1
# Number of unique matches for horned guan: 1
# Number of unique matches for african crocodile: 1
# Number of unique matches for water buffalo: 1
# Number of unique matches for jaguar: 1
# Number of unique matches for grayfish: 1
# Number of unique matches for cougar: 1
# Number of unique matches for drum: 1
# Number of unique matches for helmet coral: 1
# Number of unique matches for sea cat: 1
# Number of unique matches for bawean hog deer: 1
# Number of unique matches for beaked cup coral: 1
# Number of unique matches for great grey owl: 1
# Number of unique matches for blackfooted grey langur: 1
# Number of unique matches for blueandyellow macaw: 1
# Number of unique matches for ship: 1
# Number of unique matches for honeycomb plate coral: 1
# Number of unique matches for granite belt leaftailed gecko: 1
# Number of unique matches for tur: 1
# Number of unique matches for giant panda: 1
# Number of unique matches for lorikeets: 1
# Number of unique matches for satanas beetle: 1
# Number of unique matches for magdalena freshwater stingray: 1
# Number of unique matches for amethystine rock python: 1
# Number of unique matches for hippopotamus: 1
# Number of unique matches for cape mountain zebra: 1
# Number of unique matches for ruffed lemur: 1
# Number of unique matches for table coral: 1
# Number of unique matches for northern bahamian rock iguana: 1
# Number of unique matches for orangespined hairy dwarf porcupine: 1
# Number of unique matches for prairie falcon: 1
# Number of unique matches for saker: 1
# Number of unique matches for black and white spitting cobra: 1
# Number of unique matches for cheetah: 1
# Number of unique matches for killer whale: 1
# Number of unique matches for red bear: 1
# Number of unique matches for bathurst grassland earless dragon: 1
# Number of unique matches for aleutian cackling goose: 1
# Number of unique matches for green and black poisonarrow frog: 1
# Number of unique matches for bockadam snake: 1
# Number of unique matches for basket coral: 1
# Number of unique matches for orong: 1
# Number of unique matches for hummingbirds: 1
# Number of unique matches for burmese peacock softshell: 1
# Number of unique matches for leatherback turtle: 1
# Number of unique matches for cape griffon: 1
# Number of unique matches for bolivian red howler monkey: 1
# Number of unique matches for grey cuscus: 1
# Number of unique matches for grey whale: 1
# Number of unique matches for alto de buey poison frog: 1
# Number of unique matches for dhole: 1
# Number of unique matches for chilean helmeted water toad: 1
# Number of unique matches for common iguana: 1
# Number of unique matches for mountain horned agama: 1
# Number of unique matches for king cobra: 1
# Number of unique matches for crane: 1
# Number of unique matches for mexican prairie marmot: 1
# Number of unique matches for blackpalmed rock monitor: 1
# Number of unique matches for alice springs mouse: 1
# Number of unique matches for african elephant: 1
# Number of unique matches for blackbrowed spider monkey: 1
# Number of unique matches for angolan blackandwhite colobus: 1
# Number of unique matches for bull frog: 1
# Number of unique matches for ratel: 1
# Number of unique matches for afghan fox: 1
# Number of unique matches for apollo butterfly: 1
# Number of unique matches for bears: 1
# Number of unique matches for fierce snake: 1
# Number of unique matches for acapulco lesser orange tarantula: 1
# Number of unique matches for fly river turtle: 1
# Number of unique matches for loggerhead: 1
# Number of unique matches for indian wild ox: 1
# Number of unique matches for cyclops longbeaked echidna: 1
# Number of unique matches for bridled nailtailed wallaby: 1
# Number of unique matches for disk coral: 1
# Number of unique matches for sicklefin lemon shark: 1
# Number of unique matches for amber mountain forkmarked lemur: 1
# Number of unique matches for cabbage coral: 1
# Number of unique matches for flamingos: 1
# Number of unique matches for chinhai spiny crocodile newt: 1
# Number of unique matches for andean bear: 1
# Number of unique matches for water boa: 1
# Number of unique matches for saw shark: 1
# Number of unique matches for sturgeon: 1
# Number of unique matches for blackfooted ferret: 1
# Number of unique matches for military macaw: 1
# Number of unique matches for apes: 1
# Number of unique matches for new guinea bevelnosed boa: 1
# Number of unique matches for worm coral: 1
# Number of unique matches for eagles: 1
# Number of unique matches for african golden cat: 1
# Number of unique matches for goldfinch: 1
# Number of unique matches for bowl coral: 1
# Number of unique matches for blue bustard: 1
# Number of unique matches for northern hairynosed wombat: 1
# Number of unique matches for threestriped roof turtle: 1
# Number of unique matches for coxens bluebrowed fig parrot: 1
# Number of unique matches for african clawless otter: 1
# Number of unique matches for gila monster: 1
# Number of unique matches for humboldts hognosed skunk: 1
# Number of unique matches for drill: 1
# Number of unique matches for gorilla: 1
# Number of unique matches for weasel sportive lemur: 1
# Number of unique matches for asiatic wild dog: 1
# Number of unique matches for axolotl: 1
# Number of unique matches for proboscis monkey: 1
# Number of unique matches for brazilian water cobra: 1
# Number of unique matches for bee hummingbird: 1
# Number of unique matches for leopard: 1
# Number of unique matches for spiny boa: 1
# Number of unique matches for red fox: 1
# Number of unique matches for southern blackthroated finch: 1
# Number of unique matches for bustards: 1
# Number of unique matches for assam rabbit: 1
# Number of unique matches for bareeyed cockatoo: 1
# Number of unique matches for saola: 1
# Number of unique matches for sloth bear: 1
# Number of unique matches for china clam: 1
# Number of unique matches for van dams girdled lizard: 1
# Number of unique matches for dugong: 1
# Number of unique matches for central asian stone marten: 1
# Number of unique matches for sea horse: 1
# Number of unique matches for asian water dragon: 1
# Number of unique matches for baptista lake titi: 1
# Number of unique matches for amazon black howler monkey: 1
# Number of unique matches for indris: 1
# Number of unique matches for azovblack sea sturgeon: 1
# Number of unique matches for rio aguan valley spinytailed iguana: 1
# Number of unique matches for asian whitecrested hornbill: 1
# Number of unique matches for white pointer: 1
# Number of unique matches for toco toucan: 1
# Number of unique matches for boa constrictor: 1
# Number of unique matches for andersons salamander: 1
# Number of unique matches for argentine gray fox: 1
# Number of unique matches for black stork: 1
# Number of unique matches for redbacked saki: 1
# Number of unique matches for bale monkey: 1
# Number of unique matches for whiptail: 1
# Number of unique matches for baby python: 1
# Number of unique matches for truck wrasse: 1
# Number of unique matches for northern african wild cat: 1
# Number of unique matches for african swallowtailed kite: 1
# Number of unique matches for siamang: 1
# Number of unique matches for blackcheeked crested gibbon: 1
# Number of unique matches for bawny white: 1
# Number of unique matches for blackandwhite tasselear marmoset: 1
# Number of unique matches for chimpanzee: 1
# Number of unique matches for fluted giant clam: 1
# Number of unique matches for bengal hanuman langur: 1
# Number of unique matches for greater spotnosed guenon: 1
# Number of unique matches for blackstriped tufted capuchin: 1
# Number of unique matches for indigo macaw: 1
# Number of unique matches for african black eagle: 1
# <ipython-input-21-926c1ee93eba>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_specific_name_matches = all_specific_name_matches.append(specific_name_matches)
# <ipython-input-21-926c1ee93eba>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_specific_name_matches = all_specific_name_matches.append(specific_name_matches)
# <ipython-input-21-926c1ee93eba>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_specific_name_matches = all_specific_name_matches.append(specific_name_matches)
# <ipython-input-21-926c1ee93eba>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_specific_name_matches = all_specific_name_matches.append(specific_name_matches)

# %%
from collections import Counter

def chunker(seq, size):
    """Yield successive chunks from seq."""
    for i in range(0, len(seq), size):
        yield seq[i:i + size]

specific_name_columns = [
    'resnet50_keyword',
    'vgg16_keyword',
    'efficientNetV2M_keyword',
    'inceptionV3_keyword'
]

countries_exploded_df['Specific Names Normalized'] = countries_exploded_df['Specific Names Normalized'].astype(str)

specific_name_matches_counter = Counter()
all_specific_name_matches = pd.DataFrame()

for keyword_column in specific_name_columns:
    df[keyword_column] = df[keyword_column].astype(str)

    specific_name_column = df.columns[df.columns.get_loc(keyword_column) + 1]
    df[specific_name_column] = df[specific_name_column].astype(str)

    # Merge df with countries_exploded_df to find matches
    specific_name_matches = pd.merge(
        df[[specific_name_column]],
        countries_exploded_df[['Specific Names Normalized', 'Country_List']],
        left_on=specific_name_column,
        right_on='Specific Names Normalized',
        how='inner'
    )
    all_specific_name_matches = all_specific_name_matches.append(specific_name_matches)
    specific_name_matches_counter.update(specific_name_matches[specific_name_column].dropna().unique())

# Drop duplicates if any
all_specific_name_matches.drop_duplicates(inplace=True)
print(f'Number of unique specific names matched: {sum(specific_name_matches_counter.values())}')

columns = set()
for column, count in specific_name_matches_counter.items():
    columns.add(column)

# Convert the set to a list before passing to the chunker
columns_list = list(columns)

for chunk in chunker(columns_list, 5):
    print(', '.join(chunk))
# Out:
# <ipython-input-26-69bd937a892f>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_specific_name_matches = all_specific_name_matches.append(specific_name_matches)
# <ipython-input-26-69bd937a892f>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_specific_name_matches = all_specific_name_matches.append(specific_name_matches)
# <ipython-input-26-69bd937a892f>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_specific_name_matches = all_specific_name_matches.append(specific_name_matches)
# <ipython-input-26-69bd937a892f>:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_specific_name_matches = all_specific_name_matches.append(specific_name_matches)
# Number of unique specific names matched: 195
# blue bustard, ball python, green and black poisonarrow frog, northern african wild cat, giant panda
# bowl coral, amazon black howler monkey, toco toucan, basket coral, ruffed lemur
# bull frog, red bear, prairie falcon, acapulco lesser orange tarantula, hippopotamus
# alto de buey poison frog, blueandyellow macaw, dhole, drill, helmet coral
# lion, gorilla, baptista lake titi, fire corals, blackstriped tufted capuchin
# bawean hog deer, ship, loggerhead, brown bear, grayfish
# indris, mediterranean pillow coral, goldfinch, apollo butterfly, box ray
# terrapin, alice springs mouse, bockadam snake, white pointer, amber mountain leaf chameleon
# andersons salamander, leatherback turtle, water boa, rubber boa, cabbage coral
# ostrich, honeycomb plate coral, central asian stone marten, ass, bears
# northern bahamian rock iguana, saola, banded arboreal alligator lizard, threestriped roof turtle, fly river turtle
# ratel, northern hairynosed wombat, axolotl, military macaw, cape mountain zebra
# marenzellers mushroom coral, hermit ibis, sturgeon, whiptail, humboldts hognosed skunk
# mexican prairie marmot, sicklefin lemon shark, dugong, beaked cup coral, blackbrowed spider monkey
# kiang, siamang, orangespined hairy dwarf porcupine, grey whale, asiatic wild dog
# bolivian red howler monkey, timber wolf, blackfooted ferret, argentine gray fox, blackandwhite tasselear marmoset
# wolf, redbacked saki, african clawless otter, emerald green snail, greater spotnosed guenon
# african black eagle, great white shark, thunder snake, jaguar, lorikeets
# killer whale, african elephant, brazilian water cobra, apes, black stork
# bengal hanuman langur, indigo macaw, table coral, bustards, china clam
# gila monster, leopard, rio aguan valley spinytailed iguana, afghan fox, sea cat
# satanas beetle, blackpalmed rock monitor, bee hummingbird, african golden cat, amethystine rock python
# fierce snake, assam rabbit, magdalena freshwater stingray, african chameleon, grey sea eagle
# mountain horned agama, new guinea bevelnosed boa, bawny white, truck wrasse, argentine black and white tegu
# eel, chilean helmeted water toad, saw shark, coxens bluebrowed fig parrot, van dams girdled lizard
# southern blackthroated finch, baby python, andean bear, weasel sportive lemur, proboscis monkey
# alabama lamp pearly mussel, king cobra, grey cuscus, bald eagle, black rhinoceros
# sea horse, bareeyed cockatoo, tur, hammerhead, bridled nailtailed wallaby
# great grey owl, blackfooted grey langur, agra lizard, bathurst grassland earless dragon, african crocodile
# spiny boa, angolan blackandwhite colobus, drum, azovblack sea sturgeon, disk coral
# amber mountain forkmarked lemur, african swallowtailed kite, cheetah, chimpanzee, sasin
# amazonian poisonarrow frog, granite belt leaftailed gecko, blue dog, asian whitecrested hornbill, cougar
# ora, boa constrictor, water buffalo, argentine boa constrictor, hummingbirds
# grandidiers madagascar ground gecko, andean cat, cape griffon, gator, chinhai spiny crocodile newt
# black and white spitting cobra, central american coral snake, cyclops longbeaked echidna, mal, common iguana
# crane, eagles, blackcheeked crested gibbon, aleutian cackling goose, burmese peacock softshell
# red fox, orong, afroaustralian fur seal, sloth bear, tiger
# indian wild ox, barn owl, flamingos, worm coral, asian water dragon
# horned guan, fluted giant clam, bale monkey, saker, takin

# %%
# Aggregate this data for visualization
country_specific_species = all_specific_name_matches.groupby('Country_List').agg(','.join).reset_index()
# Out:
# <ipython-input-25-55081fade49c>:1: FutureWarning: ['score_vgg16_specific', 'score_efficientNetV2M_specific', 'score_inceptionV3_specific'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   country_specific_species = all_specific_name_matches.groupby('Country_List').agg(','.join).reset_index()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

specific_country_match_counts = all_specific_name_matches['Country_List'].value_counts().reset_index()
specific_country_match_counts.columns = ['Country', 'Match_Count']

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

world = world.merge(specific_country_match_counts, left_on='name', right_on='Country', how='left')

fig, ax = plt.subplots(1, 1, figsize=(15, 10))
world.boundary.plot(ax=ax)
world.plot(column='Match_Count', ax=ax, legend=True,
           legend_kwds={'label': "Number of Specific Species Matches by Country",
                        'orientation': "horizontal"})

plt.show()
# Out:
# <ipython-input-28-c1353bb844e6>:11: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
